# %% [markdown]
# Data source: https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences

# %% [markdown]
# Data Set Information:
#
# This dataset was created for the Paper 'From Group to Individual Labels using Deep Features', Kotzias et. al,. KDD 2015. It contains sentences labelled with positive or negative sentiment.
#
# Details:
# Sentence score is either 1 (for positive) or 0 (for negative)
# The sentences come from three different websites/fields:
# - imdb.com
# - amazon.com
# - yelp.com
#
# For each website, there exist 500 positive and 500 negative sentences. Those were selected randomly for larger datasets of reviews.

# %% [markdown]
# ### Summary:
# - [Balanced Labels](#labels)
# - [Preprocessing Sentences](#pre)
# - [Split Training and Testing Set](#split)
# - [Postprocessing](#post)
# - [Logistic Regression vs Naive Bayes](#models)
# - [N-gram Model](#2)
# - [PCA for Bag of Words](#pca)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import normalize
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from nltk.stem import WordNetLemmatizer 
from sklearn.decomposition import PCA
from nltk.corpus import stopwords
import pandas as pd
import numpy as np
import operator
import string
import nltk
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/melissajin/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/melissajin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/melissajin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#load data sets
imdb = pd.read_csv("imdb_labelled.txt", sep="\t",header =None)
amazon = pd.read_csv("amazon_cells_labelled.txt", sep="\t",header =None)
yelp = pd.read_csv("yelp_labelled.txt", sep="\t",header =None)
print(len(imdb),len(amazon),len(yelp))
# Out:
# 748 1000 1000

# %%
imdb.head()
# Out:
#                                                    0  1
# 0  A very, very, very slow-moving, aimless movie ...  0
# 1  Not sure who was more lost - the flat characte...  0
# 2  Attempting artiness with black & white and cle...  0
# 3       Very little music or anything to speak of.    0
# 4  The best scene in the movie was when Gerardo i...  1

# %% [markdown]
# #### <a id ="labels">Balanced Labels</a>

# %%
#The function count the number of positive labels and the number of negative labels and calculate the ratio
def labelcount(dataset):    
    positive = 0
    for i in range(0,len(dataset)):
        if dataset[1][i] == 1:
            positive +=1
    negative = len(dataset) - positive
    ratio = positive/negative
    print("The ratio (positive/negative) is: " + str(ratio))
labelcount(imdb)
labelcount(amazon)
labelcount(yelp)
# Out:
# The ratio (positive/negative) is: 1.0662983425414365
# The ratio (positive/negative) is: 1.0
# The ratio (positive/negative) is: 1.0

# %% [markdown]
# #### <a id = "pre">Preprocessing Sentences</a>

# %%
#convert lowercase all data 
imdb = imdb.apply(lambda x: x.astype(str).str.lower())
amazon = amazon.apply(lambda x: x.astype(str).str.lower())
yelp = yelp.apply(lambda x: x.astype(str).str.lower())

# %%
#Lemmatization of all words
lemmatizer = WordNetLemmatizer()
for i in range(0,len(imdb)):
    imdb[0][i] = nltk.word_tokenize(imdb[0][i])
    imdb[0][i] = [lemmatizer.lemmatize(w) for w in imdb[0][i]]
for i in range(0,len(amazon)):
    amazon[0][i] = nltk.word_tokenize(amazon[0][i])
    amazon[0][i] = [lemmatizer.lemmatize(w) for w in amazon[0][i]]
for i in range(0,len(yelp)):
    yelp[0][i] = nltk.word_tokenize(yelp[0][i])
    yelp[0][i] = [lemmatizer.lemmatize(w) for w in yelp[0][i]]

# %%
#strip stop words
stop_words = set(stopwords.words('english'))
for i in range(0,len(imdb)):
    imdb[0][i] = [word for word in imdb[0][i] if not word in stop_words]   
for i in range(0,len(amazon)):
    amazon[0][i] = [word for word in amazon[0][i] if not word in stop_words] 
for i in range(0,len(yelp)):
    yelp[0][i] = [word for word in yelp[0][i] if not word in stop_words]

# %%
#strip punctuation
string.punctuation
exclude = set(string.punctuation)
for i in range(0,len(imdb)):
    imdb[0][i] = [''.join(p for p in word if p not in string.punctuation) for word in imdb[0][i]]  
    imdb[0][i] = [word for word in imdb[0][i] if word]
for i in range(0,len(amazon)):
    amazon[0][i] = [''.join(p for p in word if p not in string.punctuation) for word in amazon[0][i]]
    amazon[0][i] = [word for word in amazon[0][i] if word]
for i in range(0,len(yelp)):
    yelp[0][i] = [''.join(p for p in word if p not in string.punctuation) for word in yelp[0][i]]
    yelp[0][i] = [word for word in yelp[0][i] if word]

# %% [markdown]
# #### <a id="split">Split Training and Testing Set<a/>

# %%
x_train,y_train,x_test,y_test=[],[],[],[]
x_train.extend(imdb[0][:400])
x_train.extend(amazon[0][:400])
x_train.extend(yelp[0][:400]) 
y_train.extend(imdb[1][:400])
y_train.extend(amazon[1][:400])
y_train.extend(yelp[1][:400]) 
x_test.extend(imdb[0][400:500])
x_test.extend(amazon[0][400:500])
x_test.extend(yelp[0][400:500]) 
y_test.extend(imdb[1][400:500])
y_test.extend(amazon[1][400:500])
y_test.extend(yelp[1][400:500])

# %%
print(len(x_train),len(train_y),len(test_x),len(test_y))
# Out:
# 1200 1200 300 300

# %%
x_train = [",".join(ele) for ele in x_train]
x_test = [",".join(ele) for ele in x_test]

# %%
ctV = CountVectorizer()
#build a dictionary of unique words for training set
x_train_bag = ctV.fit_transform(x_train).todense()

ctV_test = CountVectorizer(vocabulary=ctV.get_feature_names())
x_test_bag = ctV_test.fit_transform(x_test).todense()

# %%
print(x_train_bag.shape,x_test_bag.shape)
# Out:
# (1200, 2986) (300, 2986)

# %%
print(x_train[0])
print(x_train_bag[0])
# Out:
# slowmoving,aimless,movie,distressed,drifting,young,man
# [[0 0 0 ... 0 0 0]]

# %%
x_train #before
# Out:
# [['slowmoving', 'aimless', 'movie', 'distressed', 'drifting', 'young', 'man'],
#  ['sure',
#   'wa',
#   'lost',
#   'flat',
#   'character',
#   'audience',
#   'nearly',
#   'half',
#   'walked'],
#  ['attempting',
#   'artiness',
#   'black',
#   'white',
#   'clever',
#   'camera',
#   'angle',
#   'movie',
#   'disappointed',
#   'became',
#   'even',
#   'ridiculous',
#   'acting',
#   'wa',
#   'poor',
#   'plot',
#   'line',
#   'almost',
#   'nonexistent'],
#  ['little', 'music', 'anything', 'speak'],
#  ['best',
#   'scene',
#   'movie',
#   'wa',
#   'gerardo',
#   'trying',
#   'find',
#   'song',
#   'keep',
#   'running',
#   'head'],
#  ['rest',
#   'movie',
#   'lack',
#   'art',
#   'charm',
#   'meaning',
#   's',
#   'emptiness',
#   'work',
#   'guess',
#   's',
#   'empty'],
#  ['wasted', 'two', 'hour'],
#  ['saw',
#   'movie',
#   'today',
#   'thought',
#   'wa',
#   'good',
#   'effort',
#   'good',
#   'message',
#   'kid'],
#  ['bit', 'predictable'],
#  ['loved', 'casting', 'jimmy', 'buffet', 'science', 'teacher'],
#  ['baby', 'owl', 'adorable'],
#  ['movie',
#   'showed',
#   'lot',
#   'florida',
#   's',
#   'best',
#   'made',
#   'look',
#   'appealing'],
#  ['song', 'best', 'muppets', 'hilarious'],
#  ['wa', 'cool'],
#  ['right',
#   'case',
#   'movie',
#   'delivers',
#   'everything',
#   'almost',
#   'right',
#   'face'],
#  ['average',
#   'acting',
#   'main',
#   'person',
#   'wa',
#   'low',
#   'budget',
#   'clearly',
#   'see'],
#  ['review',
#   'long',
#   'overdue',
#   'since',
#   'consider',
#   'tale',
#   'two',
#   'sister',
#   'single',
#   'greatest',
#   'film',
#   'ever',
#   'made'],
#  ['ll',
#   'put',
#   'gem',
#   'movie',
#   'term',
#   'screenplay',
#   'cinematography',
#   'acting',
#   'postproduction',
#   'editing',
#   'directing',
#   'aspect',
#   'filmmaking'],
#  ['s',
#   'practically',
#   'perfect',
#   '\x96',
#   'true',
#   'masterpiece',
#   'sea',
#   'faux',
#   'masterpiece'],
#  ['structure',
#   'film',
#   'easily',
#   'tightly',
#   'constructed',
#   'history',
#   'cinema',
#   '1',
#   'think',
#   'film',
#   'something',
#   'vitally',
#   'important',
#   'occurs',
#   'every',
#   'minute',
#   '1',
#   'word',
#   'content',
#   'level',
#   'film',
#   'enough',
#   'easily',
#   'fill',
#   'dozen',
#   'film',
#   '1',
#   'anyone',
#   'right',
#   'mind',
#   'ask',
#   'anything',
#   'movie',
#   '1',
#   's',
#   'quite',
#   'simply',
#   'highest',
#   'superlative',
#   'form',
#   'cinema',
#   'imaginable',
#   '1',
#   'yes',
#   'film',
#   'doe',
#   'require',
#   'rather',
#   'significant',
#   'amount',
#   'puzzlesolving',
#   'piece',
#   'fit',
#   'together',
#   'create',
#   'beautiful',
#   'picture',
#   '1',
#   'short',
#   'film',
#   'certainly',
#   'pull',
#   'punch',
#   '0',
#   'graphic',
#   'far',
#   'best',
#   'part',
#   'game',
#   '0',
#   'number',
#   'one',
#   'best',
#   'th',
#   'game',
#   'series',
#   '1',
#   'deserves',
#   'strong',
#   'love',
#   '1',
#   'insane',
#   'game',
#   '1',
#   'massive',
#   'level',
#   'massive',
#   'unlockable',
#   'character',
#   's',
#   'massive',
#   'game',
#   '1',
#   'waste',
#   'money',
#   'game',
#   '1',
#   'kind',
#   'money',
#   'wasted',
#   'properly',
#   '1',
#   'actually',
#   'graphic',
#   'good',
#   'time',
#   '1',
#   'today',
#   'graphic',
#   'crap',
#   '0',
#   'say',
#   'canada',
#   'fun',
#   'game',
#   'aye',
#   '1',
#   'game',
#   'rock',
#   '1',
#   'buy',
#   'play',
#   'enjoy',
#   'love',
#   '1',
#   's',
#   'pure',
#   'brilliance',
#   '1',
#   'wa',
#   'flick',
#   'doomed',
#   'conception',
#   '0',
#   'idea',
#   'wa',
#   'lame',
#   'take',
#   'minor',
#   'character',
#   'mediocre',
#   'pg13',
#   'film',
#   'make',
#   'complete',
#   'nonsequel',
#   'changing',
#   'tone',
#   'pgrated',
#   'family',
#   'movie',
#   '0',
#   'wa',
#   'nt',
#   'least',
#   'bit',
#   'interested',
#   '0',
#   'confirm',
#   'film',
#   'would',
#   'unfunny',
#   'generic',
#   'also',
#   'managed',
#   'give',
#   'away',
#   'entire',
#   'movie',
#   'm',
#   'exaggerating',
#   'every',
#   'moment',
#   'every',
#   'plot',
#   'point',
#   'every',
#   'joke',
#   'told',
#   'trailer',
#   '0',
#   's',
#   'funny',
#   '0',
#   'even',
#   'talented',
#   'carrell',
#   'ca',
#   'nt',
#   'save',
#   '0',
#   'costar',
#   'nt',
#   'fare',
#   'much',
#   'better',
#   'people',
#   'like',
#   'morgan',
#   'freeman',
#   'jonah',
#   'hill',
#   'ed',
#   'helm',
#   'wasted',
#   '0',
#   'story',
#   'predictable',
#   'lazy',
#   '0',
#   'real',
#   'effect',
#   'work',
#   'presence',
#   'animal',
#   'integration',
#   'scene',
#   'worst',
#   'obvious',
#   'bluegreenscreen',
#   'work',
#   've',
#   'ever',
#   'seen',
#   '0',
#   'whatever',
#   'wa',
#   'cost',
#   'much',
#   'nt',
#   'translate',
#   'quality',
#   's',
#   'sure',
#   '0',
#   'film',
#   'succeeds',
#   'despite',
#   'perhaps',
#   'obviously',
#   'meagre',
#   'budget',
#   '1',
#   'm',
#   'glad',
#   'film',
#   'nt',
#   'go',
#   'obvious',
#   'choice',
#   'lesser',
#   'film',
#   'certainly',
#   'would',
#   '1',
#   'addition',
#   'one',
#   'lovely',
#   'song',
#   'ever',
#   'written',
#   'french',
#   'cancan',
#   'also',
#   'boast',
#   'one',
#   'cutest',
#   'leading',
#   'lady',
#   'ever',
#   'grace',
#   'screen',
#   '1',
#   's',
#   'hard',
#   'fall',
#   'headoverheels',
#   'love',
#   'girl',
#   '1',
#   'negative',
#   's',
#   'insipid',
#   'enough',
#   'cause',
#   'regret',
#   'another',
#   '2',
#   'hour',
#   'life',
#   'wasted',
#   'front',
#   'screen',
#   '0',
#   'long',
#   'whiny',
#   'pointless',
#   '0',
#   'recommend',
#   'waiting',
#   'future',
#   'effort',
#   'let',
#   'one',
#   'go',
#   '0',
#   'excellent',
#   'cast',
#   'story',
#   'line',
#   'performance',
#   '1',
#   'totally',
#   'believable',
#   '1',
#   'anne',
#   'heche',
#   'wa',
#   'utterly',
#   'convincing',
#   '1',
#   'sam',
#   'shepard',
#   's',
#   'portrayal',
#   'gung',
#   'ho',
#   'marine',
#   'wa',
#   'sobering',
#   '1',
#   'sat',
#   'riveted',
#   'tv',
#   'screen',
#   '1',
#   'give',
#   'one',
#   'resounding',
#   '9',
#   '10',
#   '1',
#   'think',
#   'tom',
#   'hank',
#   'good',
#   'actor',
#   '1',
#   'enjoyed',
#   'reading',
#   'book',
#   'child',
#   'little',
#   '1',
#   'wa',
#   'disappointed',
#   'movie',
#   '0',
#   'one',
#   'character',
#   'totally',
#   'annoying',
#   'voice',
#   'give',
#   'feeling',
#   'fingernail',
#   'chalkboard',
#   '0',
#   'totally',
#   'unnecessary',
#   'trainroller',
#   'coaster',
#   'scene',
#   '0',
#   'wa',
#   'absolutely',
#   'warmth',
#   'charm',
#   'scene',
#   'character',
#   '0',
#   'movie',
#   'totally',
#   'grate',
#   'nerve',
#   '0',
#   'performance',
#   'improved',
#   'improvisation',
#   'actor',
#   'twice',
#   'much',
#   'worry',
#   'whether',
#   're',
#   'delivering',
#   'line',
#   'well',
#   'whether',
#   'line',
#   'good',
#   '0',
#   'quite',
#   'honestly',
#   'often',
#   'good',
#   '0',
#   'often',
#   'dialogue',
#   'doe',
#   'nt',
#   'really',
#   'follow',
#   'one',
#   'line',
#   'another',
#   'fit',
#   'surroundings',
#   '0',
#   'crackle',
#   'unpredictable',
#   'youthful',
#   'energy',
#   'honestly',
#   'found',
#   'hard',
#   'follow',
#   'concentrate',
#   'meander',
#   'badly',
#   '0',
#   'generally',
#   'great',
#   'thing',
#   '1',
#   'would',
#   'nt',
#   'say',
#   're',
#   'worth',
#   '2',
#   'hour',
#   'time',
#   'though',
#   '0',
#   'suspense',
#   'builder',
#   'good',
#   'cross',
#   'line',
#   'g',
#   'pg',
#   '1',
#   'especially',
#   'liked',
#   'noncliche',
#   'choice',
#   'parent',
#   'movie',
#   'could',
#   'predict',
#   'dialog',
#   'verbatim',
#   'writing',
#   'movie',
#   'made',
#   'better',
#   'selection',
#   '1',
#   'want',
#   'movie',
#   's',
#   'gross',
#   'give',
#   'chill',
#   'great',
#   'choice',
#   '1',
#   'alexander',
#   'nevsky',
#   'great',
#   'film',
#   '1',
#   'amazing',
#   'film',
#   'artist',
#   'one',
#   'important',
#   'whoever',
#   'lived',
#   '1',
#   'm',
#   'glad',
#   'pretentious',
#   'piece',
#   'nt',
#   'planned',
#   'dodge',
#   'stratus',
#   'big',
#   'shot',
#   's',
#   'gon',
#   'na',
#   'help',
#   'movie',
#   'maker',
#   'nt',
#   'restrained',
#   'movie',
#   'business',
#   'québec'],
#  ['first', 'movie', 've', 'given', '10', 'year'],
#  ['wa', 'ever', 'movie', 'needed', 'wordofmouth', 'promote'],
#  ['overall', 'film', 'interesting', 'thoughtprovoking'],
#  ['plus', 'wa', 'wellpaced', 'suited', 'relatively', 'short', 'run', 'time'],
#  ['give', 'one', 'look'],
#  ['gave', '10'],
#  ['wind', 'lion', 'well', 'written', 'superbly', 'acted'],
#  ['true', 'classic'],
#  ['actually',
#   'turned',
#   'pretty',
#   'decent',
#   'far',
#   'blist',
#   'horrorsuspense',
#   'film',
#   'go'],
#  ['definitely', 'worth', 'checking'],
#  ['problem', 'wa', 'script'],
#  ['wa', 'horrendous'],
#  ['wa', 'nothing', 'believable'],
#  ['suspense', 'wa', 'feeling', 'wa', 'frustration', 'retarded', 'girl'],
#  ['manna',
#   'heaven',
#   'terrific',
#   'film',
#   'predictable',
#   'unpredictable',
#   'time'],
#  ['scene',
#   'often',
#   'funny',
#   'occasionally',
#   'touching',
#   'character',
#   'evaluate',
#   'life',
#   'going'],
#  ['cast', 'veteran', 'actor', 'nostalgia', 'trip'],
#  ['ursula',
#   'burton',
#   's',
#   'portrayal',
#   'nun',
#   'touching',
#   'funny',
#   'time',
#   'making',
#   'fun',
#   'nun',
#   'church'],
#  ['looking',
#   'movie',
#   'terrific',
#   'cast',
#   'good',
#   'music',
#   'including',
#   'shirley',
#   'jones',
#   'rendition',
#   'way',
#   'look',
#   'tonight',
#   'uplifting',
#   'ending',
#   'give',
#   'one',
#   'try'],
#  ['nt', 'think', 'disappointed'],
#  ['frankly',
#   'cotton',
#   'club',
#   'unfaithful',
#   'wa',
#   'kind',
#   'embarrassing',
#   'watch',
#   'lane',
#   'gere',
#   'film',
#   'bad'],
#  ['acting', 'wa', 'bad', 'dialog', 'extremely', 'shallow', 'insincere'],
#  ['wa', 'predictable', 'even', 'chick', 'flick'],
#  ['politically', 'correct'],
#  ['disappointing'],
#  ['thing',
#   'really',
#   'worth',
#   'watching',
#   'wa',
#   'scenery',
#   'house',
#   'beautiful'],
#  ['love', 'lane', 've', 'never', 'seen', 'movie', 'lousy'],
#  ['hour', 'half', 'wish', 'could', 'bring', 'back'],
#  ['term', 'writing', 's', 'fresh', 'bold'],
#  ['acting',
#   'help',
#   'writing',
#   'along',
#   'well',
#   'maybe',
#   'idiotsavant',
#   'sister',
#   'could',
#   'played',
#   'better',
#   'real',
#   'joy',
#   'watch'],
#  ['directing', 'cinematography', 'nt', 'quite', 'good'],
#  ['movie',
#   'wa',
#   'boring',
#   'sometimes',
#   'found',
#   'occupied',
#   'peaking',
#   'paper',
#   'instead',
#   'watching',
#   'never',
#   'happened',
#   'columbo',
#   'movie'],
#  ['sometimes', 'wa', 'embarrassing', 'look', 'away'],
#  ['directing', 'seems', 'pretentious'],
#  ['scene', 'ohsomature', 'neighbourgirl', 'misplace'],
#  ['generally', 'line', 'plot', 'weaker', 'average', 'episode'],
#  ['scene',
#   'debated',
#   'whether',
#   'sack',
#   'trumpeter',
#   'falsely',
#   'wa',
#   'accused',
#   'murder',
#   'pure',
#   'horror',
#   'really',
#   'stupid'],
#  ['applause', 'given', 'prelude', 'however'],
#  ['really', 'liked'],
#  ['great', 'film', 'great', 'director'],
#  ['movie',
#   'edge',
#   'seat',
#   'made',
#   'somewhat',
#   'afraid',
#   'go',
#   'car',
#   'end',
#   'night'],
#  ['music', 'film', 'really', 'nice'],
#  ['d', 'advise', 'anyone', 'go', 'see'],
#  ['brilliant'],
#  ['1010'],
#  ['liked', 'movie', 'way', 'much'],
#  ['problem',
#   'thought',
#   'actor',
#   'playing',
#   'villain',
#   'wa',
#   'low',
#   'rent',
#   'michael',
#   'ironside'],
#  ['rocked',
#   'world',
#   'certainly',
#   'must',
#   'see',
#   'anyone',
#   'social',
#   'physical',
#   'outlet'],
#  ['however',
#   'nt',
#   'make',
#   'fact',
#   'overall',
#   'wa',
#   'tremendously',
#   'boring',
#   'movie'],
#  ['wa',
#   'chemistry',
#   'ben',
#   'affleck',
#   'sandra',
#   'bullock',
#   'film',
#   'could',
#   'nt',
#   'understand',
#   'would',
#   'consider',
#   'even',
#   'leaving',
#   'wifetobe',
#   'chick',
#   'supposedly',
#   'wa',
#   'knocked'],
#  ['several',
#   'moment',
#   'movie',
#   'nt',
#   'need',
#   'excruciatingly',
#   'slow',
#   'moving'],
#  ['wa', 'poor', 'remake', 'best', 'friend', 'wedding'],
#  ['great', 'disappointment'],
#  ['believe', 'actor', 'agreed', 'film'],
#  ['could', 'stand', 'even', 'watch', 'long', 'fear', 'losing', 'iq'],
#  ['guess', 'nobody', 'network', 'aired', 'dribble', 'watched', 'putting'],
#  ['imdb',
#   'rating',
#   'go',
#   'low',
#   '1',
#   'awful',
#   's',
#   'time',
#   'get',
#   'negative',
#   'number',
#   'case'],
#  ['saw', 'mirrormask', 'last', 'night', 'wa', 'unsatisfactory', 'experience'],
#  ['unfortunately',
#   'inexperience',
#   'direction',
#   'meant',
#   'scene',
#   'scene',
#   'passed',
#   'little',
#   'way',
#   'dramatic',
#   'tension',
#   'conflict'],
#  ['central',
#   'theme',
#   'film',
#   'handled',
#   'ineptly',
#   'stereotypically',
#   'depth',
#   'imagination'],
#  ['pretty', 'picture', 'world', 'make', 'piece', 'work', 'flawed', 'core'],
#  ['hour',
#   'half',
#   'waste',
#   'time',
#   'following',
#   'bunch',
#   'pretty',
#   'high',
#   'schoolers',
#   'whine',
#   'cry',
#   'life'],
#  ['ca', 'nt', 'relate', 'hell', 'barely', 'understand'],
#  ['definitely',
#   'cult',
#   'classic',
#   'well',
#   'worth',
#   'viewing',
#   'sharing',
#   'others'],
#  ['movie',
#   'pure',
#   'disaster',
#   'story',
#   'stupid',
#   'editing',
#   'worst',
#   'seen',
#   'confuses',
#   'incredibly'],
#  ['fish',
#   'badly',
#   'made',
#   'underwater',
#   'shot',
#   'repeated',
#   'thousand',
#   'time',
#   'film'],
#  ['truly', 'truly', 'bad', 'film'],
#  ['acting', 'terrible', 'writing', 'worse'],
#  ['possible', 'way', 'movie', 'could', 'redeemed', 'would', 'mst3k', 'fodder'],
#  ['paid', 'much'],
#  ['also',
#   's',
#   'real',
#   'treat',
#   'see',
#   'anthony',
#   'quinn',
#   'playing',
#   'crazy',
#   'horse'],
#  ['wa', 'boring'],
#  ['plot', 'whatsoever'],
#  ['plot'],
#  ['horrible'],
#  ['worst', 'hour', 'half', 'life', 'oh', 'gosh'],
#  ['walk', 'theatre', 'minute', 'get', 'relief'],
#  ['hate', 'movie', 'like'],
#  ['yeah', 'movie', 'pretty', 'much', 'sucked'],
#  ['plot', 'storyline'],
#  ['go',
#   'see',
#   'movie',
#   'bring',
#   'pillow',
#   'girlfriendboyfriend',
#   'keep',
#   'occupied'],
#  ['awful'],
#  ['nt', 'think', 've', 'ever', 'gone', 'movie', 'disliked', 'much'],
#  ['wa',
#   'good',
#   'thing',
#   'ticket',
#   'cost',
#   'five',
#   'dollar',
#   'would',
#   'mad',
#   'd',
#   'paid',
#   '750',
#   'see',
#   'crap'],
#  ['nobody',
#   'identifies',
#   'character',
#   're',
#   'cardboard',
#   'cutout',
#   'stereotype',
#   'predictably',
#   'reversestereotypes'],
#  ['bad',
#   'film',
#   'bad',
#   'writing',
#   'good',
#   'actor',
#   'ugly',
#   'cartoon',
#   'crafted',
#   'paul',
#   'haggis',
#   'people',
#   'ca',
#   'nt',
#   'handle',
#   'anything',
#   'bold',
#   'stroke',
#   'storytelling',
#   'picture',
#   'painted',
#   'crayon'],
#  ['crash',
#   'depressing',
#   'little',
#   'nothing',
#   'provokes',
#   'emotion',
#   'teach',
#   'nothing',
#   'already',
#   'know',
#   'racism',
#   'prejudice',
#   'bad',
#   'thing'],
#  ['still',
#   'like',
#   'movie',
#   's',
#   'empowerment',
#   'woman',
#   's',
#   'enough',
#   'movie',
#   'like',
#   'one'],
#  ['brain',
#   'attempt',
#   'shutdown',
#   'part',
#   'primal',
#   'impulse',
#   'selfpreservation'],
#  ['wa',
#   'left',
#   'shattered',
#   'experience',
#   'watching',
#   'film',
#   'took',
#   'good',
#   'two',
#   'hour',
#   'fully',
#   'recover'],
#  ['movie',
#   'join',
#   'revenge',
#   'boogeyman',
#   'zombiez',
#   'part',
#   'hellish',
#   'trinity',
#   'horror',
#   'film'],
#  ['certainly', 'mean', 'distinction', 'good', 'way'],
#  ['mean', 'terrible', 'way'],
#  ['film', 'ha', 'redeeming', 'feature'],
#  ['everything', 'appalling'],
#  ['artless',
#   'camerawork',
#   'endlessly',
#   'present',
#   'u',
#   'ugliest',
#   'setting',
#   'imaginable',
#   'ie'],
#  ['story', 'beyond', 'stupid'],
#  ['script', 'wa', 'script'],
#  ['kid', 'annoying'],
#  ['lead', 'man', 'charismafree'],
#  ['utterly', 'without', 'merit', 'level', 'akin', 'torture'],
#  ['ll', 'even', 'say', '\x96', 'torture'],
#  ['maybe', 'would', 'reasonable', 'explanation', 'atrocity'],
#  ['pleasant', 'voyage', 'selfdiscovery'],
#  ['highly', 'unrecommended'],
#  ['premise', 'sound', 'stupid', 's'],
#  ['yes', 's', 'bad'],
#  ['nothing', 'recommend'],
#  ['excellent', 'performance'],
#  ['garbo',
#   'showed',
#   'right',
#   'bat',
#   'talent',
#   'could',
#   'carry',
#   'silent',
#   'era',
#   'wanted',
#   'see',
#   'silent',
#   'work',
#   'netflix',
#   'doe',
#   'nt',
#   'seem',
#   'stocking'],
#  ['s',
#   'also',
#   'great',
#   'see',
#   'renowned',
#   'silent',
#   'screenwriter',
#   'france',
#   'marion',
#   'ha',
#   'nt',
#   'missed',
#   'step',
#   'going',
#   'silent',
#   'sound'],
#  ['movie', 'suffered', 'writing', 'needed', 'suspense'],
#  ['many', 'close', 'ups'],
#  ['movie', 'seemed', 'drag', 'hero', 'nt', 'really', 'work', 'freedom'],
#  ['movie', 'definitely', 'average', 'rent'],
#  ['ll',
#   'love',
#   '1',
#   'movie',
#   'bad',
#   '0',
#   'bad',
#   '0',
#   'film',
#   'way',
#   'long',
#   '0',
#   'definitely',
#   'one',
#   'bad',
#   'one',
#   '0',
#   'movie',
#   'received',
#   'wa',
#   'great',
#   'quality',
#   'film',
#   's',
#   'age',
#   '1',
#   'john',
#   'wayne',
#   'incredible',
#   'job',
#   'young',
#   'movie',
#   'industry',
#   '1',
#   'screen',
#   'presence',
#   'shined',
#   'thought',
#   'even',
#   'though',
#   'senior',
#   'actor',
#   'screen',
#   '1',
#   'think',
#   'must',
#   'see',
#   'older',
#   'john',
#   'wayne',
#   'film',
#   '1',
#   'really',
#   'nt',
#   'see',
#   'anyone',
#   'could',
#   'enjoy',
#   'movie',
#   '0',
#   'nt',
#   'think',
#   've',
#   'ever',
#   'seen',
#   'movie',
#   'half',
#   'boring',
#   'selfindulgent',
#   'piece',
#   'junk',
#   '0',
#   'probably',
#   'would',
#   'better',
#   'director',
#   'nt',
#   'spent',
#   'movie',
#   'showcasing',
#   'art',
#   'work',
#   'really',
#   'nt',
#   'noteworthy',
#   '0',
#   'another',
#   'thing',
#   'nt',
#   'really',
#   'like',
#   'character',
#   'got',
#   'punched',
#   'face',
#   'gallon',
#   'blood',
#   'would',
#   'spew',
#   'forth',
#   'soon',
#   '0',
#   'jamie',
#   'foxx',
#   'absolutely',
#   'ray',
#   'charles',
#   '1',
#   'performance',
#   'simply',
#   'genius',
#   '1',
#   'owns',
#   'film',
#   'spacek',
#   'owned',
#   'coal',
#   'miner',
#   's',
#   'daughter',
#   'quaid',
#   'owned',
#   'great',
#   'ball',
#   'fire'],
#  ['fact',
#   's',
#   'hard',
#   'remember',
#   'part',
#   'ray',
#   'charles',
#   'acted',
#   'played',
#   'man',
#   '1',
#   'ray',
#   'charles',
#   'legendary',
#   '1',
#   'ray',
#   'charles',
#   'life',
#   'provided',
#   'excellent',
#   'biographical',
#   'material',
#   'film',
#   'go',
#   'well',
#   'beyond',
#   'another',
#   'movie',
#   'musician',
#   '1',
#   'hitchcock',
#   'great',
#   'director',
#   '1',
#   'ironically',
#   'mostly',
#   'find',
#   'film',
#   'total',
#   'waste',
#   'time',
#   'watch',
#   '0',
#   'secondly',
#   'hitchcock',
#   'pretty',
#   'much',
#   'perfected',
#   'thriller',
#   'chase',
#   'movie',
#   '1',
#   's',
#   'pandering',
#   'audience',
#   'sabotage',
#   'film',
#   '0',
#   'hence',
#   'whole',
#   'story',
#   'lack',
#   'certain',
#   'energy',
#   '0',
#   'plot',
#   'simply',
#   'rumble',
#   'like',
#   'machine',
#   'desperately',
#   'depending',
#   'addition',
#   'new',
#   'scene',
#   '0',
#   'usual',
#   'hitchcock',
#   'logic',
#   'flaw',
#   '0',
#   'mishima',
#   'extremely',
#   'uninteresting',
#   '0',
#   'chilly',
#   'unremarkable',
#   'movie',
#   'author',
#   'livingworking',
#   'chilly',
#   'abstruse',
#   'culture',
#   '0',
#   'flat',
#   'reenactment',
#   'nt',
#   'hold',
#   'attention',
#   'emotionally',
#   'adrift',
#   'stagy',
#   '0',
#   'rest',
#   'sits',
#   'awful',
#   'soldier',
#   'singing',
#   'song',
#   'masculinity',
#   'pledge',
#   'hairsplitting',
#   'purity',
#   'admiration',
#   'sword',
#   'etc',
#   '0',
#   'bore',
#   'piece',
#   'kill',
#   'momentum',
#   'movie',
#   'quicker',
#   'anyone',
#   'else',
#   '0',
#   'schrader',
#   'ha',
#   'made',
#   'resume',
#   'full',
#   'lousy',
#   'amateurish',
#   'film',
#   '0',
#   'first',
#   'watched',
#   'movie',
#   '80',
#   'loved',
#   '1',
#   'wa',
#   'totally',
#   'fascinated',
#   'music',
#   'dancing',
#   'everything',
#   '1',
#   'however',
#   'recently',
#   'watched',
#   'whole',
#   'thing',
#   'dvd',
#   'wa',
#   'completely',
#   'struck',
#   'extremely',
#   'stupid',
#   'storyline',
#   'wa',
#   'contained',
#   'hole',
#   'inconsistency',
#   'frankly',
#   'whole',
#   'lot',
#   'crap',
#   'horrid',
#   'dancing',
#   'wa',
#   '0',
#   'mean',
#   'realistic',
#   'world',
#   'would',
#   'never',
#   'gotten',
#   'ballet',
#   'repertory',
#   'whole',
#   'thing',
#   'wa',
#   'quite',
#   'pathetic',
#   '0',
#   'character',
#   'development',
#   'also',
#   'lacked',
#   'depth',
#   '0',
#   'woa',
#   'talk',
#   'awful',
#   '0',
#   'waste',
#   'time',
#   '0',
#   'wa',
#   'horrible',
#   '0',
#   'worst',
#   'sappiest',
#   'dialogue',
#   'could',
#   'go',
#   '0',
#   'really',
#   'made',
#   'unwatchable',
#   'wa',
#   'direction',
#   '0',
#   'poor',
#   'actor',
#   '0',
#   'ca',
#   'nt',
#   'even',
#   'tell',
#   'talent',
#   'pathetic',
#   'line',
#   'speak',
#   'director',
#   'gave',
#   'action',
#   '0',
#   'check',
#   'director',
#   's',
#   'filmography',
#   'site',
#   'see',
#   'film',
#   'nt',
#   'chance',
#   '0',
#   'would',
#   'even',
#   'good',
#   'made',
#   'tv',
#   'flick',
#   '0',
#   'good',
#   'intention',
#   'made',
#   'film',
#   'great',
#   'film',
#   'might',
#   'one',
#   'greatest',
#   'film',
#   'ever',
#   'made',
#   '1',
#   'film',
#   'ha',
#   'great',
#   'actor',
#   'master',
#   'director',
#   'significant',
#   'theme',
#   'least',
#   'wouldbe',
#   'significant',
#   'theme',
#   'undertone',
#   'fifty',
#   'existential',
#   'worldweariness',
#   'aerial',
#   'scene',
#   'ought',
#   'thrilled',
#   'sens',
#   'imagination',
#   'character',
#   'one',
#   'might',
#   'deeply',
#   'care',
#   '1',
#   'regrettably',
#   'film',
#   'fails',
#   '0',
#   'movie',
#   'lack',
#   'visual',
#   'interest',
#   'drama',
#   'expression',
#   'feeling',
#   'celebration',
#   'patriotism',
#   'underline',
#   'narrative',
#   '0',
#   'actress',
#   'ha',
#   'worse',
#   'used',
#   'june',
#   'allison',
#   'movie',
#   '0',
#   'yet',
#   'enjoy',
#   'watching',
#   '1',
#   'unfortunately',
#   'bad',
#   'movie',
#   'plain',
#   'bad',
#   '0',
#   'bad',
#   'script',
#   'bad',
#   'direction',
#   'horrible',
#   'acting',
#   'make',
#   'one',
#   'plain',
#   'bad',
#   '0',
#   'dialogue',
#   'sucked',
#   '0',
#   'cinematographyif',
#   'called',
#   'thatsucked',
#   '0',
#   'soundtrack',
#   'sucked',
#   '0',
#   'acting',
#   'sucked',
#   '0',
#   'concert',
#   'sequence',
#   'sucked',
#   '0',
#   'wa',
#   'nice',
#   '1',
#   'wa',
#   'funny',
#   '1',
#   'wa',
#   'funny',
#   '1',
#   'overall',
#   'movie',
#   'wa',
#   'cheap',
#   'trash',
#   '0',
#   'movie',
#   'funny',
#   'considering',
#   'ridiculousness',
#   '0',
#   'came',
#   'feeling',
#   'angry',
#   '0',
#   'spoiler',
#   'whatever',
#   'else',
#   'ca',
#   'nt',
#   'said',
#   'surface',
#   'superbly',
#   'crafted',
#   '1',
#   'cinematography',
#   'simply',
#   'stunning',
#   'say',
#   'least',
#   'fx',
#   'nothing',
#   'stateoftheart',
#   '1',
#   'conceptually',
#   'show',
#   'offer',
#   'little',
#   'bit',
#   'everything',
#   'everybody',
#   'parent',
#   'kid',
#   'fantasy',
#   'andor',
#   'fx',
#   'fan',
#   '1',
#   'wa',
#   'nt',
#   'single',
#   'sour',
#   'note',
#   'struck',
#   'actingwise',
#   'either',
#   'surprisingly',
#   'solid',
#   'casting',
#   '1',
#   'thing',
#   'considered',
#   'job',
#   'well',
#   'done',
#   '1',
#   'thanks',
#   'good',
#   'movie',
#   'like',
#   'wa',
#   'done',
#   'released',
#   '1',
#   'one',
#   'best',
#   'mexican',
#   'movie',
#   'ever',
#   'one',
#   'le',
#   'understood',
#   'even',
#   'mexican',
#   'matter',
#   'identified',
#   'felt',
#   '1',
#   'rank',
#   'highly',
#   'great',
#   'noircrimedrama',
#   'incredible',
#   'performance',
#   'belmondo',
#   'lino',
#   'ventura',
#   '1',
#   'attention',
#   'given',
#   'every',
#   'character',
#   'complex',
#   'psychological',
#   'portrayal',
#   'detailing',
#   'loyalty',
#   'treachery',
#   'love',
#   'hope',
#   'tremendous',
#   '1',
#   'excellent',
#   'drama',
#   'excellent',
#   'thriller',
#   'excellent',
#   'film',
#   '1',
#   'best',
#   'melville',
#   '1',
#   'everything',
#   'film',
#   'simply',
#   'incredible',
#   '1',
#   'truly',
#   'take',
#   'journey',
#   'eye',
#   'soul',
#   'child',
#   '1',
#   'black',
#   'water',
#   'thriller',
#   'manages',
#   'completely',
#   'transcend',
#   's',
#   'limitation',
#   's',
#   'indie',
#   'flick',
#   'continually',
#   'subverting',
#   'expectation',
#   'emerge',
#   'intense',
#   'experience',
#   '1',
#   'performance',
#   'real',
#   'gripping',
#   'crocdodile',
#   'extremely',
#   'well',
#   'done',
#   'indeed',
#   'black',
#   'water',
#   'website',
#   'believed',
#   's',
#   'used',
#   'real',
#   'crocs',
#   'swamp',
#   'location',
#   'fabulous',
#   '1',
#   'thoroughly',
#   'enjoyed',
#   'christopher',
#   'eccleston',
#   'took',
#   'control',
#   'tardis',
#   'continuation',
#   'series',
#   '1',
#   'm',
#   'sure',
#   'wa',
#   'trying',
#   'film',
#   '0',
#   'wa',
#   'turn',
#   'good',
#   'day',
#   'feeling',
#   'night',
#   'disturbing',
#   'memory',
#   'guess',
#   'succeeded',
#   '0',
#   'lot',
#   'beautiful',
#   'place',
#   '1',
#   'wa',
#   'forced',
#   'like',
#   'everything',
#   'movie',
#   '0',
#   'lame',
#   '0',
#   's',
#   'movie',
#   'really',
#   'pi',
#   'ed',
#   '0',
#   'nt',
#   'even',
#   'get',
#   'started',
#   'jerky',
#   'camerawork',
#   '0',
#   'saw',
#   'theater',
#   'thought',
#   'wa',
#   'going',
#   'sick',
#   '0',
#   'summary',
#   'witticism',
#   'nt',
#   'witty',
#   '0',
#   'plot',
#   'well',
#   'said',
#   'd',
#   'let',
#   'one',
#   'go',
#   '0',
#   'acting',
#   'wa',
#   'bad',
#   '0',
#   'really',
#   'bad',
#   '0',
#   'even',
#   'billy',
#   'bob',
#   'could',
#   'nt',
#   'rise',
#   'script',
#   'wa',
#   'worse',
#   '0',
#   'camerawork',
#   'bad',
#   '0',
#   'rating',
#   '1',
#   '10',
#   '0',
#   'amazing',
#   'finale',
#   'possibly',
#   'best',
#   'trilogy',
#   'time',
#   '1',
#   'kieslowski',
#   'never',
#   'cease',
#   'amaze',
#   '1',
#   'one',
#   'favourite',
#   'director',
#   'one',
#   'talented',
#   'director',
#   'history',
#   'cinema',
#   '1',
#   'use',
#   'colour',
#   'french',
#   'flag',
#   'three',
#   'film',
#   'wa',
#   'nothing',
#   'short',
#   'incredible',
#   'every',
#   'shot',
#   'every',
#   'scene',
#   'wa',
#   'like',
#   'work',
#   'art',
#   '1',
#   'three',
#   'visually',
#   'appealing',
#   'movie',
#   've',
#   'ever',
#   'seen',
#   '1',
#   'subtle',
#   'connection',
#   'three',
#   'film',
#   'awesome',
#   '1',
#   'mention',
#   'huge',
#   'spoiler',
#   'loved',
#   'ending',
#   'character',
#   'three',
#   'film',
#   'remaining',
#   'survivor',
#   'ferry',
#   'disaster',
#   'valentine',
#   'young',
#   'judge',
#   'together',
#   'old',
#   'man',
#   'watching',
#   'tv',
#   'solidifying',
#   'happiness',
#   'suffering',
#   'dealt',
#   'many',
#   'year',
#   '1',
#   'could',
#   'nt',
#   'think',
#   'better',
#   'way',
#   'end',
#   'film',
#   'smile',
#   'face',
#   'great',
#   'way',
#   'wrap',
#   'amazing',
#   'film',
#   'trilogy',
#   '1',
#   'recommend',
#   'everyone',
#   'love',
#   'film',
#   'movie',
#   'anything',
#   'work',
#   'art',
#   '1',
#   '10',
#   '10',
#   'movie',
#   'trilogy',
#   '1',
#   'literally',
#   'vomited',
#   'watching',
#   'film',
#   '0',
#   'think',
#   'wa',
#   'one',
#   'people',
#   'found',
#   'another',
#   'one',
#   'roth',
#   's',
#   'pearl',
#   '1',
#   'performance',
#   'awarded',
#   'wa',
#   'stunning',
#   '1',
#   'story',
#   'wa',
#   'told',
#   'eloquently',
#   'francis',
#   'ford',
#   'coppola',
#   '25',
#   'year',
#   'earlier',
#   'really',
#   'unfolds',
#   'gradually',
#   'leaf',
#   'room',
#   'character',
#   'develop',
#   '1',
#   'wonderful',
#   'location',
#   'lie',
#   'story',
#   'contrast',
#   '1',
#   'beautiful',
#   'directed',
#   'film',
#   'nicola',
#   's',
#   'roeg',
#   'wih',
#   'sublime',
#   'cast',
#   '1',
#   'm',
#   'translating',
#   'movie',
#   'living',
#   'first',
#   'movie',
#   '5year',
#   'working',
#   'experience',
#   'found',
#   'offensive',
#   'intelligence',
#   '0',
#   'someone',
#   'strives',
#   'greatness',
#   'poetry',
#   'delivers',
#   'muddled',
#   'often',
#   'ridiculous',
#   'story',
#   'bunch',
#   'disparate',
#   'scene',
#   'pretentious',
#   'dialogue',
#   'get',
#   'worst',
#   'kind',
#   'movie',
#   'reviewer',
#   'accurately',
#   'defined',
#   'pretentious',
#   'crap'],
#  ['find',
#   'movie',
#   'intelligent',
#   'even',
#   'masterful',
#   'say',
#   's',
#   'intelligence',
#   'imagination',
#   'obviously',
#   'used',
#   'try',
#   'make',
#   'sense',
#   'pitiful',
#   'attempt',
#   's',
#   'human',
#   'nature',
#   'try',
#   'make',
#   'sense',
#   'thing'],
#  ['one',
#   'thing',
#   'tolerate',
#   'political',
#   'incorrectness',
#   'well',
#   'm',
#   'artistic',
#   'freedom',
#   'suspension',
#   'disbelief',
#   'slavic',
#   'female',
#   'character',
#   'wa',
#   'much'],
#  ['fun', 'funny', 'movie'],
#  ['highly', 'entertaining', 'angle'],
#  ['feature',
#   'outlandish',
#   'array',
#   'memorable',
#   'psychotic',
#   'lovable',
#   'nut'],
#  ['enjoyment', 'get', 'see', 'run', 'around', 'play', 'game', 'dangerous'],
#  ['even', 'ha', 'sweet', 'moment'],
#  ['telephone',
#   'repair',
#   'man',
#   'wa',
#   'really',
#   'funny',
#   'reaction',
#   'nut',
#   'bitchy',
#   'bos',
#   'truly',
#   'genuine'],
#  ['character', 'film', 'tremendously', 'well', 'played'],
#  ['really', 'find', 'funny'],
#  ['actually', 'smart', 'movie'],
#  ['brilliant', 'twist', 'ending'],
#  ['love',
#   '1',
#   'ending',
#   'perfect',
#   'll',
#   'shed',
#   'tear',
#   '1',
#   'thrilled',
#   'seeing',
#   'movie',
#   'like',
#   '1',
#   'never',
#   'forget',
#   '1',
#   'cult',
#   'cult',
#   'classic',
#   '1',
#   'ha',
#   'depth',
#   'character',
#   'man',
#   'underneath',
#   '0',
#   'malta',
#   'setting',
#   'dry',
#   'barren',
#   'dialogue',
#   '0',
#   'movie',
#   'terrible',
#   '0',
#   'hockey',
#   'scene',
#   'terrible',
#   'defensemen',
#   'playing',
#   'like',
#   're',
#   '5',
#   'year',
#   'old',
#   'goalie',
#   'diving',
#   'shot',
#   '10',
#   'foot',
#   'wide',
#   'net',
#   'etc',
#   '0',
#   'nt',
#   'seen',
#   'nt',
#   'waste',
#   'time',
#   '0',
#   'call',
#   'movie',
#   'drama',
#   'ridiculous',
#   '0',
#   'started',
#   'watching',
#   'nt',
#   'believe',
#   'character',
#   '0',
#   'particular',
#   'relationship',
#   'bakery',
#   'assistant',
#   'waitress',
#   'nt',
#   'work',
#   '0',
#   'wa',
#   'superficial',
#   'movie',
#   'gave',
#   'feeling',
#   'wa',
#   'watching',
#   'play',
#   'rather',
#   'film',
#   '0',
#   'character',
#   'stagey',
#   'storyline',
#   'wa',
#   'lot',
#   'like',
#   'stage',
#   'farce',
#   '0',
#   'time',
#   'pyromaniac',
#   'waylaid',
#   'assistant',
#   'wa',
#   'bored',
#   'nt',
#   'care',
#   'happened',
#   'next',
#   'switched',
#   '0',
#   'glad',
#   'nt',
#   'pay',
#   'see',
#   '0',
#   'nt',
#   'laugh',
#   'even',
#   'smile',
#   '0',
#   'wa',
#   'nt',
#   'anything',
#   'one',
#   'big',
#   'yawn',
#   '0',
#   'really',
#   'good',
#   'show',
#   'watch',
#   '1',
#   'educational',
#   'child',
#   '1',
#   '8',
#   'year',
#   'old',
#   '1',
#   'barney',
#   'definitely',
#   'super',
#   'de',
#   'duper',
#   '1',
#   'pretty',
#   'funny',
#   '1',
#   'babie',
#   'bop',
#   'cute',
#   '1',
#   'kid',
#   'cool',
#   '1',
#   'storm',
#   'trooper',
#   'even',
#   'bad',
#   'enough',
#   'make',
#   'list',
#   'wonderfully',
#   'terrible',
#   'movie'],
#  ['s', 'lame'],
#  ['guy', 'said', 's', 'better', 'dialogue', 'potted', 'plant', 'ha', 'right'],
#  ['everything', 'movie', 'stupid'],
#  ['even', 'love', 'bad', 'movie', 'watch', 'movie'],
#  ['shameful'],
#  ['would', 'give', 'television', 'series', '10', 'plus', 'could'],
#  ['writer',
#   'smack',
#   'think',
#   'best',
#   'actor',
#   'actress',
#   'bonus',
#   'showthese',
#   'character',
#   'real'],
#  ['must', 'say', 'taped', 'episode', 'find', 'watching'],
#  ['know', 'gave', '10'],
#  ['nt',
#   'know',
#   'exactly',
#   'movie',
#   'latched',
#   'endearing',
#   'movie',
#   'ha',
#   'become',
#   'special',
#   'part',
#   'family',
#   's',
#   'memory'],
#  ['totally',
#   'absolutely',
#   'recommend',
#   'movie',
#   'anyone',
#   'like',
#   'good',
#   'wholesome',
#   'family',
#   'movie',
#   'exactly'],
#  ['thing', 'four', 'kid', 'get', 'absolutely', 'hilarious', 'watch'],
#  ['one', 'best', 'movie', 'show', 'strong', 'sibling', 'bond'],
#  ['much',
#   'interesting',
#   'action',
#   'suspense',
#   'le',
#   'unneeded',
#   'controversy'],
#  ['everything', 'acting', 'cinematography', 'wa', 'solid'],
#  ['definitely', 'worth', 'checking'],
#  ['damian',
#   'talented',
#   'versatile',
#   'many',
#   'way',
#   'writing',
#   'portraying',
#   'different',
#   'character',
#   'screen'],
#  ['movie', 'ha', 'cutting', 'edge'],
#  ['pleased',
#   'know',
#   'modern',
#   'day',
#   'genius',
#   'letting',
#   'passion',
#   'art',
#   'drive',
#   'taking',
#   'u',
#   'audience'],
#  ['new', 'character', 'nt', 'memorable', 'found', 'forgetting', 'wa'],
#  ['felt', 'though', 'going', 'ireland', 'absolutely', 'nothing', 'whatsoever'],
#  ['nt',
#   'make',
#   'scared',
#   'horrified',
#   'make',
#   'sympathetic',
#   'towards',
#   'character',
#   'wa',
#   'simply',
#   'annoying'],
#  ['jerky', 'camera', 'movement', 'also', 'annoying'],
#  ['plot', 'wa', 'pretty', 'much', 'every', 'cheap', 'horror'],
#  ['wa',
#   'pathetic',
#   'attempt',
#   'give',
#   'character',
#   'depth',
#   'nt',
#   'really',
#   'work',
#   'rest',
#   'plot'],
#  ['guess',
#   'wa',
#   'supposed',
#   'clever',
#   'twist',
#   'shed',
#   'light',
#   'situation',
#   'wa',
#   'stupid'],
#  ['see', 'probably', 'leave', 'shelf'],
#  ['elia',
#   'koteas',
#   'jack',
#   'palance',
#   'play',
#   'good',
#   'role',
#   'angelina',
#   'hot',
#   'get',
#   'nakedbilly',
#   'drago',
#   'appears',
#   'cool',
#   'usual',
#   'cameo',
#   'sven',
#   'ole',
#   'thorsen',
#   'help',
#   'make',
#   'enjoyable',
#   'movie',
#   'good',
#   'acting',
#   'decent',
#   'budget'],
#  ['wa', 'awesome', 'movie', 'bought', 'ebay'],
#  ['really',
#   'loved',
#   'story',
#   'line',
#   'poler',
#   'bear',
#   'wa',
#   'kinda',
#   'cutebut',
#   'anyone',
#   'ha',
#   'question',
#   'fort',
#   'steele',
#   'ask',
#   'away'],
#  ['totally',
#   'unfunny',
#   'movie',
#   'top',
#   'pathetic',
#   'unrealistic',
#   'throughout',
#   'whole',
#   '90',
#   'minute',
#   'utter',
#   'torture',
#   'probably',
#   'looked',
#   'watch',
#   '70000',
#   'time'],
#  ['lucy',
#   'bell',
#   'much',
#   'higher',
#   'crap',
#   'sink',
#   'low',
#   'quite',
#   'depressing'],
#  ['movie',
#   'doe',
#   'make',
#   'sick',
#   'watching',
#   'slacker',
#   'make',
#   'excuse',
#   'stupid',
#   'action',
#   '90',
#   'minute'],
#  ['god', 'never', 'get', '90', 'minute', 'back'],
#  ['think',
#   'wonderful',
#   'part',
#   'literally',
#   'full',
#   'wonder',
#   'excerpt',
#   'work'],
#  ['set',
#   'especially',
#   'designed',
#   'work',
#   'camera',
#   'amazing',
#   'stylized',
#   'beautiful',
#   'effective'],
#  ['could', 'used', 'exemplar', 'set', 'designer'],
#  ['story', 'powerful', 'exploration', 'nature', 'man', 'art'],
#  ['watching', 'film', 'wanted', 'learn', 'work', 'artist'],
#  ['highly',
#   'recommend',
#   'movie',
#   'anyone',
#   'interested',
#   'art',
#   'poetry',
#   'theater',
#   'politics',
#   'japanese',
#   'history'],
#  ['wind',
#   'lion',
#   'see',
#   'wonderful',
#   'rendering',
#   'america',
#   's',
#   'imperial',
#   'age'],
#  ['make',
#   'story',
#   'different',
#   'terrific',
#   'production',
#   'value',
#   'faultless',
#   'photography',
#   'composition',
#   'editing',
#   'terrific',
#   'casting',
#   'underappreciated',
#   'brian',
#   'keith',
#   'playing',
#   'bully',
#   'teddy',
#   'vivid',
#   'history'],
#  ['though',
#   'wind',
#   'lion',
#   'told',
#   'largely',
#   'eye',
#   'son',
#   'every',
#   'member',
#   'family',
#   'identify',
#   'one',
#   'character',
#   'whether',
#   'sean',
#   'connery',
#   's',
#   'noble',
#   'brigand',
#   'candace',
#   'bergen',
#   's',
#   'feisty',
#   'heroine',
#   'john',
#   'huston',
#   's',
#   'wily',
#   'john',
#   'hay',
#   'steve',
#   'kanaly',
#   's',
#   'spiffy',
#   'radiant',
#   'ruthless',
#   'cando',
#   'lieutenant',
#   'roosevelt',
#   's',
#   'big',
#   'stick'],
#  ['high', 'adventure', 'best'],
#  ['think',
#   'wa',
#   'robert',
#   'ryans',
#   'best',
#   'film',
#   'portrayed',
#   'someone',
#   'like',
#   'father',
#   'wa',
#   'schizophrenic',
#   'real',
#   'life',
#   'father',
#   'although',
#   'never',
#   'murdered',
#   'anyone',
#   'wa',
#   'affected',
#   'second',
#   'world',
#   'war',
#   'made',
#   'worse'],
#  ['humour', 'get', 'get', 'day', 'wa', 'apt'],
#  ['mother',
#   'brother',
#   'saw',
#   'robert',
#   'ryan',
#   'portraying',
#   'type',
#   'man',
#   'wa',
#   'good',
#   'imitation',
#   'type',
#   'individual',
#   'wa',
#   'impressed'],
#  ['almost', 'song', 'cover', 'girl', 'oldfashioned', 'tuneful'],
#  ['annoying',
#   'thing',
#   'cover',
#   'girl',
#   'way',
#   'rita',
#   'hayworth',
#   'put',
#   'pedestal'],
#  ['unfortunately',
#   'cover',
#   'girl',
#   'example',
#   'hollywood',
#   'used',
#   'exploit',
#   'woman',
#   'financial',
#   'gain'],
#  ['nonlinear',
#   'narration',
#   'thus',
#   'many',
#   'flashback',
#   'every',
#   'part',
#   'articulated',
#   'quite',
#   'well'],
#  ['good',
#   'cinematography',
#   'also',
#   'make',
#   'monica',
#   'bellucci',
#   'look',
#   'beautiful'],
#  ['good',
#   'commentary',
#   'today',
#   's',
#   'love',
#   'undoubtedly',
#   'film',
#   'worth',
#   'seeing'],
#  ['people', 'first', 'timer', 'film', 'making', 'think', 'excellent', 'job'],
#  ['wa',
#   'popular',
#   'wa',
#   'cinema',
#   'good',
#   'house',
#   'good',
#   'reaction',
#   'plenty',
#   'laugh'],
#  ['s', 'feelgood', 'film', 's', 'felt', 'came', 'cinema'],
#  ['ha', 'northern', 'humour', 'positive', 'community', 'represents'],
#  ['rather', 'enjoyed'],
#  ['liked'],
#  ['could', 'nt', 'take', 'seriously'],
#  ['really', 'created', 'unique', 'feeling', 'though'],
#  ['vivian', 'schilling', 'excellent', 'job', 'script'],
#  ['world', 'better', '95', 'garbage', 'theatre', 'today'],
#  ['role', 'wa', 'played', 'well'],
#  ['screamy', 'masculine', 'right'],
#  ['camera', 'really', 'like', 'movie'],
#  ['would', 'casted', 'role', 'ready', 'script'],
#  ['european',
#   'movie',
#   'nice',
#   'throwback',
#   'time',
#   'student',
#   '1980',
#   's',
#   'experience',
#   'living',
#   'abroad',
#   'interacting',
#   'nationality',
#   'although',
#   'circumstance',
#   'slightly',
#   'different'],
#  ['fan', 'movie', 'sucked', 'really', 'bad'],
#  ['even', 'worse', 'ticker'],
#  ['movie', 'wa', 'bad'],
#  ['like',
#   '3',
#   '4',
#   'building',
#   'used',
#   'couple',
#   'location',
#   'maybe',
#   'poor',
#   'hummh'],
#  ['blew'],
#  ['movie',
#   'excellent',
#   'angel',
#   'beautiful',
#   'scamp',
#   'adorable',
#   'little',
#   'yelp',
#   'scared',
#   'funniest',
#   'part',
#   'scamp',
#   'caught',
#   'curtain',
#   'angel',
#   'scamp',
#   'singing',
#   'ive',
#   'never',
#   'feeling',
#   'beforei',
#   'totally',
#   'recommend',
#   'movie',
#   'coming',
#   'special',
#   'edition',
#   'june',
#   '20the',
#   'cover',
#   'ha',
#   'scamp',
#   'garbage',
#   'angel',
#   'underneath',
#   'lid'],
#  ['cant',
#   'explain',
#   'movie',
#   'romantic',
#   'charming',
#   'hilarious',
#   'adorablethe',
#   'junkyard',
#   'scene',
#   'funny',
#   'junkyard',
#   'dog',
#   'something',
#   'specialtoo',
#   'funny',
#   'laughed',
#   'kid',
#   'love',
#   'itbuy',
#   'come',
#   'ha',
#   'new',
#   'feature'],
#  ['chosen',
#   'tortured',
#   'disgusting',
#   'piece',
#   'blatant',
#   'american',
#   'propaganda'],
#  ['show',
#   'made',
#   'american',
#   'stupid',
#   'full',
#   'hatred',
#   'clichés',
#   'admitted',
#   'elsewhere'],
#  ['almost',
#   'everyone',
#   'involved',
#   'must',
#   'return',
#   'school',
#   'acting',
#   'utterly',
#   'predictable',
#   'bad',
#   'script',
#   'pile',
#   'garbage',
#   'round'],
#  ['wish', 'could', 'enter', 'negative', 'value', 'admins'],
#  ['set', 'bad', 'would', 'nt', 'look', 'place', 'thunderbird', 'episode'],
#  ['use',
#   'slowmotion',
#   'needlessly',
#   'repeat',
#   'throughout',
#   'movie',
#   'well',
#   'backed',
#   'bad',
#   'acting',
#   'bad',
#   'kind',
#   'word',
#   'continuity',
#   'scene',
#   'thrown',
#   'reason',
#   'whatsoever',
#   'vehicle',
#   'looked',
#   'like',
#   'made',
#   'corn',
#   'flake',
#   'box',
#   'directorial',
#   'style',
#   'bordered',
#   'stupidity'],
#  ['oh', 'yeah', 'storyline', 'wa', 'pathetic'],
#  ['hate',
#   'writing',
#   'bad',
#   'review',
#   'film',
#   'especially',
#   'really',
#   'like',
#   'star',
#   'film',
#   'bad',
#   'nt',
#   'believe',
#   'one',
#   'second',
#   'anyone',
#   'could',
#   'proud'],
#  ['filmmaker',
#   'director',
#   'would',
#   'hide',
#   'head',
#   'sand',
#   'd',
#   'spent',
#   'whatever',
#   'amount',
#   'money',
#   'time',
#   'movie'],
#  ['short',
#   'wa',
#   'monumental',
#   'waste',
#   'time',
#   'energy',
#   'would',
#   'recommend',
#   'anyone',
#   'ever',
#   'see',
#   'film'],
#  ['came',
#   'free',
#   'dvd',
#   'player',
#   'bought',
#   'still',
#   'turned',
#   'thing',
#   'halfway',
#   'wa',
#   'embarrassed',
#   'howell'],
#  ['110', 'setting', '010'],
#  ['interesting',
#   'premise',
#   'billy',
#   'drago',
#   'always',
#   'good',
#   'dangerous',
#   'nutbag',
#   'side',
#   'note',
#   'd',
#   'love',
#   'see',
#   'drago',
#   'stephen',
#   'mchattie',
#   'lance',
#   'hendrikson',
#   'flick',
#   'together',
#   'talk',
#   'raging',
#   'cheekbone'],
#  ['soundtrack', 'wa', 'nt', 'terrible', 'either'],
#  ['acting',
#   'even',
#   'professional',
#   'drago',
#   'debbie',
#   'rochon',
#   'wa',
#   'terrible',
#   'directing',
#   'worse',
#   'perhaps',
#   'contributory',
#   'former',
#   'dialog',
#   'chimplike',
#   'camera',
#   'work',
#   'barely',
#   'tolerable'],
#  ['still', 'wa', 'set', 'got', 'big', '10', 'oyvey', 'scale'],
#  ['yes',
#   'simplifying',
#   'thing',
#   'sake',
#   'brevity',
#   'really',
#   'core',
#   'problem',
#   'film',
#   'ha',
#   'much',
#   'going',
#   'without',
#   'real',
#   'fulfilling',
#   'explanation'],
#  ['good', 'job', 'quite', 'amusing'],
#  ['convoluted',
#   'plot',
#   'nt',
#   'convince',
#   'much',
#   'film',
#   'wa',
#   'watched',
#   'weird',
#   'questioning',
#   'glance'],
#  ['let', 'girlfriend', 'talk', 'seeing', 'bad', 'idea', 'hated'],
#  ['last', '15', 'minute', 'movie', 'also', 'bad', 'well'],
#  ['bela', 'lugosi', 'wa', 'totally', 'extraneous', 'intoning', 'odd', 'line'],
#  ['acting',
#   'wa',
#   'decidely',
#   'wooden',
#   'though',
#   'worse',
#   'period',
#   'universal',
#   'b',
#   'movie'],
#  ['like',
#   'armand',
#   'assante',
#   'cable',
#   'company',
#   's',
#   'summary',
#   'sounded',
#   'interesting',
#   'watched',
#   'twice',
#   'already',
#   'probably'],
#  ['believe', 'screenwriter', 'good', 'job', 'tying', 'loose', 'end'],
#  ['810', 'score', 'mostly', 'plot'],
#  ['wo',
#   'nt',
#   'say',
#   'nt',
#   'like',
#   'spoiler',
#   'nt',
#   'want',
#   'one',
#   'believe',
#   'film',
#   'worth',
#   'time'],
#  ['wow', 'bad', 'film'],
#  ['frightening', 'least', 'barely', 'comprehensible'],
#  ['plot',
#   'doe',
#   'nt',
#   'hang',
#   'together',
#   'acting',
#   'absolutely',
#   'appalling'],
#  ['even', 'good', 'camp', 'value'],
#  ['wa', 'nt', 'expecting', 'oscar', 'material'],
#  ['d', 'iq', 'particularly', 'stupid', 'mollusk', 'see', 'one', 'coming'],
#  ['film', 'use', 'word', 'loosely', 'insult', 'moviegoing', 'public'],
#  ['someone', 'involved', 'knew', 'string', 'together', 'narrative'],
#  ['get', '1', '10', 'simply', 's', 'nothing', 'lower'],
#  ['one',
#   'watched',
#   'recently',
#   'fox',
#   'movie',
#   'channel',
#   'wa',
#   'disappointed'],
#  ['know',
#   'wa',
#   'contract',
#   'player',
#   'little',
#   'control',
#   'script',
#   'acting',
#   'wa',
#   'bad',
#   'script'],
#  ['victor',
#   'mclaglen',
#   'wa',
#   'even',
#   'bad',
#   'brian',
#   'donlevy',
#   'wa',
#   'almost',
#   'unrecognizable'],
#  ['considering',
#   'relation',
#   'screen',
#   'taylor',
#   'stanwyck',
#   'wa',
#   'surprising',
#   'little',
#   'chemistry',
#   'wa',
#   'screen',
#   'two'],
#  ['premise', 'film', 'wa', 'ridiculous', 'president', 'us'],
#  ['death', 'row', 'scene', 'entirely', 'unmoving'],
#  ['thing', 'worse', 'taylor', 's', 'acting', 'wa', 'stanwyck', 's', 'singing'],
#  ['whatever', 'producer', 'wa', 'going', 'missed', 'entirely'],
#  ['wa', 'deeply', 'impressed', 'character', 'played'],
#  ['knew', 'saw', 'film', 'great', 'thing', 'come', 'gifted', 'actor'],
#  ['cheap',
#   'cheerless',
#   'heist',
#   'movie',
#   'poor',
#   'characterisation',
#   'lot',
#   'underbite',
#   'style',
#   'stoic',
#   'emoting',
#   'think',
#   'chow',
#   'yun',
#   'fat',
#   'better',
#   'tomorrow',
#   'cheesy',
#   'clichés',
#   'thrown',
#   'abandoned',
#   'factory',
#   'ready',
#   'poorly',
#   'executed',
#   'flying',
#   'judo',
#   'roll',
#   'la',
#   'john',
#   'woo'],
#  ['even', 'squib', 'look', 'awful'],
#  ['point', 'proceeding', 'doe', 'look', 'remotely', 'like', 'america'],
#  ['plot', 'derivative', 'predictable', 'ending', 'like', 'mercy', 'killing'],
#  ['awful',
#   'dialogue',
#   'hopeless',
#   'overacting',
#   'everyone',
#   'get',
#   'shot',
#   'top',
#   'real',
#   'waste',
#   'space',
#   'time'],
#  ['wa', 'uneasy', 'bad', 'movie', 'wa', 'scared'],
#  ['dialogue', 'composed', 'thing', 'make', 'little', 'sense'],
#  ['30',
#   'minute',
#   'footage',
#   'wasted',
#   'show',
#   'mediocre',
#   'elderly',
#   'actor',
#   'awkwardly',
#   'babbling',
#   'overwrought',
#   'pseudosatanic',
#   'gibberish',
#   'corny',
#   'enough',
#   'make',
#   'teen',
#   'goth',
#   'blush',
#   'almost',
#   'always',
#   'olde',
#   'english',
#   'sometimes',
#   'latin',
#   'may',
#   'may',
#   'made',
#   'word'],
#  ['directing', 'sloppy', 'best'],
#  ['hackneyed',
#   'writing',
#   'certainly',
#   'made',
#   'even',
#   'worse',
#   'bad',
#   'directing'],
#  ['course', 'acting', 'blah'],
#  ['acting',
#   'whole',
#   'cast',
#   'could',
#   'put',
#   'scale',
#   'balanced',
#   'perfectly',
#   'overacting',
#   'underacting'],
#  ['finally',
#   'get',
#   'ending',
#   'would',
#   've',
#   'great',
#   'handled',
#   'competent',
#   'people',
#   'jerry',
#   'falwell'],
#  ['loved',
#   'movie',
#   'wa',
#   'great',
#   'portrayal',
#   'family',
#   's',
#   'share',
#   'ups',
#   'end',
#   'knew',
#   'special',
#   'love'],
#  ['seen',
#   'many',
#   'movie',
#   'starring',
#   'jaclyn',
#   'smith',
#   'god',
#   'wa',
#   'one',
#   'best',
#   'though',
#   'came',
#   '12',
#   'year',
#   'ago'],
#  ['movie',
#   'contained',
#   'allstar',
#   'cast',
#   'loved',
#   'wa',
#   'opened',
#   'eye',
#   'see',
#   'actor',
#   'nt',
#   'seen'],
#  ['movie', 'wa', 'kind', 'long', 'length', 'enjoyed', 'every', 'minute'],
#  ['overall', 'rate', 'movie', '10', '110', 'scale'],
#  ['lifetime',
#   'doe',
#   'air',
#   'enough',
#   'anyone',
#   'know',
#   'store',
#   'sell',
#   'let',
#   'know',
#   'musthave'],
#  ['particularly',
#   'remember',
#   'sens',
#   'assaulted',
#   'strident',
#   'cord',
#   'music',
#   'would',
#   'blare',
#   'little',
#   'warning',
#   'even',
#   'le',
#   'meaning'],
#  ['sort', 'pap', 'screened', 'afternoon', 'punish', 'unemployed', 'job'],
#  ['totally',
#   'different',
#   'load',
#   'understatement',
#   'black',
#   'comedy',
#   'film',
#   'get',
#   'see',
#   'remember'],
#  ['movie', 'creates', 'universe', 'fascinating', 'every', 'way'],
#  ['movie', 'really', 'got'],
#  ['see'],
#  ['really',
#   'hope',
#   'team',
#   'behind',
#   'movie',
#   'make',
#   'movie',
#   'continue',
#   'kinda',
#   'weird',
#   'style'],
#  ['forgot',
#   'casting',
#   'superb',
#   'trond',
#   'fausa',
#   'aurvåg',
#   'perfect',
#   'role',
#   'bothersome',
#   'man',
#   'doe',
#   'nt',
#   'understand'],
#  ['movie', 'good', 'humorous', 'comment', 'life', '2006'],
#  ['found', 'move', 'beautiful', 'enjoyable', 'uplifting'],
#  ['initially',
#   'local',
#   'site',
#   'film',
#   'wa',
#   'filmed',
#   'buffalo',
#   'intrigued'],
#  ['later', 'found', 'lost', 'power', 'film'],
#  ['entire', 'audience', 'applauded', 'conclusion', 'film'],
#  ['left', 'theater', 'lilt', 'step', 'joy', 'heart', 'hope', 'human', 'race'],
#  ['duris', 'ha', 'wholesome', 'appearance', 'give', 'fine', 'performance'],
#  ['rest', 'cast', 'also', 'play', 'well'],
#  ['cinematography',
#   'noteworthy',
#   'including',
#   'fine',
#   'view',
#   'barcelona',
#   'famed',
#   'gaudi',
#   'tower'],
#  ['ten', 'minute', 'film', 'started', 'second', 'thought'],
#  ['half', 'way', 'film', 'started', 'dislike'],
#  ['time', 'film', 'ended', 'disliked', 'despised'],
#  ['film', 'lack', 'convincing', 'script'],
#  ['script',
#   'look',
#   'rough',
#   'draft',
#   'wa',
#   'written',
#   'shooting',
#   'began',
#   'finished',
#   'script',
#   'wa',
#   'completed'],
#  ['thing',
#   'happen',
#   'character',
#   'personality',
#   'change',
#   'plot',
#   'twist',
#   'occur',
#   'real',
#   'reason',
#   'script',
#   'call'],
#  ['cast', 'good'],
#  ['s', 'worth', 'checking'],
#  ['probably', 'irritating', 'show', 'ever', 'seen', 'entire', 'life'],
#  ['indescribably', 'annoying', 'idiotic', 'show', 'ever', 'seen'],
#  ['everything', 'bad'],
#  ['could',
#   'understand',
#   'kind',
#   'idiot',
#   'would',
#   'produce',
#   'mess',
#   'first',
#   'place',
#   'mention',
#   'several',
#   'season'],
#  ['script',
#   'bad',
#   'bad',
#   '\x96',
#   'contains',
#   'cheesiness',
#   'unethical',
#   'joke',
#   'normally',
#   'see',
#   'rated',
#   'r',
#   'nc17',
#   'movie'],
#  ['casting',
#   'also',
#   'horrible',
#   'cause',
#   'see',
#   'really',
#   'really',
#   'bad',
#   'actor',
#   'period'],
#  ['final', 'word', 'show', 'real', 'torture'],
#  ['zillion', 'time', 'away', 'reality'],
#  ['watching',
#   'washing',
#   'machine',
#   'twirling',
#   'around',
#   'would',
#   'nt',
#   'hurt',
#   'eye',
#   'much',
#   'show'],
#  ['rating',
#   '010',
#   'grade',
#   'z',
#   'note',
#   'show',
#   'bad',
#   'even',
#   'mother',
#   'cast',
#   'pull',
#   'daughter',
#   'show'],
#  ['20th',
#   'century',
#   'fox',
#   's',
#   'road',
#   'house',
#   '1948',
#   'quite',
#   'silly',
#   'noir',
#   'implausible',
#   'unmitigated',
#   'bore',
#   'movie'],
#  ['full',
#   'unconvincing',
#   'cardboard',
#   'character',
#   'blandly',
#   'written',
#   'edward',
#   'chodorov',
#   'also',
#   'produced',
#   'surprisingly',
#   'directed',
#   'jean',
#   'negulesco',
#   'one',
#   'would',
#   'expect',
#   'great',
#   'deal'],
#  ['widmark', 'character', 'turn', 'unintentionally', 'comical'],
#  ['losing',
#   'marble',
#   'early',
#   'proceeding',
#   'totally',
#   'implausible',
#   'unconvincing'],
#  ['nt',
#   'enough',
#   'mess',
#   'movie',
#   'picture',
#   'also',
#   'marred',
#   'constant',
#   'use',
#   'studio',
#   'set',
#   'indoor',
#   'exterior'],
#  ['whatever', 'prompted', 'documentary', 'beyond'],
#  ['serious', 'spoiler', 'movie', 'wa', 'huge', 'disappointment'],
#  ['many', 'problem', 'dont', 'know', 'start'],
#  ['cast', 'wa', 'great'],
#  ['steve',
#   'martin',
#   'delivers',
#   'really',
#   'funny',
#   'performance',
#   'middleaged',
#   'upper',
#   'class',
#   'uptight',
#   'white',
#   'guy'],
#  ['add',
#   'betty',
#   'white',
#   'jean',
#   'smart',
#   'great',
#   'cast',
#   'everyone',
#   'played',
#   'part',
#   'really',
#   'well'],
#  ['movie', 'make', 'lot', 'serious', 'mistake'],
#  ['first',
#   'enough',
#   'racial',
#   'stereotype',
#   'racial',
#   'joke',
#   'offend',
#   'everyone'],
#  ['movie',
#   'littered',
#   'overt',
#   'racial',
#   'slur',
#   'towards',
#   'black',
#   'cast',
#   'member',
#   'return',
#   'white',
#   'depicted',
#   'moron',
#   'boob'],
#  ['putting',
#   'race',
#   'card',
#   'aside',
#   'let',
#   'look',
#   'major',
#   'flaw',
#   'film',
#   'destroy',
#   'latifa',
#   's',
#   'character'],
#  ['real', 'plot'],
#  ['wouldnt', 'see', 'movie', 'free'],
#  ['steamboat',
#   'willie',
# ...
#  ['microphone',
#   'also',
#   'work',
#   'well',
#   'according',
#   'people',
#   'called',
#   'applifies',
#   'everything'],
#  ['nice', 'design', 'quality'],
#  ['also',
#   'phone',
#   'dropped',
#   'case',
#   'going',
#   'save',
#   'specially',
#   'dropped',
#   'face'],
#  ['light', 'easy', 'use', 'ha', 'clear', 'reception', 'transmission'],
#  ['bad', 'fit', 'way', 'big'],
#  ['definitely', 'wa', 'good', 's11'],
#  ['awesome', 'device'],
#  ['waste', 'money'],
#  ['ordered',
#   'motorola',
#   'data',
#   'cable',
#   'got',
#   'well',
#   'finished',
#   'working',
#   'product'],
#  ['love', 'phone'],
#  ['wa',
#   'looking',
#   'headset',
#   'long',
#   'time',
#   've',
#   'got',
#   'could',
#   'nt',
#   'happier'],
#  ['ll', 'drivng', 'along', 'headset', 'start', 'ringing', 'reason'],
#  ['display', 'excellent', 'camera', 'good', 'year'],
#  ['battery', 'life', 'also', 'great'],
#  ['worst', 'phone', 've', 'ever', 'month'],
#  ['good',
#   'item',
#   'worked',
#   'started',
#   'problem',
#   'auto',
#   'reverse',
#   'tape',
#   'player'],
#  ['embarassing', 'also', 'ear', 'hurt', 'try', 'push', 'ear', 'plug', 'ear'],
#  ['protects', 'phone', 'side'],
#  ['average', 'phone', 'bad', 'battery', 'life', 'operates', 'weak', 'network'],
#  ['clear', 'skype', 'call', 'long', 'battery', 'life', 'long', 'range'],
#  ['soyo', 'technology', 'suck'],
#  ['great', 'hand', 'free', 'device'],
#  ['even',
#   'take',
#   'self',
#   'portrait',
#   'outside',
#   'exterior',
#   'display',
#   'cool'],
#  ['problem', 'others', 'mentioned'],
#  ['trying',
#   'many',
#   'many',
#   'handsfree',
#   'gadget',
#   'one',
#   'finally',
#   'work',
#   'well'],
#  ['magical', 'help'],
#  ['worst', 'piece', 'crap', 'ever', 'along', 'verizon', 'customer', 'service'],
#  ['poor', 'sound', 'quality'],
#  ['best', 'phone', 'market'],
#  ['worked', 'well'],
#  ['company', 'shipped', 'product', 'promptly', 'work', 'well'],
#  ['exactly', 'wanted'],
#  ['picture',
#   'resolution',
#   'far',
#   'comparablypriced',
#   'phone',
#   'offering',
#   'today'],
#  ['great', 'deal'],
#  ['excellent', 'product', 'satisfied', 'purchase'],
#  ['highly', 'recommend', 'encourage', 'people', 'give', 'try'],
#  ['better', 'd', 'expect'],
#  ['using', 'earpiece', 'left', 'right', 'thing', 'stay', 'ear'],
#  ['great', 'product', 'price'],
#  ['sound', 'good', 'reasonably', 'priced', 'effective', 'simple'],
#  ['still',
#   'waiting',
#   'm',
#   'sure',
#   'item',
#   'would',
#   'work',
#   'well',
#   'ever',
#   'recieve'],
#  ['wow', 'loved', 'place'],
#  ['crust', 'good'],
#  ['tasty', 'texture', 'wa', 'nasty'],
#  ['stopped',
#   'late',
#   'may',
#   'bank',
#   'holiday',
#   'rick',
#   'steve',
#   'recommendation',
#   'loved'],
#  ['selection', 'menu', 'wa', 'great', 'price'],
#  ['getting', 'angry', 'want', 'damn', 'pho'],
#  ['honeslty', 'nt', 'taste', 'fresh'],
#  ['potato',
#   'like',
#   'rubber',
#   'could',
#   'tell',
#   'made',
#   'ahead',
#   'time',
#   'kept',
#   'warmer'],
#  ['fry', 'great'],
#  ['great', 'touch'],
#  ['service', 'wa', 'prompt'],
#  ['would', 'go', 'back'],
#  ['cashier', 'care', 'ever', 'say', 'still', 'ended', 'wayyy', 'overpriced'],
#  ['tried', 'cape', 'cod', 'ravoli', 'chicken', 'cranberry', 'mmmm'],
#  ['wa', 'disgusted', 'wa', 'pretty', 'sure', 'wa', 'human', 'hair'],
#  ['wa', 'shocked', 'sign', 'indicate', 'cash'],
#  ['highly', 'recommended'],
#  ['waitress', 'wa', 'little', 'slow', 'service'],
#  ['place', 'worth', 'time', 'let', 'alone', 'vega'],
#  ['like'],
#  ['burrittos', 'blah'],
#  ['food', 'amazing'],
#  ['service', 'also', 'cute'],
#  ['could', 'care', 'le', 'interior', 'beautiful'],
#  ['performed'],
#  ['s', 'right', 'red', 'velvet', 'cake', 'ohhh', 'stuff', 'good'],
#  ['never', 'brought', 'salad', 'asked'],
#  ['hole',
#   'wall',
#   'ha',
#   'great',
#   'mexican',
#   'street',
#   'taco',
#   'friendly',
#   'staff'],
#  ['took',
#   'hour',
#   'get',
#   'food',
#   '4',
#   'table',
#   'restaurant',
#   'food',
#   'wa',
#   'luke',
#   'warm',
#   'sever',
#   'wa',
#   'running',
#   'around',
#   'like',
#   'wa',
#   'totally',
#   'overwhelmed'],
#  ['worst', 'wa', 'salmon', 'sashimi'],
#  ['also', 'combo', 'like', 'burger', 'fry', 'beer', '23', 'decent', 'deal'],
#  ['wa', 'like', 'final', 'blow'],
#  ['found', 'place', 'accident', 'could', 'happier'],
#  ['seems',
#   'like',
#   'good',
#   'quick',
#   'place',
#   'grab',
#   'bite',
#   'familiar',
#   'pub',
#   'food',
#   'favor',
#   'look',
#   'elsewhere'],
#  ['overall', 'like', 'place', 'lot'],
#  ['redeeming', 'quality', 'restaurant', 'wa', 'wa', 'inexpensive'],
#  ['ample', 'portion', 'good', 'price'],
#  ['poor',
#   'service',
#   'waiter',
#   'made',
#   'feel',
#   'like',
#   'wa',
#   'stupid',
#   'every',
#   'time',
#   'came',
#   'table'],
#  ['first', 'visit', 'hiro', 'wa', 'delight'],
#  ['service', 'suck'],
#  ['shrimp', 'tender', 'moist'],
#  ['deal', 'good', 'enough', 'would', 'drag', 'establishment'],
#  ['hard',
#   'judge',
#   'whether',
#   'side',
#   'good',
#   'grossed',
#   'melted',
#   'styrofoam',
#   'nt',
#   'want',
#   'eat',
#   'fear',
#   'getting',
#   'sick'],
#  ['positive',
#   'note',
#   'server',
#   'wa',
#   'attentive',
#   'provided',
#   'great',
#   'service'],
#  ['frozen', 'puck', 'disgust', 'worst', 'people', 'behind', 'register'],
#  ['thing', 'like', 'wa', 'prime', 'rib', 'dessert', 'section'],
#  ['s', 'bad', 'food', 'damn', 'generic'],
#  ['burger', 'good', 'beef', 'cooked', 'right'],
#  ['want', 'sandwich', 'go', 'firehouse'],
#  ['side',
#   'greek',
#   'salad',
#   'greek',
#   'dressing',
#   'wa',
#   'tasty',
#   'pita',
#   'hummus',
#   'wa',
#   'refreshing'],
#  ['ordered',
#   'duck',
#   'rare',
#   'wa',
#   'pink',
#   'tender',
#   'inside',
#   'nice',
#   'char',
#   'outside'],
#  ['came', 'running', 'u', 'realized', 'husband', 'left', 'sunglass', 'table'],
#  ['chow', 'mein', 'good'],
#  ['horrible',
#   'attitude',
#   'towards',
#   'customer',
#   'talk',
#   'one',
#   'customer',
#   'nt',
#   'enjoy',
#   'food'],
#  ['portion', 'wa', 'huge'],
#  ['loved',
#   'friendly',
#   'server',
#   'great',
#   'food',
#   'wonderful',
#   'imaginative',
#   'menu'],
#  ['heart',
#   'attack',
#   'grill',
#   'downtown',
#   'vega',
#   'absolutely',
#   'flatlined',
#   'excuse',
#   'restaurant'],
#  ['much', 'seafood', 'like', '5', 'string', 'pasta', 'bottom'],
#  ['salad',
#   'right',
#   'amount',
#   'sauce',
#   'power',
#   'scallop',
#   'wa',
#   'perfectly',
#   'cooked'],
#  ['ripped', 'banana', 'wa', 'ripped', 'petrified', 'tasteless'],
#  ['least', 'think', 'refill', 'water', 'struggle', 'wave', '10', 'minute'],
#  ['place', 'receives', 'star', 'appetizer'],
#  ['cocktail', 'handmade', 'delicious'],
#  ['d', 'definitely', 'go', 'back'],
#  ['glad', 'found', 'place'],
#  ['great',
#   'food',
#   'service',
#   'huge',
#   'portion',
#   'give',
#   'military',
#   'discount'],
#  ['always', 'great', 'time', 'gringo'],
#  ['update', 'went', 'back', 'second', 'time', 'wa', 'still', 'amazing'],
#  ['got',
#   'food',
#   'apparently',
#   'never',
#   'heard',
#   'salt',
#   'batter',
#   'fish',
#   'wa',
#   'chewy'],
#  ['great', 'way', 'finish', 'great'],
#  ['deal',
#   'included',
#   '5',
#   'tasting',
#   '2',
#   'drink',
#   'jeff',
#   'went',
#   'beyond',
#   'expected'],
#  ['really', 'really', 'good', 'rice', 'time'],
#  ['service', 'wa', 'meh'],
#  ['took',
#   '30',
#   'min',
#   'get',
#   'milkshake',
#   'wa',
#   'nothing',
#   'chocolate',
#   'milk'],
#  ['guess',
#   'known',
#   'place',
#   'would',
#   'suck',
#   'inside',
#   'excalibur',
#   'nt',
#   'use',
#   'common',
#   'sense'],
#  ['scallop', 'dish', 'quite', 'appalling', 'value', 'well'],
#  ['2', 'time', 'bad', 'customer', 'service'],
#  ['sweet', 'potato', 'fry', 'good', 'seasoned', 'well'],
#  ['today', 'second', 'time', 've', 'lunch', 'buffet', 'wa', 'pretty', 'good'],
#  ['much',
#   'good',
#   'food',
#   'vega',
#   'feel',
#   'cheated',
#   'wasting',
#   'eating',
#   'opportunity',
#   'going',
#   'rice',
#   'company'],
#  ['coming',
#   'like',
#   'experiencing',
#   'underwhelming',
#   'relationship',
#   'party',
#   'ca',
#   'nt',
#   'wait',
#   'person',
#   'ask',
#   'break'],
#  ['walked',
#   'place',
#   'smelled',
#   'like',
#   'old',
#   'grease',
#   'trap',
#   '2',
#   'others',
#   'eating'],
#  ['turkey', 'roast', 'beef', 'bland'],
#  ['place', 'ha'],
#  ['pan',
#   'cake',
#   'everyone',
#   'raving',
#   'taste',
#   'like',
#   'sugary',
#   'disaster',
#   'tailored',
#   'palate',
#   'six',
#   'year',
#   'old'],
#  ['love', 'pho', 'spring', 'roll', 'oh', 'yummy', 'try'],
#  ['poor',
#   'batter',
#   'meat',
#   'ratio',
#   'made',
#   'chicken',
#   'tender',
#   'unsatisfying'],
#  ['say', 'food', 'wa', 'amazing'],
#  ['omelet', 'die'],
#  ['everything', 'wa', 'fresh', 'delicious'],
#  ['summary', 'wa', 'largely', 'disappointing', 'dining', 'experience'],
#  ['s',
#   'like',
#   'really',
#   'sexy',
#   'party',
#   'mouth',
#   're',
#   'outrageously',
#   'flirting',
#   'hottest',
#   'person',
#   'party'],
#  ['never', 'hard', 'rock', 'casino', 'never', 'ever', 'step', 'forward'],
#  ['best', 'breakfast', 'buffet'],
#  ['say', 'bye', 'bye', 'tip', 'lady'],
#  ['ll', 'never', 'go'],
#  ['back'],
#  ['food', 'arrived', 'quickly'],
#  ['wa', 'good'],
#  ['side', 'cafe', 'serf', 'really', 'good', 'food'],
#  ['server',
#   'wa',
#   'fantastic',
#   'found',
#   'wife',
#   'love',
#   'roasted',
#   'garlic',
#   'bone',
#   'marrow',
#   'added',
#   'extra',
#   'meal',
#   'another',
#   'marrow',
#   'go'],
#  ['good',
#   'thing',
#   'wa',
#   'waiter',
#   'wa',
#   'helpful',
#   'kept',
#   'bloddy',
#   'mary',
#   's',
#   'coming'],
#  ['best', 'buffet', 'town', 'price', 'beat'],
#  ['loved',
#   'mussel',
#   'cooked',
#   'wine',
#   'reduction',
#   'duck',
#   'wa',
#   'tender',
#   'potato',
#   'dish',
#   'delicious'],
#  ['one', 'better', 'buffet'],
#  ['went', 'tigerlilly', 'fantastic', 'afternoon'],
#  ['food',
#   'wa',
#   'delicious',
#   'bartender',
#   'wa',
#   'attentive',
#   'personable',
#   'got',
#   'great',
#   'deal'],
#  ['ambience', 'wonderful', 'music', 'playing'],
#  ['go', 'back', 'next', 'trip'],
#  ['sooooo', 'good'],
#  ['real', 'sushi', 'lover', 'let', 's', 'honest', 'yama', 'good'],
#  ['least',
#   '40min',
#   'passed',
#   'u',
#   'ordering',
#   'food',
#   'arriving',
#   'wa',
#   'nt',
#   'busy'],
#  ['really', 'fantastic', 'thai', 'restaurant', 'definitely', 'worth', 'visit'],
#  ['nice', 'spicy', 'tender'],
#  ['good', 'price'],
#  ['check'],
#  ['wa', 'pretty', 'gross'],
#  ['ve', 'better', 'atmosphere'],
#  ['kind', 'hard', 'mess', 'steak'],
#  ['although',
#   'much',
#   'liked',
#   'look',
#   'sound',
#   'place',
#   'actual',
#   'experience',
#   'wa',
#   'bit',
#   'disappointing'],
#  ['nt',
#   'know',
#   'place',
#   'managed',
#   'served',
#   'blandest',
#   'food',
#   'ever',
#   'eaten',
#   'preparing',
#   'indian',
#   'cuisine'],
#  ['worst', 'service', 'boot', 'least', 'worry'],
#  ['service', 'wa', 'fine', 'waitress', 'wa', 'friendly'],
#  ['guy',
#   'steak',
#   'steak',
#   'loving',
#   'son',
#   'ha',
#   'steak',
#   'best',
#   'worst',
#   'place',
#   'said',
#   'wa',
#   'best',
#   'steak',
#   's',
#   'ever',
#   'eaten'],
#  ['thought',
#   'd',
#   'venture',
#   'away',
#   'get',
#   'good',
#   'sushi',
#   'place',
#   'really',
#   'hit',
#   'spot',
#   'night'],
#  ['host', 'staff', 'lack', 'better', 'word', 'bitch'],
#  ['bland',
#   'liking',
#   'place',
#   'number',
#   'reason',
#   'nt',
#   'want',
#   'waste',
#   'time',
#   'bad',
#   'reviewing',
#   'll',
#   'leave'],
#  ['phenomenal', 'food', 'service', 'ambiance'],
#  ['would', 'nt', 'return'],
#  ['definitely',
#   'worth',
#   'venturing',
#   'strip',
#   'pork',
#   'belly',
#   'return',
#   'next',
#   'time',
#   'm',
#   'vega'],
#  ['place', 'way', 'overpriced', 'mediocre', 'food'],
#  ['penne', 'vodka', 'excellent'],
#  ['good',
#   'selection',
#   'food',
#   'including',
#   'massive',
#   'meatloaf',
#   'sandwich',
#   'crispy',
#   'chicken',
#   'wrap',
#   'delish',
#   'tuna',
#   'melt',
#   'tasty',
#   'burger'],
#  ['management', 'rude'],
#  ['delicious',
#   'nyc',
#   'bagel',
#   'good',
#   'selection',
#   'cream',
#   'cheese',
#   'real',
#   'lox',
#   'caper',
#   'even'],
#  ['great',
#   'subway',
#   'fact',
#   's',
#   'good',
#   'come',
#   'every',
#   'subway',
#   'meet',
#   'expectation'],
#  ['seriously', 'solid', 'breakfast'],
#  ['one', 'best', 'bar', 'food', 'vega'],
#  ['wa',
#   'extremely',
#   'rude',
#   'really',
#   'many',
#   'restaurant',
#   'would',
#   'love',
#   'dine',
#   'weekend',
#   'vega'],
#  ['drink',
#   'wa',
#   'never',
#   'empty',
#   'made',
#   'really',
#   'great',
#   'menu',
#   'suggestion'],
#  ['nt'],
#  ['waiter', 'wa', 'nt', 'helpful', 'friendly', 'rarely', 'checked', 'u'],
#  ['husband', 'ate', 'lunch', 'disappointed', 'food', 'service'],
#  ['red', 'curry', 'much', 'bamboo', 'shoot', 'wa', 'nt', 'tasty'],
#  ['nice',
#   'blanket',
#   'moz',
#   'top',
#   'feel',
#   'like',
#   'wa',
#   'done',
#   'cover',
#   'subpar',
#   'food'],
#  ['bathroom', 'clean', 'place', 'well', 'decorated'],
#  ['menu',
#   'always',
#   'changing',
#   'food',
#   'quality',
#   'going',
#   'service',
#   'extremely',
#   'slow'],
#  ['service',
#   'wa',
#   'little',
#   'slow',
#   'considering',
#   'served',
#   '3',
#   'people',
#   'server',
#   'food',
#   'wa',
#   'coming',
#   'slow',
#   'pace'],
#  ['give', '2', 'thumb'],
#  ['watched', 'waiter', 'pay', 'lot', 'attention', 'table', 'ignore', 'u'],
#  ['fiancé', 'came', 'middle', 'day', 'greeted', 'seated', 'right', 'away'],
#  ['great', 'restaurant', 'mandalay', 'bay'],
#  ['waited', 'forty', 'five', 'minute', 'vain'],
#  ['crostini', 'came', 'salad', 'wa', 'stale'],
#  ['highlight', 'great', 'quality', 'nigiri'],
#  ['staff', 'friendly', 'joint', 'always', 'clean'],
#  ['wa',
#   'different',
#   'cut',
#   'piece',
#   'day',
#   'still',
#   'wonderful',
#   'tender',
#   'well',
#   'well',
#   'flavored'],
#  ['ordered',
#   'voodoo',
#   'pasta',
#   'wa',
#   'first',
#   'time',
#   'd',
#   'really',
#   'excellent',
#   'pasta',
#   'since',
#   'going',
#   'gluten',
#   'free',
#   'several',
#   'year',
#   'ago'],
#  ['place', 'good'],
#  ['unfortunately',
#   'must',
#   'hit',
#   'bakery',
#   'leftover',
#   'day',
#   'everything',
#   'ordered',
#   'wa',
#   'stale'],
#  ['came', 'back', 'today', 'since', 'relocated', 'still', 'impressed'],
#  ['wa', 'seated', 'immediately'],
#  ['menu', 'diverse', 'reasonably', 'priced'],
#  ['avoid', 'cost'],
#  ['restaurant', 'always', 'full', 'never', 'wait'],
#  ['delicious'],
#  ['place',
#   'handsdown',
#   'one',
#   'best',
#   'place',
#   'eat',
#   'phoenix',
#   'metro',
#   'area'],
#  ['nt', 'go', 'looking', 'good', 'food'],
#  ['ve', 'never', 'treated', 'bad'],
#  ['bacon', 'hella', 'salty'],
#  ['also',
#   'ordered',
#   'spinach',
#   'avocado',
#   'salad',
#   'ingredient',
#   'sad',
#   'dressing',
#   'literally',
#   'zero',
#   'taste'],
#  ['really',
#   'vega',
#   'fine',
#   'dining',
#   'used',
#   'right',
#   'menu',
#   'handed',
#   'lady',
#   'price',
#   'listed'],
#  ['waitress', 'friendly'],
#  ['lordy', 'khao', 'soi', 'dish', 'missed', 'curry', 'lover'],
#  ['everything',
#   'menu',
#   'terrific',
#   'also',
#   'thrilled',
#   'made',
#   'amazing',
#   'accommodation',
#   'vegetarian',
#   'daughter'],
#  ['perhaps',
#   'caught',
#   'night',
#   'judging',
#   'review',
#   'm',
#   'inspired',
#   'go',
#   'back'],
#  ['service', 'leaf', 'lot', 'desired'],
#  ['atmosphere', 'modern', 'hip', 'maintaining', 'touch', 'coziness'],
#  ['weekly', 'haunt', 'definitely', 'place', 'come', 'back', 'every'],
#  ['literally', 'sat', '20', 'minute', 'one', 'asking', 'take', 'order'],
#  ['burger',
#   'absolutely',
#   'flavor',
#   'meat',
#   'wa',
#   'totally',
#   'bland',
#   'burger',
#   'wa',
#   'overcooked',
#   'wa',
#   'charcoal',
#   'flavor'],
#  ['also',
#   'decided',
#   'send',
#   'back',
#   'waitress',
#   'looked',
#   'like',
#   'wa',
#   'verge',
#   'heart',
#   'attack'],
#  ['dressed', 'treated', 'rudely'],
#  ['wa', 'probably', 'dirt'],
#  ['love',
#   'place',
#   'hit',
#   'spot',
#   'want',
#   'something',
#   'healthy',
#   'lacking',
#   'quantity',
#   'flavor'],
#  ['ordered',
#   'lemon',
#   'raspberry',
#   'ice',
#   'cocktail',
#   'wa',
#   'also',
#   'incredible'],
#  ['food', 'sucked', 'expected', 'sucked', 'could', 'imagined'],
#  ['interesting', 'decor'],
#  ['really', 'like', 'crepe', 'station'],
#  ['also',
#   'served',
#   'hot',
#   'bread',
#   'butter',
#   'home',
#   'made',
#   'potato',
#   'chip',
#   'bacon',
#   'bit',
#   'top',
#   'original',
#   'good'],
#  ['watch', 'preparing', 'delicious', 'food'],
#  ['egg', 'roll', 'fantastic'],
#  ['order', 'arrived', 'one', 'gyro', 'wa', 'missing'],
#  ['salad',
#   'wing',
#   'ice',
#   'cream',
#   'dessert',
#   'left',
#   'feeling',
#   'quite',
#   'satisfied'],
#  ['m',
#   'really',
#   'sure',
#   'joey',
#   's',
#   'wa',
#   'voted',
#   'best',
#   'hot',
#   'dog',
#   'valley',
#   'reader',
#   'phoenix',
#   'magazine'],
#  ['best', 'place', 'go', 'tasty', 'bowl', 'pho'],
#  ['live', 'music', 'friday', 'totally', 'blow'],
#  ['ve', 'never', 'insulted', 'felt', 'disrespected'],
#  ['friendly', 'staff'],
#  ['worth', 'drive'],
#  ...]

# %%
x_train #after
# Out:
# ['slowmoving,aimless,movie,distressed,drifting,young,man',
#  'sure,wa,lost,flat,character,audience,nearly,half,walked',
#  'attempting,artiness,black,white,clever,camera,angle,movie,disappointed,became,even,ridiculous,acting,wa,poor,plot,line,almost,nonexistent',
#  'little,music,anything,speak',
#  'best,scene,movie,wa,gerardo,trying,find,song,keep,running,head',
#  'rest,movie,lack,art,charm,meaning,s,emptiness,work,guess,s,empty',
#  'wasted,two,hour',
#  'saw,movie,today,thought,wa,good,effort,good,message,kid',
#  'bit,predictable',
#  'loved,casting,jimmy,buffet,science,teacher',
#  'baby,owl,adorable',
#  'movie,showed,lot,florida,s,best,made,look,appealing',
#  'song,best,muppets,hilarious',
#  'wa,cool',
#  'right,case,movie,delivers,everything,almost,right,face',
#  'average,acting,main,person,wa,low,budget,clearly,see',
#  'review,long,overdue,since,consider,tale,two,sister,single,greatest,film,ever,made',
#  'll,put,gem,movie,term,screenplay,cinematography,acting,postproduction,editing,directing,aspect,filmmaking',
#  's,practically,perfect,\x96,true,masterpiece,sea,faux,masterpiece',
#  'structure,film,easily,tightly,constructed,history,cinema,1,think,film,something,vitally,important,occurs,every,minute,1,word,content,level,film,enough,easily,fill,dozen,film,1,anyone,right,mind,ask,anything,movie,1,s,quite,simply,highest,superlative,form,cinema,imaginable,1,yes,film,doe,require,rather,significant,amount,puzzlesolving,piece,fit,together,create,beautiful,picture,1,short,film,certainly,pull,punch,0,graphic,far,best,part,game,0,number,one,best,th,game,series,1,deserves,strong,love,1,insane,game,1,massive,level,massive,unlockable,character,s,massive,game,1,waste,money,game,1,kind,money,wasted,properly,1,actually,graphic,good,time,1,today,graphic,crap,0,say,canada,fun,game,aye,1,game,rock,1,buy,play,enjoy,love,1,s,pure,brilliance,1,wa,flick,doomed,conception,0,idea,wa,lame,take,minor,character,mediocre,pg13,film,make,complete,nonsequel,changing,tone,pgrated,family,movie,0,wa,nt,least,bit,interested,0,confirm,film,would,unfunny,generic,also,managed,give,away,entire,movie,m,exaggerating,every,moment,every,plot,point,every,joke,told,trailer,0,s,funny,0,even,talented,carrell,ca,nt,save,0,costar,nt,fare,much,better,people,like,morgan,freeman,jonah,hill,ed,helm,wasted,0,story,predictable,lazy,0,real,effect,work,presence,animal,integration,scene,worst,obvious,bluegreenscreen,work,ve,ever,seen,0,whatever,wa,cost,much,nt,translate,quality,s,sure,0,film,succeeds,despite,perhaps,obviously,meagre,budget,1,m,glad,film,nt,go,obvious,choice,lesser,film,certainly,would,1,addition,one,lovely,song,ever,written,french,cancan,also,boast,one,cutest,leading,lady,ever,grace,screen,1,s,hard,fall,headoverheels,love,girl,1,negative,s,insipid,enough,cause,regret,another,2,hour,life,wasted,front,screen,0,long,whiny,pointless,0,recommend,waiting,future,effort,let,one,go,0,excellent,cast,story,line,performance,1,totally,believable,1,anne,heche,wa,utterly,convincing,1,sam,shepard,s,portrayal,gung,ho,marine,wa,sobering,1,sat,riveted,tv,screen,1,give,one,resounding,9,10,1,think,tom,hank,good,actor,1,enjoyed,reading,book,child,little,1,wa,disappointed,movie,0,one,character,totally,annoying,voice,give,feeling,fingernail,chalkboard,0,totally,unnecessary,trainroller,coaster,scene,0,wa,absolutely,warmth,charm,scene,character,0,movie,totally,grate,nerve,0,performance,improved,improvisation,actor,twice,much,worry,whether,re,delivering,line,well,whether,line,good,0,quite,honestly,often,good,0,often,dialogue,doe,nt,really,follow,one,line,another,fit,surroundings,0,crackle,unpredictable,youthful,energy,honestly,found,hard,follow,concentrate,meander,badly,0,generally,great,thing,1,would,nt,say,re,worth,2,hour,time,though,0,suspense,builder,good,cross,line,g,pg,1,especially,liked,noncliche,choice,parent,movie,could,predict,dialog,verbatim,writing,movie,made,better,selection,1,want,movie,s,gross,give,chill,great,choice,1,alexander,nevsky,great,film,1,amazing,film,artist,one,important,whoever,lived,1,m,glad,pretentious,piece,nt,planned,dodge,stratus,big,shot,s,gon,na,help,movie,maker,nt,restrained,movie,business,québec',
#  'first,movie,ve,given,10,year',
#  'wa,ever,movie,needed,wordofmouth,promote',
#  'overall,film,interesting,thoughtprovoking',
#  'plus,wa,wellpaced,suited,relatively,short,run,time',
#  'give,one,look',
#  'gave,10',
#  'wind,lion,well,written,superbly,acted',
#  'true,classic',
#  'actually,turned,pretty,decent,far,blist,horrorsuspense,film,go',
#  'definitely,worth,checking',
#  'problem,wa,script',
#  'wa,horrendous',
#  'wa,nothing,believable',
#  'suspense,wa,feeling,wa,frustration,retarded,girl',
#  'manna,heaven,terrific,film,predictable,unpredictable,time',
#  'scene,often,funny,occasionally,touching,character,evaluate,life,going',
#  'cast,veteran,actor,nostalgia,trip',
#  'ursula,burton,s,portrayal,nun,touching,funny,time,making,fun,nun,church',
#  'looking,movie,terrific,cast,good,music,including,shirley,jones,rendition,way,look,tonight,uplifting,ending,give,one,try',
#  'nt,think,disappointed',
#  'frankly,cotton,club,unfaithful,wa,kind,embarrassing,watch,lane,gere,film,bad',
#  'acting,wa,bad,dialog,extremely,shallow,insincere',
#  'wa,predictable,even,chick,flick',
#  'politically,correct',
#  'disappointing',
#  'thing,really,worth,watching,wa,scenery,house,beautiful',
#  'love,lane,ve,never,seen,movie,lousy',
#  'hour,half,wish,could,bring,back',
#  'term,writing,s,fresh,bold',
#  'acting,help,writing,along,well,maybe,idiotsavant,sister,could,played,better,real,joy,watch',
#  'directing,cinematography,nt,quite,good',
#  'movie,wa,boring,sometimes,found,occupied,peaking,paper,instead,watching,never,happened,columbo,movie',
#  'sometimes,wa,embarrassing,look,away',
#  'directing,seems,pretentious',
#  'scene,ohsomature,neighbourgirl,misplace',
#  'generally,line,plot,weaker,average,episode',
#  'scene,debated,whether,sack,trumpeter,falsely,wa,accused,murder,pure,horror,really,stupid',
#  'applause,given,prelude,however',
#  'really,liked',
#  'great,film,great,director',
#  'movie,edge,seat,made,somewhat,afraid,go,car,end,night',
#  'music,film,really,nice',
#  'd,advise,anyone,go,see',
#  'brilliant',
#  '1010',
#  'liked,movie,way,much',
#  'problem,thought,actor,playing,villain,wa,low,rent,michael,ironside',
#  'rocked,world,certainly,must,see,anyone,social,physical,outlet',
#  'however,nt,make,fact,overall,wa,tremendously,boring,movie',
#  'wa,chemistry,ben,affleck,sandra,bullock,film,could,nt,understand,would,consider,even,leaving,wifetobe,chick,supposedly,wa,knocked',
#  'several,moment,movie,nt,need,excruciatingly,slow,moving',
#  'wa,poor,remake,best,friend,wedding',
#  'great,disappointment',
#  'believe,actor,agreed,film',
#  'could,stand,even,watch,long,fear,losing,iq',
#  'guess,nobody,network,aired,dribble,watched,putting',
#  'imdb,rating,go,low,1,awful,s,time,get,negative,number,case',
#  'saw,mirrormask,last,night,wa,unsatisfactory,experience',
#  'unfortunately,inexperience,direction,meant,scene,scene,passed,little,way,dramatic,tension,conflict',
#  'central,theme,film,handled,ineptly,stereotypically,depth,imagination',
#  'pretty,picture,world,make,piece,work,flawed,core',
#  'hour,half,waste,time,following,bunch,pretty,high,schoolers,whine,cry,life',
#  'ca,nt,relate,hell,barely,understand',
#  'definitely,cult,classic,well,worth,viewing,sharing,others',
#  'movie,pure,disaster,story,stupid,editing,worst,seen,confuses,incredibly',
#  'fish,badly,made,underwater,shot,repeated,thousand,time,film',
#  'truly,truly,bad,film',
#  'acting,terrible,writing,worse',
#  'possible,way,movie,could,redeemed,would,mst3k,fodder',
#  'paid,much',
#  'also,s,real,treat,see,anthony,quinn,playing,crazy,horse',
#  'wa,boring',
#  'plot,whatsoever',
#  'plot',
#  'horrible',
#  'worst,hour,half,life,oh,gosh',
#  'walk,theatre,minute,get,relief',
#  'hate,movie,like',
#  'yeah,movie,pretty,much,sucked',
#  'plot,storyline',
#  'go,see,movie,bring,pillow,girlfriendboyfriend,keep,occupied',
#  'awful',
#  'nt,think,ve,ever,gone,movie,disliked,much',
#  'wa,good,thing,ticket,cost,five,dollar,would,mad,d,paid,750,see,crap',
#  'nobody,identifies,character,re,cardboard,cutout,stereotype,predictably,reversestereotypes',
#  'bad,film,bad,writing,good,actor,ugly,cartoon,crafted,paul,haggis,people,ca,nt,handle,anything,bold,stroke,storytelling,picture,painted,crayon',
#  'crash,depressing,little,nothing,provokes,emotion,teach,nothing,already,know,racism,prejudice,bad,thing',
#  'still,like,movie,s,empowerment,woman,s,enough,movie,like,one',
#  'brain,attempt,shutdown,part,primal,impulse,selfpreservation',
#  'wa,left,shattered,experience,watching,film,took,good,two,hour,fully,recover',
#  'movie,join,revenge,boogeyman,zombiez,part,hellish,trinity,horror,film',
#  'certainly,mean,distinction,good,way',
#  'mean,terrible,way',
#  'film,ha,redeeming,feature',
#  'everything,appalling',
#  'artless,camerawork,endlessly,present,u,ugliest,setting,imaginable,ie',
#  'story,beyond,stupid',
#  'script,wa,script',
#  'kid,annoying',
#  'lead,man,charismafree',
#  'utterly,without,merit,level,akin,torture',
#  'll,even,say,\x96,torture',
#  'maybe,would,reasonable,explanation,atrocity',
#  'pleasant,voyage,selfdiscovery',
#  'highly,unrecommended',
#  'premise,sound,stupid,s',
#  'yes,s,bad',
#  'nothing,recommend',
#  'excellent,performance',
#  'garbo,showed,right,bat,talent,could,carry,silent,era,wanted,see,silent,work,netflix,doe,nt,seem,stocking',
#  's,also,great,see,renowned,silent,screenwriter,france,marion,ha,nt,missed,step,going,silent,sound',
#  'movie,suffered,writing,needed,suspense',
#  'many,close,ups',
#  'movie,seemed,drag,hero,nt,really,work,freedom',
#  'movie,definitely,average,rent',
#  'll,love,1,movie,bad,0,bad,0,film,way,long,0,definitely,one,bad,one,0,movie,received,wa,great,quality,film,s,age,1,john,wayne,incredible,job,young,movie,industry,1,screen,presence,shined,thought,even,though,senior,actor,screen,1,think,must,see,older,john,wayne,film,1,really,nt,see,anyone,could,enjoy,movie,0,nt,think,ve,ever,seen,movie,half,boring,selfindulgent,piece,junk,0,probably,would,better,director,nt,spent,movie,showcasing,art,work,really,nt,noteworthy,0,another,thing,nt,really,like,character,got,punched,face,gallon,blood,would,spew,forth,soon,0,jamie,foxx,absolutely,ray,charles,1,performance,simply,genius,1,owns,film,spacek,owned,coal,miner,s,daughter,quaid,owned,great,ball,fire',
#  'fact,s,hard,remember,part,ray,charles,acted,played,man,1,ray,charles,legendary,1,ray,charles,life,provided,excellent,biographical,material,film,go,well,beyond,another,movie,musician,1,hitchcock,great,director,1,ironically,mostly,find,film,total,waste,time,watch,0,secondly,hitchcock,pretty,much,perfected,thriller,chase,movie,1,s,pandering,audience,sabotage,film,0,hence,whole,story,lack,certain,energy,0,plot,simply,rumble,like,machine,desperately,depending,addition,new,scene,0,usual,hitchcock,logic,flaw,0,mishima,extremely,uninteresting,0,chilly,unremarkable,movie,author,livingworking,chilly,abstruse,culture,0,flat,reenactment,nt,hold,attention,emotionally,adrift,stagy,0,rest,sits,awful,soldier,singing,song,masculinity,pledge,hairsplitting,purity,admiration,sword,etc,0,bore,piece,kill,momentum,movie,quicker,anyone,else,0,schrader,ha,made,resume,full,lousy,amateurish,film,0,first,watched,movie,80,loved,1,wa,totally,fascinated,music,dancing,everything,1,however,recently,watched,whole,thing,dvd,wa,completely,struck,extremely,stupid,storyline,wa,contained,hole,inconsistency,frankly,whole,lot,crap,horrid,dancing,wa,0,mean,realistic,world,would,never,gotten,ballet,repertory,whole,thing,wa,quite,pathetic,0,character,development,also,lacked,depth,0,woa,talk,awful,0,waste,time,0,wa,horrible,0,worst,sappiest,dialogue,could,go,0,really,made,unwatchable,wa,direction,0,poor,actor,0,ca,nt,even,tell,talent,pathetic,line,speak,director,gave,action,0,check,director,s,filmography,site,see,film,nt,chance,0,would,even,good,made,tv,flick,0,good,intention,made,film,great,film,might,one,greatest,film,ever,made,1,film,ha,great,actor,master,director,significant,theme,least,wouldbe,significant,theme,undertone,fifty,existential,worldweariness,aerial,scene,ought,thrilled,sens,imagination,character,one,might,deeply,care,1,regrettably,film,fails,0,movie,lack,visual,interest,drama,expression,feeling,celebration,patriotism,underline,narrative,0,actress,ha,worse,used,june,allison,movie,0,yet,enjoy,watching,1,unfortunately,bad,movie,plain,bad,0,bad,script,bad,direction,horrible,acting,make,one,plain,bad,0,dialogue,sucked,0,cinematographyif,called,thatsucked,0,soundtrack,sucked,0,acting,sucked,0,concert,sequence,sucked,0,wa,nice,1,wa,funny,1,wa,funny,1,overall,movie,wa,cheap,trash,0,movie,funny,considering,ridiculousness,0,came,feeling,angry,0,spoiler,whatever,else,ca,nt,said,surface,superbly,crafted,1,cinematography,simply,stunning,say,least,fx,nothing,stateoftheart,1,conceptually,show,offer,little,bit,everything,everybody,parent,kid,fantasy,andor,fx,fan,1,wa,nt,single,sour,note,struck,actingwise,either,surprisingly,solid,casting,1,thing,considered,job,well,done,1,thanks,good,movie,like,wa,done,released,1,one,best,mexican,movie,ever,one,le,understood,even,mexican,matter,identified,felt,1,rank,highly,great,noircrimedrama,incredible,performance,belmondo,lino,ventura,1,attention,given,every,character,complex,psychological,portrayal,detailing,loyalty,treachery,love,hope,tremendous,1,excellent,drama,excellent,thriller,excellent,film,1,best,melville,1,everything,film,simply,incredible,1,truly,take,journey,eye,soul,child,1,black,water,thriller,manages,completely,transcend,s,limitation,s,indie,flick,continually,subverting,expectation,emerge,intense,experience,1,performance,real,gripping,crocdodile,extremely,well,done,indeed,black,water,website,believed,s,used,real,crocs,swamp,location,fabulous,1,thoroughly,enjoyed,christopher,eccleston,took,control,tardis,continuation,series,1,m,sure,wa,trying,film,0,wa,turn,good,day,feeling,night,disturbing,memory,guess,succeeded,0,lot,beautiful,place,1,wa,forced,like,everything,movie,0,lame,0,s,movie,really,pi,ed,0,nt,even,get,started,jerky,camerawork,0,saw,theater,thought,wa,going,sick,0,summary,witticism,nt,witty,0,plot,well,said,d,let,one,go,0,acting,wa,bad,0,really,bad,0,even,billy,bob,could,nt,rise,script,wa,worse,0,camerawork,bad,0,rating,1,10,0,amazing,finale,possibly,best,trilogy,time,1,kieslowski,never,cease,amaze,1,one,fav ...
#  'find,movie,intelligent,even,masterful,say,s,intelligence,imagination,obviously,used,try,make,sense,pitiful,attempt,s,human,nature,try,make,sense,thing',
#  'one,thing,tolerate,political,incorrectness,well,m,artistic,freedom,suspension,disbelief,slavic,female,character,wa,much',
#  'fun,funny,movie',
#  'highly,entertaining,angle',
#  'feature,outlandish,array,memorable,psychotic,lovable,nut',
#  'enjoyment,get,see,run,around,play,game,dangerous',
#  'even,ha,sweet,moment',
#  'telephone,repair,man,wa,really,funny,reaction,nut,bitchy,bos,truly,genuine',
#  'character,film,tremendously,well,played',
#  'really,find,funny',
#  'actually,smart,movie',
#  'brilliant,twist,ending',
#  'love,1,ending,perfect,ll,shed,tear,1,thrilled,seeing,movie,like,1,never,forget,1,cult,cult,classic,1,ha,depth,character,man,underneath,0,malta,setting,dry,barren,dialogue,0,movie,terrible,0,hockey,scene,terrible,defensemen,playing,like,re,5,year,old,goalie,diving,shot,10,foot,wide,net,etc,0,nt,seen,nt,waste,time,0,call,movie,drama,ridiculous,0,started,watching,nt,believe,character,0,particular,relationship,bakery,assistant,waitress,nt,work,0,wa,superficial,movie,gave,feeling,wa,watching,play,rather,film,0,character,stagey,storyline,wa,lot,like,stage,farce,0,time,pyromaniac,waylaid,assistant,wa,bored,nt,care,happened,next,switched,0,glad,nt,pay,see,0,nt,laugh,even,smile,0,wa,nt,anything,one,big,yawn,0,really,good,show,watch,1,educational,child,1,8,year,old,1,barney,definitely,super,de,duper,1,pretty,funny,1,babie,bop,cute,1,kid,cool,1,storm,trooper,even,bad,enough,make,list,wonderfully,terrible,movie',
#  's,lame',
#  'guy,said,s,better,dialogue,potted,plant,ha,right',
#  'everything,movie,stupid',
#  'even,love,bad,movie,watch,movie',
#  'shameful',
#  'would,give,television,series,10,plus,could',
#  'writer,smack,think,best,actor,actress,bonus,showthese,character,real',
#  'must,say,taped,episode,find,watching',
#  'know,gave,10',
#  'nt,know,exactly,movie,latched,endearing,movie,ha,become,special,part,family,s,memory',
#  'totally,absolutely,recommend,movie,anyone,like,good,wholesome,family,movie,exactly',
#  'thing,four,kid,get,absolutely,hilarious,watch',
#  'one,best,movie,show,strong,sibling,bond',
#  'much,interesting,action,suspense,le,unneeded,controversy',
#  'everything,acting,cinematography,wa,solid',
#  'definitely,worth,checking',
#  'damian,talented,versatile,many,way,writing,portraying,different,character,screen',
#  'movie,ha,cutting,edge',
#  'pleased,know,modern,day,genius,letting,passion,art,drive,taking,u,audience',
#  'new,character,nt,memorable,found,forgetting,wa',
#  'felt,though,going,ireland,absolutely,nothing,whatsoever',
#  'nt,make,scared,horrified,make,sympathetic,towards,character,wa,simply,annoying',
#  'jerky,camera,movement,also,annoying',
#  'plot,wa,pretty,much,every,cheap,horror',
#  'wa,pathetic,attempt,give,character,depth,nt,really,work,rest,plot',
#  'guess,wa,supposed,clever,twist,shed,light,situation,wa,stupid',
#  'see,probably,leave,shelf',
#  'elia,koteas,jack,palance,play,good,role,angelina,hot,get,nakedbilly,drago,appears,cool,usual,cameo,sven,ole,thorsen,help,make,enjoyable,movie,good,acting,decent,budget',
#  'wa,awesome,movie,bought,ebay',
#  'really,loved,story,line,poler,bear,wa,kinda,cutebut,anyone,ha,question,fort,steele,ask,away',
#  'totally,unfunny,movie,top,pathetic,unrealistic,throughout,whole,90,minute,utter,torture,probably,looked,watch,70000,time',
#  'lucy,bell,much,higher,crap,sink,low,quite,depressing',
#  'movie,doe,make,sick,watching,slacker,make,excuse,stupid,action,90,minute',
#  'god,never,get,90,minute,back',
#  'think,wonderful,part,literally,full,wonder,excerpt,work',
#  'set,especially,designed,work,camera,amazing,stylized,beautiful,effective',
#  'could,used,exemplar,set,designer',
#  'story,powerful,exploration,nature,man,art',
#  'watching,film,wanted,learn,work,artist',
#  'highly,recommend,movie,anyone,interested,art,poetry,theater,politics,japanese,history',
#  'wind,lion,see,wonderful,rendering,america,s,imperial,age',
#  'make,story,different,terrific,production,value,faultless,photography,composition,editing,terrific,casting,underappreciated,brian,keith,playing,bully,teddy,vivid,history',
#  'though,wind,lion,told,largely,eye,son,every,member,family,identify,one,character,whether,sean,connery,s,noble,brigand,candace,bergen,s,feisty,heroine,john,huston,s,wily,john,hay,steve,kanaly,s,spiffy,radiant,ruthless,cando,lieutenant,roosevelt,s,big,stick',
#  'high,adventure,best',
#  'think,wa,robert,ryans,best,film,portrayed,someone,like,father,wa,schizophrenic,real,life,father,although,never,murdered,anyone,wa,affected,second,world,war,made,worse',
#  'humour,get,get,day,wa,apt',
#  'mother,brother,saw,robert,ryan,portraying,type,man,wa,good,imitation,type,individual,wa,impressed',
#  'almost,song,cover,girl,oldfashioned,tuneful',
#  'annoying,thing,cover,girl,way,rita,hayworth,put,pedestal',
#  'unfortunately,cover,girl,example,hollywood,used,exploit,woman,financial,gain',
#  'nonlinear,narration,thus,many,flashback,every,part,articulated,quite,well',
#  'good,cinematography,also,make,monica,bellucci,look,beautiful',
#  'good,commentary,today,s,love,undoubtedly,film,worth,seeing',
#  'people,first,timer,film,making,think,excellent,job',
#  'wa,popular,wa,cinema,good,house,good,reaction,plenty,laugh',
#  's,feelgood,film,s,felt,came,cinema',
#  'ha,northern,humour,positive,community,represents',
#  'rather,enjoyed',
#  'liked',
#  'could,nt,take,seriously',
#  'really,created,unique,feeling,though',
#  'vivian,schilling,excellent,job,script',
#  'world,better,95,garbage,theatre,today',
#  'role,wa,played,well',
#  'screamy,masculine,right',
#  'camera,really,like,movie',
#  'would,casted,role,ready,script',
#  'european,movie,nice,throwback,time,student,1980,s,experience,living,abroad,interacting,nationality,although,circumstance,slightly,different',
#  'fan,movie,sucked,really,bad',
#  'even,worse,ticker',
#  'movie,wa,bad',
#  'like,3,4,building,used,couple,location,maybe,poor,hummh',
#  'blew',
#  'movie,excellent,angel,beautiful,scamp,adorable,little,yelp,scared,funniest,part,scamp,caught,curtain,angel,scamp,singing,ive,never,feeling,beforei,totally,recommend,movie,coming,special,edition,june,20the,cover,ha,scamp,garbage,angel,underneath,lid',
#  'cant,explain,movie,romantic,charming,hilarious,adorablethe,junkyard,scene,funny,junkyard,dog,something,specialtoo,funny,laughed,kid,love,itbuy,come,ha,new,feature',
#  'chosen,tortured,disgusting,piece,blatant,american,propaganda',
#  'show,made,american,stupid,full,hatred,clichés,admitted,elsewhere',
#  'almost,everyone,involved,must,return,school,acting,utterly,predictable,bad,script,pile,garbage,round',
#  'wish,could,enter,negative,value,admins',
#  'set,bad,would,nt,look,place,thunderbird,episode',
#  'use,slowmotion,needlessly,repeat,throughout,movie,well,backed,bad,acting,bad,kind,word,continuity,scene,thrown,reason,whatsoever,vehicle,looked,like,made,corn,flake,box,directorial,style,bordered,stupidity',
#  'oh,yeah,storyline,wa,pathetic',
#  'hate,writing,bad,review,film,especially,really,like,star,film,bad,nt,believe,one,second,anyone,could,proud',
#  'filmmaker,director,would,hide,head,sand,d,spent,whatever,amount,money,time,movie',
#  'short,wa,monumental,waste,time,energy,would,recommend,anyone,ever,see,film',
#  'came,free,dvd,player,bought,still,turned,thing,halfway,wa,embarrassed,howell',
#  '110,setting,010',
#  'interesting,premise,billy,drago,always,good,dangerous,nutbag,side,note,d,love,see,drago,stephen,mchattie,lance,hendrikson,flick,together,talk,raging,cheekbone',
#  'soundtrack,wa,nt,terrible,either',
#  'acting,even,professional,drago,debbie,rochon,wa,terrible,directing,worse,perhaps,contributory,former,dialog,chimplike,camera,work,barely,tolerable',
#  'still,wa,set,got,big,10,oyvey,scale',
#  'yes,simplifying,thing,sake,brevity,really,core,problem,film,ha,much,going,without,real,fulfilling,explanation',
#  'good,job,quite,amusing',
#  'convoluted,plot,nt,convince,much,film,wa,watched,weird,questioning,glance',
#  'let,girlfriend,talk,seeing,bad,idea,hated',
#  'last,15,minute,movie,also,bad,well',
#  'bela,lugosi,wa,totally,extraneous,intoning,odd,line',
#  'acting,wa,decidely,wooden,though,worse,period,universal,b,movie',
#  'like,armand,assante,cable,company,s,summary,sounded,interesting,watched,twice,already,probably',
#  'believe,screenwriter,good,job,tying,loose,end',
#  '810,score,mostly,plot',
#  'wo,nt,say,nt,like,spoiler,nt,want,one,believe,film,worth,time',
#  'wow,bad,film',
#  'frightening,least,barely,comprehensible',
#  'plot,doe,nt,hang,together,acting,absolutely,appalling',
#  'even,good,camp,value',
#  'wa,nt,expecting,oscar,material',
#  'd,iq,particularly,stupid,mollusk,see,one,coming',
#  'film,use,word,loosely,insult,moviegoing,public',
#  'someone,involved,knew,string,together,narrative',
#  'get,1,10,simply,s,nothing,lower',
#  'one,watched,recently,fox,movie,channel,wa,disappointed',
#  'know,wa,contract,player,little,control,script,acting,wa,bad,script',
#  'victor,mclaglen,wa,even,bad,brian,donlevy,wa,almost,unrecognizable',
#  'considering,relation,screen,taylor,stanwyck,wa,surprising,little,chemistry,wa,screen,two',
#  'premise,film,wa,ridiculous,president,us',
#  'death,row,scene,entirely,unmoving',
#  'thing,worse,taylor,s,acting,wa,stanwyck,s,singing',
#  'whatever,producer,wa,going,missed,entirely',
#  'wa,deeply,impressed,character,played',
#  'knew,saw,film,great,thing,come,gifted,actor',
#  'cheap,cheerless,heist,movie,poor,characterisation,lot,underbite,style,stoic,emoting,think,chow,yun,fat,better,tomorrow,cheesy,clichés,thrown,abandoned,factory,ready,poorly,executed,flying,judo,roll,la,john,woo',
#  'even,squib,look,awful',
#  'point,proceeding,doe,look,remotely,like,america',
#  'plot,derivative,predictable,ending,like,mercy,killing',
#  'awful,dialogue,hopeless,overacting,everyone,get,shot,top,real,waste,space,time',
#  'wa,uneasy,bad,movie,wa,scared',
#  'dialogue,composed,thing,make,little,sense',
#  '30,minute,footage,wasted,show,mediocre,elderly,actor,awkwardly,babbling,overwrought,pseudosatanic,gibberish,corny,enough,make,teen,goth,blush,almost,always,olde,english,sometimes,latin,may,may,made,word',
#  'directing,sloppy,best',
#  'hackneyed,writing,certainly,made,even,worse,bad,directing',
#  'course,acting,blah',
#  'acting,whole,cast,could,put,scale,balanced,perfectly,overacting,underacting',
#  'finally,get,ending,would,ve,great,handled,competent,people,jerry,falwell',
#  'loved,movie,wa,great,portrayal,family,s,share,ups,end,knew,special,love',
#  'seen,many,movie,starring,jaclyn,smith,god,wa,one,best,though,came,12,year,ago',
#  'movie,contained,allstar,cast,loved,wa,opened,eye,see,actor,nt,seen',
#  'movie,wa,kind,long,length,enjoyed,every,minute',
#  'overall,rate,movie,10,110,scale',
#  'lifetime,doe,air,enough,anyone,know,store,sell,let,know,musthave',
#  'particularly,remember,sens,assaulted,strident,cord,music,would,blare,little,warning,even,le,meaning',
#  'sort,pap,screened,afternoon,punish,unemployed,job',
#  'totally,different,load,understatement,black,comedy,film,get,see,remember',
#  'movie,creates,universe,fascinating,every,way',
#  'movie,really,got',
#  'see',
#  'really,hope,team,behind,movie,make,movie,continue,kinda,weird,style',
#  'forgot,casting,superb,trond,fausa,aurvåg,perfect,role,bothersome,man,doe,nt,understand',
#  'movie,good,humorous,comment,life,2006',
#  'found,move,beautiful,enjoyable,uplifting',
#  'initially,local,site,film,wa,filmed,buffalo,intrigued',
#  'later,found,lost,power,film',
#  'entire,audience,applauded,conclusion,film',
#  'left,theater,lilt,step,joy,heart,hope,human,race',
#  'duris,ha,wholesome,appearance,give,fine,performance',
#  'rest,cast,also,play,well',
#  'cinematography,noteworthy,including,fine,view,barcelona,famed,gaudi,tower',
#  'ten,minute,film,started,second,thought',
#  'half,way,film,started,dislike',
#  'time,film,ended,disliked,despised',
#  'film,lack,convincing,script',
#  'script,look,rough,draft,wa,written,shooting,began,finished,script,wa,completed',
#  'thing,happen,character,personality,change,plot,twist,occur,real,reason,script,call',
#  'cast,good',
#  's,worth,checking',
#  'probably,irritating,show,ever,seen,entire,life',
#  'indescribably,annoying,idiotic,show,ever,seen',
#  'everything,bad',
#  'could,understand,kind,idiot,would,produce,mess,first,place,mention,several,season',
#  'script,bad,bad,\x96,contains,cheesiness,unethical,joke,normally,see,rated,r,nc17,movie',
#  'casting,also,horrible,cause,see,really,really,bad,actor,period',
#  'final,word,show,real,torture',
#  'zillion,time,away,reality',
#  'watching,washing,machine,twirling,around,would,nt,hurt,eye,much,show',
#  'rating,010,grade,z,note,show,bad,even,mother,cast,pull,daughter,show',
#  '20th,century,fox,s,road,house,1948,quite,silly,noir,implausible,unmitigated,bore,movie',
#  'full,unconvincing,cardboard,character,blandly,written,edward,chodorov,also,produced,surprisingly,directed,jean,negulesco,one,would,expect,great,deal',
#  'widmark,character,turn,unintentionally,comical',
#  'losing,marble,early,proceeding,totally,implausible,unconvincing',
#  'nt,enough,mess,movie,picture,also,marred,constant,use,studio,set,indoor,exterior',
#  'whatever,prompted,documentary,beyond',
#  'serious,spoiler,movie,wa,huge,disappointment',
#  'many,problem,dont,know,start',
#  'cast,wa,great',
#  'steve,martin,delivers,really,funny,performance,middleaged,upper,class,uptight,white,guy',
#  'add,betty,white,jean,smart,great,cast,everyone,played,part,really,well',
#  'movie,make,lot,serious,mistake',
#  'first,enough,racial,stereotype,racial,joke,offend,everyone',
#  'movie,littered,overt,racial,slur,towards,black,cast,member,return,white,depicted,moron,boob',
#  'putting,race,card,aside,let,look,major,flaw,film,destroy,latifa,s,character',
#  'real,plot',
#  'wouldnt,see,movie,free',
#  'steamboat,willie,amazingly,important,film,cinema,history',
#  'second,appearance,mickey,mouse,following,silent,plane,crazy,earlier,year,probably,famous,film,mostly,wa,groundbreaking',
#  'nt,yet,hear,mickey,speak,ton,sound,effect,music,throughout,film,something,take,granted,wa,huge,crowd,pleaser,1928',
#  'however,seeing,short,25,year,wa,amazed,timeless,film,actually',
#  's,adorable,seeing,mickey,playing,turkey,straw,highly,imaginative,occasionally,cruel,way',
#  'clever,real,crowdpleaser,film,still,rank,among,mickey,s,best,film,even,80,wonderful,year',
#  'bipolarity,ruthless,thug,one,minute,ruthless,killer,next,minute,luv,s,diaper,commercial,completely,unconvincing',
#  'm,terribly,disappointed,film,would,receive,many,award,accolade,especially,far,deserving,work,film',
#  'original,body,soul,1947,masterpiece',
#  'john,garfield,ann,revere,lilli,plmer,william,conrad,canada,lee,filmed,one,greatest,cinematographer,ever,grace,screen,james,wong,howe',
#  'nt,think,redeeming,quality,remake',
#  'may,bad,film,ever,made',
#  'bad,well,s,bad',
#  'movie,solid,example,bad,plot,bad,idea,way',
#  's,shame,see,good,actor,like,thomerson,james,make,living,mess,like',
#  'thought,wa,bad',
#  'film,terrible,credit,1986,version,wa,watchable',
#  'let,s,start,problems\x97the,acting,especially,lead,professor,wa,bad',
#  'script,big,flawed,mess',
#  'best,example,dumb,writing,s,established,turn,zombiestudents,back,human,removing,necklace,containing,piece,meteorite',
#  'director,paul,matthew,also,wrotedirected,weak,1995,monster,movie,grim,clearly,doe,nt,know,pace,film',
#  'movie,terribly,boring,place',
#  'lighting,awful',
#  'film,look,cheap,bland',
#  'one,disappointing,aspect,lack,notable,gore',
#  'convention,never,worked,well,past,certainly,doe,nt,work',
#  'visual,effect,awful',
#  'cg,opening,sequence,space,looked,like,could,created,microsoft,slideshow,god,s,sake',
#  'explosion,gas,tank,end,wa,awful',
#  'okay,like,consider,fair,critic,ll,give,credit,credit,s,due,creature,effect,actually,pretty,cool',
#  'got,ta,love,closeups,slimy,drooling,teeth',
#  'sum,film,breeder,terrible,cheaply,made,horror,movie,avoided,like,ebola,virus',
#  'recommended',
#  'almost,unbearable,watch,screen,ha,little,charisma,terrible,comedic,timing',
#  'aside,s,terrible,lead,film,ha,load,debit',
#  'understand,s,supposed,cheap,popcorn,comedy,doe,nt,mean,ha,completely,insult,intelligence,writing,incredibly,hackneyed,border,offensive',
#  'lewis,black,s,considerable,talent,wasted,incendiary,unrestrained,pg13,rating,certainly,wo,nt,allow',
#  'film,s,sole,bright,spot,wa,jonah,hill,look,almost,unrecognizable,fan,recent,superbad,due,amount,weight,lost,interim',
#  'originality,freshness,first,movie,spent,remake,little,else,offer',
#  'budget,wa,evidently,limited',
#  'wa,reflected,cast,also,belowpar,script,borrowed,much,earlier,classic',
#  'however,wa,decent,acting,action,location,work,balance,thing',
#  'filmiing,wa,le,expansive',
#  'failed,convey,broad,sweep,landscape,great,part,original',
#  'generally,lacked,imagination',
#  'recommended',
#  'possible,movie,get,worse',
#  'plot,keep,going,first,place',
#  'even,woman,finally,show,sign,improvement,expected,thing,happen,time,film,might,far,asleep',
#  'beware,trashy,cult,movie,trash,period',
#  'ca,nt,believe,s,even,sequel',
#  'precisely,giving,bad,review',
#  '90,s,child,truly,enjoyed,show,proudly,say,enjoyed,big,time,even,classical,wb,cartoon',
#  'tiny,toon,kept,90,s,vibe,delivered,one,popular,funny,underrated,cartoon,ever,created',
#  'memory,murky,say,enjoyed,every,single,episode,product,related,show',
#  'easily,none,cartoon,made,laugh,tender,way,getting,dark,sitcom,oriented,teenager',
#  'character,funny,peculiarity,true,lead,character',
#  'every,single,character,wa,hilarious,deserved,called,lead',
#  'way,plug,u,unless,go,converter',
#  'good,case,excellent,value',
#  'great,jawbone',
#  'tied,charger,conversation,lasting,45,minutesmajor,problem',
#  'mic,great',
#  'jiggle,plug,get,line,right,get,decent,volume',
#  'several,dozen,several,hundred,contact,imagine,fun,sending,one,one',
#  'razr,owner,must',
#  'needle,say,wasted,money',
#  'waste,money,time',
#  'sound,quality,great',
#  'wa,impressed,going,original,battery,extended,battery',
#  'two,seperated,mere,5,ft,started,notice,excessive,static,garbled,sound,headset',
#  'good,quality,though',
#  'design,odd,ear,clip,comfortable',
#  'highly,recommend,one,ha,blue,tooth,phone',
#  'advise,everyone,fooled',
#  'far,good',
#  'work,great',
#  'click,place,way,make,wonder,long,mechanism,would,last',
#  'went,motorola,s,website,followed,direction,could,get,pair',
#  'bought,use,kindle,fire,absolutely,loved',
#  'commercial,misleading',
#  'yet,run,new,battery,two,bar,s,three,day,without,charging',
#  'bought,mother,problem,battery',
#  'great,pocket,pc,phone,combination',
#  've,owned,phone,7,month,say,s,best,mobile,phone,ve',
#  'nt,think,instruction,provided,helpful',
#  'people,couldnt,hear,talk,pull,earphone,talk,phone',
#  'doe,nt,hold,charge',
#  'simple,little,phone,use,breakage,unacceptible',
#  'product,ideal,people,like,whose,ear,sensitive',
#  'unusable,moving,car,freeway,speed',
#  'two,year,left,contract,hate,phone',
#  'car,charger,well,ac,charger,included,make,sure,never,run,juicehighy,recommended',
#  'need,least,3,min,get,phone,book,time,first,turn,phonebattery,life,short',
#  'ha,kept,well',
#  'poor,talk,time,performance',
#  'case,great,work,fine,680',
#  'worthless,product',
#  'ha,great,camera,thats,2mp,pic,nice,clear,great,picture,quality',
#  'wa,impressed,product',
#  'nice,headset,priced,right',
#  'hear,garbage,audio',
#  'excellent,bluetooth,headset',
#  'ha,feature,want',
#  'right,mind,gon,na,buy,battery',
#  'arguing,verizon,regarding,dropped,call,returned,phone,two,day',
#  'case,seems,well,made',
#  'disappointed,battery',
#  'loud,enough,doe,nt,turn,like',
#  'good,protection,doe,make,phone,bulky',
#  'usable,keyboard,actually,turn,pda,realworld,useful,machine,instead,neat,gadget',
#  'phone,pretty,sturdy,ve,never,large,problem',
#  'love,thing',
#  'everything,fine,reasonable,price,ie',
#  'disappointed',
#  'even,dropped,phone,stream,wa,submerged,15,second,still,work,great',
#  'happy,510,complaint,one,regarding,sound,quality,end',
#  'button,bad',
#  'essentially,forget,microsoft,s,tech,support',
#  'really,recommend,faceplate,since,look,nice,elegant,cool',
#  'headphone,great,find,think,perhaps,best,purchase,ve,made,last,several,year,seriously',
#  'buy,different,phone',
#  'hold,phone,particular,angle,party,hear,clearly',
#  'one,big,drawback,mp3,player,button,phone,s,front,cover,let,pause,skip,song,lock,second',
#  'week,later,activated,suddenly,died',
#  'feel,comfortable,headset,wear,glass,get,way,sometimes',
#  'great,ipod',
#  'device,great,several,situations1',
#  'mic,doe,nt,work',
#  'even,bmw,3,series,fairly,quiet,trouble,hearing,person,saying',
#  'great,choice',
#  'nice,docking,station,home,work',
#  'beautiful,phone',
#  'love,product',
#  'buy,d807,wrongly,advertised,d807',
#  'great,little,item',
#  'love,phone,handy,ha,lot,feature',
#  'purchased,within,2,day,wa,longer,working',
#  'wear,everyday,hold,well',
#  'good,bargain',
#  'well,packaged,arrived,time,work,intended',
#  'battery,run,quickly',
#  'item,worked,great,broke,6,month,use',
#  'headset,easy,use,everyone,love',
#  'phone,work,great',
#  'construction,headset,poor',
#  'product,wa,excellent,work,better,verizon,one,boy,wa,cheaper',
#  'phone,load,super',
#  'product,cost,much,one,doe,expect,work,far,better,greater,ease,thing,doe',
#  'made,sturdy',
#  'worked,great',
#  'ear,bud,play,music,one,ear',
#  'dont,waste,money',
#  'order',
#  'plan,use,car,forget',
#  'found,product,waaay,big',
#  'best,ve,found,far,ve,tried,2,bluetooths,one,ha,best,quality,listener,well,ease,using',
#  'm,disappointed,decision',
#  'integrated,seamlessly,motorola,razr,phone',
#  'buyer,beware,could,flush,money,right,toilet',
#  'definitely,bargain',
#  'price,wa,good,free,shipping,wa,good,purchase',
#  'received,supposedly,new,motorola,375,apparently,wa,match,phone,charger',
#  'pro,good,camera,nice,picture,also,ha,cool,style,like,black,white',
#  's,huge,design,flaw,unless,m,using,correctly,nt,think,case',
#  'love,350,headset,jabra350,bluetooth,headset,great,reception,good,ear,piece,comfortable,fit',
#  'camera,although,rated,impressive,13,megapixels,render,image,fall,well,expectation,relatively,high,resolution',
#  'purcashed,car,charger,doe,work',
#  'sound,quality,end,excellent,use,headset,call,wife,ask,wife,use,headset,call,2',
#  'phone,slim,light,display,beautiful',
#  'little,geeky,think,thats,sex,toast,rock,ooze,sex,right,battery,embedded,sleek,stylish,leather,case',
#  'great,product,fast,shipping',
#  'absolutely,great',
#  'keyboard,nice,compromise,full,qwerty,basic,cell,phone,number,keypad',
#  'got,phone,around,end,may,m,completely,unhappy',
#  'comfortable,ear',
#  'ha,winner,u',
#  'setup,could,nt,simpler',
#  've,tried,several,different,earpiece,cell,phone,jabra,one,first,one,ve,found,fit,ear,comfortably',
#  'could,get,strong,enough,signal',
#  'iam,pleased,purchase',
#  'bad,quality',
#  'get,job,done',
#  'great,audio',
#  'basically,service,wa,bad',
#  'work,cell,phone,plug,set,charger',
#  've,bluetooth,week,really,like',
#  'bt,headset,wa,disapoinment',
#  'small,nt,even,realize,getting,used',
#  'accompanied,software,almost,brilliant',
#  'headset,work,great,wa,packaged,nicely,avoid,damage',
#  'definitly,recommend',
#  'buyer,careful',
#  'majority,logitech,earbud,headset,failed',
#  'good,stuff,price',
#  'headset,work,peachykeen',
#  'house,wa,getting,dropped,coverage,upstairs,coverage,basement',
#  'voice,recognition,tremendous',
#  'waste',
#  'several,different,2,minute,call,experienced,5,drop,wa,area,5,bar',
#  'wa,happy,item',
#  'disappointed',
#  'phone,take,forever,charge,like,2,5,hour,literally',
#  'got,phone,reccomendation,relative,m,glad',
#  'waste,time',
#  'reception,poor',
#  'item,stated,included,description,included',
#  '3,month,screen,went,black,sudden',
#  'wa,hoping',
#  'audio,quality,poor,poor',
#  'absolutely,problem,headset,linking,8530,blackberry,curve',
#  'know,sound,funny,seemed,like,sketchy,technology,would,nt,work,wellwell,one,work,great',
#  've,bought,5,wired,headphone,sound,better',
#  'phone,fast,sending,kind,message,web,browsing,significantly,faster,previous,phone,used',
#  'nice,quality,build,unlike,cheap',
#  'item,fantastic,work,perfectly',
#  'love,color',
#  'w810i,superb',
#  'whine,internet,goesthe,use,thing,le,like',
#  'great,charger',
#  'essentially,communication,tool,doe,communicate',
#  'work,like,charm,work,one,got,phone',
#  'still,maintain,monkey,nt,make,headphone,obviously,nt,share,enough,dna,copy,design,human',
#  'great,value',
#  'doe,nt,work,bougth,l7c,working',
#  'look,sharp,screen,nice,clear,great,graphic',
#  'doe,nt,last,long',
#  'one,thing,hate,mode,set,button,side',
#  'excellent,service',
#  'thank,wasting,money',
#  'audio,quality,poor',
#  'igo,charger,tip,really,great',
#  'file,browser,offer,option,one,needshandsfree,great',
#  'superb,phone,great,network',
#  'connected,wife,s,bluetooth,motorola,hs850,phone,worked,like,charm,whether,phone,wa,pocket,case',
#  'put,latest,v115g,like,slow,crawl,lock,every',
#  'recognizes,phone,storage,device',
#  'like,loud,buzzing,override,conversation,phone',
#  'nt,buy,product',
#  've,bluetoooth,headset,time,still,comfortable,way,fit,ear',
#  'sound,quality,good,functionality,awesome',
#  'phone,thorn,side,really,abhor',
#  'recently,problem,could,stay,connected,10,minute,disconnected',
#  'incredible',
#  'design,flaw',
#  'great,phone',
#  'waste,13,buck',
#  'check,voice,mail,night,keypad,backlight,turn,second,first,message,m,lost',
#  'replacement,died,week',
#  'ring,tone,overall,good,phone,buy',
#  'lately,extremely,nice,helpful,phone',
#  'problem,wit,hit,dropping,signal',
#  'impressed',
#  'light,weight,hardly,notice',
#  'll,love,thin',
#  'bad,choice',
#  'pleather,case,doe,nt,fit',
#  'useless,phone,simply,deaf',
#  'color,even,prettier,thought,would,graphic,incredibly,sharp',
#  'think,wa,good,investment',
#  'make,strange,ticking,noise,end,call',
#  'best,electronics,available,fm,transmitter',
#  'battery,last,hour',
#  'great,headset,impressed,h500',
#  '12,mega,pixel,camera,part,phone,reasonably,good7',
#  've,nearly,2,year,ha,worked,great',
#  'good,transmit,audio',
#  'sending,back',
#  'bother,contacting,company,dollar,product,learned,lesson,bought,form,online,anyway',
#  'hate,earbugs,avoid,phone,mean',
#  'great,price,also',
#  'range,decent,ve,able,roam,around,house,phone,living,room,receptionsound,quality,issue',
#  'fast,service',
#  'would,highly,recommend',
#  'would,recommend',
#  'also,nt,like,button,felt,like,would,crack,use',
#  'worst,phone,ever',
#  'm,still,infatuated,phone',
#  'freeze,frequently4',
#  's,kind,embarrassing,use,look,mostly,s,embarrassing,childlike,company',
#  'simple,lightweight,great,fit',
#  'd,expected,better,consumer,experience,motorola',
#  's,horrible,tick,sound,background,call,never,experienced',
#  'certainly,comfortable,functionality,decent',
#  'usually,nt,like,headband,one,lightweight,doe,nt,mess,hair',
#  'm,bit,disappointed',
#  'phone,year,tell,great',
#  'ordered,sony,ericsson,w810i,think,worked,thats,first,used',
#  'battery,completely,useless',
#  'big,waste,time',
#  'nt,waste,one',
#  'great,sound,service',
#  'really,pleased,product,far',
#  'one,favorite,purchase,ever',
#  'best,bluetooth,market',
#  'authentic,leather,nice,shine,comfort,i,recommend,case',
#  'wa,excited,get,headset,thought,wa,really,cute',
#  'make,mistake',
#  'big,disappointment,calendar,sync',
#  'phone,wa,unusable,wa,new',
#  'worst,customer,service,ever',
#  'additional,ear,gel,provided,instruction,whatsoever',
#  'defeat,purpose,bluetooth,headset',
#  'worth,every,penny',
#  'excellent,wallet,type,phone,case',
#  'nice,headphone,price,work,great',
#  'internet,excrutiatingly,slow',
#  'comfortable,wear,well,probably,important,aspect,using,case',
#  's,fit,like,glove,strong,secure,durable',
#  'gosh,best,phone,ever',
#  's,attractive,appears,good,quality',
#  'love,feature,form,factor',
#  'product,strong,rubberpetroleum,smell,wa,unbearable,caused,return',
#  'poor,quality,service',
#  'cable,look,thin,flimsy,scary',
#  'great,earpiece',
#  'excellent,hand,free,tool',
#  'great,using,home,stereo',
#  'good,product,incredible,value',
#  'month,s,worked,flawlessly,far',
#  'work,great',
#  'absolutel,junk',
#  'one,nt,work,either',
#  'battery,life,real,good',
#  'returned,8,hour,later',
#  's,great,item',
#  'nt,waste,money',
#  'love,headset',
#  'drain,player,may,also,potentially,fry',
#  'worked,perfectly',
#  'unreliable,m,giving',
#  'gave,5,star,sound,quality',
#  'avoid,one',
#  'reversible,plug,work,great',
#  'wasted,little,money,earpiece',
#  'good,phone',
#  'best,rotating,feature,helpful',
#  'comfort,whole,family',
#  'good,product,good,seller',
#  'love,bluetooth',
#  'first,doe,nt,wear,well',
#  'impressed,headset,plantronics',
#  'got,wa,small,adorable',
#  'great,phone',
#  'would,nt,recommend,buying,product',
#  'piece,junk',
#  'poorly,contstruct,hinge',
#  'item,great,installed,let,charged,overnite,ha,working,good,every,since,problem',
#  'great,phone',
#  'nt,buy',
#  'excellent,phone',
#  'purchase,phone',
#  'voice,recognition,thru,handset,excellent',
#  'hand,best,phone,ve,ever',
#  'work,great,cat,attacked,phone,scratched,protective,strip,instead,destroying,screen',
#  'one,work,wa,priced,right',
#  'customer,service,wa,terrible',
#  'battery,life,still,long,enough,motorola,razor,v3i',
#  'sending,back',
#  'know,made,wise,decision',
#  'someone,shouldve,invented,sooner',
#  'good,price',
#  'everything,worked,first,trythe,device,wa,certainly,engineered,clever,way,construction,feel,good',
#  'received,quickly,work,great',
#  'ha,working,great',
#  'many,people,complained,found,headset,s,microphone,wa,weak',
#  '5year,old,nokia,2160,tracfone,hold,charge,lot,better',
#  'care,consumer,one,bit',
#  'good,battery,got,really,fast',
#  'instruction,manual,lacking',
#  'also,slim,enough,fit,alarm,clock,docking,station,without,removing,case',
#  'phone,hold,charge,like,wa,new',
#  'battery,unreliable,well,service,use,antena',
#  's,uncomfortable,sound,quality,quite,poor,compared,phone,razr,previous,wired,headset,plugged,lg',
#  'gotten,lot,compliment',
#  'definitely,must,state,doe,allow,cell,phone,usage,driving',
#  'want,money,back',
#  'love,device',
#  'also,happy,price',
#  'ordered,product,first,wa,unhappy,immediately',
#  'ngage,still,lacking,earbuds',
#  'wa,able,voice,dialing,car,problem',
#  '23,bar,cell,phone,home,cant,hear,anything',
#  'good,item,low,price',
#  'howeverthe,riingtones,best,neither,game',
#  'plug,work,well',
#  'amazon,suck',
#  'rip,charge,shipping',
#  'comfortable',
#  'battery,working,well,replacement,original,came,phone,2,year,ago',
#  'reception,excellent',
#  'fit,comfortably,either,ear,sound,clear,loud,charge,last,couple,day',
#  'clear,quality,sound,nt,mess,sound,ipod,since,sound,button,headset',
#  '1,long,lasting,battery,nt,recharge,frequentyly,flip,phone,2',
#  'obviously,problem,adhesive',
#  'disappointing',
#  'wa,inexpensive,piece,would,still,expected,better,quality',
#  'practically,useless,add,kind,boost,reception,bought',
#  'excellent,sound,quality',
#  'wa,happy',
#  'piece,junk,broke,phone,2,day',
#  'new,battery,work,great,phone',
#  'worst,customer,service',
#  've,dropped,phone,time,say,even,concrete,phone,still,great,knock,wood',
#  'reception,terrible,full,static',
#  'good,audio,quality',
#  'little,device,ha,transformed,organizational,capability,made,life,whole,lot,easier',
#  'wa,sitting,vehicle,cradle,belt,headset,lost,signal',
#  'jerk,phone',
#  'work,like,charm,work,advertised',
#  'comfortable,nice,range,good,battery,life',
#  'network,coverage,los,angeles,horrible',
#  'excellent,starter,wireless,headset',
#  'loudspeaker,option,great,bumper,light,appealing',
#  'thing,think,could,improve,sound,leak,headset',
#  'first,reception,suck,never,2,bar,ever',
#  'phone,get,extremely,hot',
#  'microphone,also,work,well,according,people,called,applifies,everything',
#  'nice,design,quality',
#  'also,phone,dropped,case,going,save,specially,dropped,face',
#  'light,easy,use,ha,clear,reception,transmission',
#  'bad,fit,way,big',
#  'definitely,wa,good,s11',
#  'awesome,device',
#  'waste,money',
#  'ordered,motorola,data,cable,got,well,finished,working,product',
#  'love,phone',
#  'wa,looking,headset,long,time,ve,got,could,nt,happier',
#  'll,drivng,along,headset,start,ringing,reason',
#  'display,excellent,camera,good,year',
#  'battery,life,also,great',
#  'worst,phone,ve,ever,month',
#  'good,item,worked,started,problem,auto,reverse,tape,player',
#  'embarassing,also,ear,hurt,try,push,ear,plug,ear',
#  'protects,phone,side',
#  'average,phone,bad,battery,life,operates,weak,network',
#  'clear,skype,call,long,battery,life,long,range',
#  'soyo,technology,suck',
#  'great,hand,free,device',
#  'even,take,self,portrait,outside,exterior,display,cool',
#  'problem,others,mentioned',
#  'trying,many,many,handsfree,gadget,one,finally,work,well',
#  'magical,help',
#  'worst,piece,crap,ever,along,verizon,customer,service',
#  'poor,sound,quality',
#  'best,phone,market',
#  'worked,well',
#  'company,shipped,product,promptly,work,well',
#  'exactly,wanted',
#  'picture,resolution,far,comparablypriced,phone,offering,today',
#  'great,deal',
#  'excellent,product,satisfied,purchase',
#  'highly,recommend,encourage,people,give,try',
#  'better,d,expect',
#  'using,earpiece,left,right,thing,stay,ear',
#  'great,product,price',
#  'sound,good,reasonably,priced,effective,simple',
#  'still,waiting,m,sure,item,would,work,well,ever,recieve',
#  'wow,loved,place',
#  'crust,good',
#  'tasty,texture,wa,nasty',
#  'stopped,late,may,bank,holiday,rick,steve,recommendation,loved',
#  'selection,menu,wa,great,price',
#  'getting,angry,want,damn,pho',
#  'honeslty,nt,taste,fresh',
#  'potato,like,rubber,could,tell,made,ahead,time,kept,warmer',
#  'fry,great',
#  'great,touch',
#  'service,wa,prompt',
#  'would,go,back',
#  'cashier,care,ever,say,still,ended,wayyy,overpriced',
#  'tried,cape,cod,ravoli,chicken,cranberry,mmmm',
#  'wa,disgusted,wa,pretty,sure,wa,human,hair',
#  'wa,shocked,sign,indicate,cash',
#  'highly,recommended',
#  'waitress,wa,little,slow,service',
#  'place,worth,time,let,alone,vega',
#  'like',
#  'burrittos,blah',
#  'food,amazing',
#  'service,also,cute',
#  'could,care,le,interior,beautiful',
#  'performed',
#  's,right,red,velvet,cake,ohhh,stuff,good',
#  'never,brought,salad,asked',
#  'hole,wall,ha,great,mexican,street,taco,friendly,staff',
#  'took,hour,get,food,4,table,restaurant,food,wa,luke,warm,sever,wa,running,around,like,wa,totally,overwhelmed',
#  'worst,wa,salmon,sashimi',
#  'also,combo,like,burger,fry,beer,23,decent,deal',
#  'wa,like,final,blow',
#  'found,place,accident,could,happier',
#  'seems,like,good,quick,place,grab,bite,familiar,pub,food,favor,look,elsewhere',
#  'overall,like,place,lot',
#  'redeeming,quality,restaurant,wa,wa,inexpensive',
#  'ample,portion,good,price',
#  'poor,service,waiter,made,feel,like,wa,stupid,every,time,came,table',
#  'first,visit,hiro,wa,delight',
#  'service,suck',
#  'shrimp,tender,moist',
#  'deal,good,enough,would,drag,establishment',
#  'hard,judge,whether,side,good,grossed,melted,styrofoam,nt,want,eat,fear,getting,sick',
#  'positive,note,server,wa,attentive,provided,great,service',
#  'frozen,puck,disgust,worst,people,behind,register',
#  'thing,like,wa,prime,rib,dessert,section',
#  's,bad,food,damn,generic',
#  'burger,good,beef,cooked,right',
#  'want,sandwich,go,firehouse',
#  'side,greek,salad,greek,dressing,wa,tasty,pita,hummus,wa,refreshing',
#  'ordered,duck,rare,wa,pink,tender,inside,nice,char,outside',
#  'came,running,u,realized,husband,left,sunglass,table',
#  'chow,mein,good',
#  'horrible,attitude,towards,customer,talk,one,customer,nt,enjoy,food',
#  'portion,wa,huge',
#  'loved,friendly,server,great,food,wonderful,imaginative,menu',
#  'heart,attack,grill,downtown,vega,absolutely,flatlined,excuse,restaurant',
#  'much,seafood,like,5,string,pasta,bottom',
#  'salad,right,amount,sauce,power,scallop,wa,perfectly,cooked',
#  'ripped,banana,wa,ripped,petrified,tasteless',
#  'least,think,refill,water,struggle,wave,10,minute',
#  'place,receives,star,appetizer',
#  'cocktail,handmade,delicious',
#  'd,definitely,go,back',
#  'glad,found,place',
#  'great,food,service,huge,portion,give,military,discount',
#  'always,great,time,gringo',
#  'update,went,back,second,time,wa,still,amazing',
#  'got,food,apparently,never,heard,salt,batter,fish,wa,chewy',
#  'great,way,finish,great',
#  'deal,included,5,tasting,2,drink,jeff,went,beyond,expected',
#  'really,really,good,rice,time',
#  'service,wa,meh',
#  'took,30,min,get,milkshake,wa,nothing,chocolate,milk',
#  'guess,known,place,would,suck,inside,excalibur,nt,use,common,sense',
#  'scallop,dish,quite,appalling,value,well',
#  '2,time,bad,customer,service',
#  'sweet,potato,fry,good,seasoned,well',
#  'today,second,time,ve,lunch,buffet,wa,pretty,good',
#  'much,good,food,vega,feel,cheated,wasting,eating,opportunity,going,rice,company',
#  'coming,like,experiencing,underwhelming,relationship,party,ca,nt,wait,person,ask,break',
#  'walked,place,smelled,like,old,grease,trap,2,others,eating',
#  'turkey,roast,beef,bland',
#  'place,ha',
#  'pan,cake,everyone,raving,taste,like,sugary,disaster,tailored,palate,six,year,old',
#  'love,pho,spring,roll,oh,yummy,try',
#  'poor,batter,meat,ratio,made,chicken,tender,unsatisfying',
#  'say,food,wa,amazing',
#  'omelet,die',
#  'everything,wa,fresh,delicious',
#  'summary,wa,largely,disappointing,dining,experience',
#  's,like,really,sexy,party,mouth,re,outrageously,flirting,hottest,person,party',
#  'never,hard,rock,casino,never,ever,step,forward',
#  'best,breakfast,buffet',
#  'say,bye,bye,tip,lady',
#  'll,never,go',
#  'back',
#  'food,arrived,quickly',
#  'wa,good',
#  'side,cafe,serf,really,good,food',
#  'server,wa,fantastic,found,wife,love,roasted,garlic,bone,marrow,added,extra,meal,another,marrow,go',
#  'good,thing,wa,waiter,wa,helpful,kept,bloddy,mary,s,coming',
#  'best,buffet,town,price,beat',
#  'loved,mussel,cooked,wine,reduction,duck,wa,tender,potato,dish,delicious',
#  'one,better,buffet',
#  'went,tigerlilly,fantastic,afternoon',
#  'food,wa,delicious,bartender,wa,attentive,personable,got,great,deal',
#  'ambience,wonderful,music,playing',
#  'go,back,next,trip',
#  'sooooo,good',
#  'real,sushi,lover,let,s,honest,yama,good',
#  'least,40min,passed,u,ordering,food,arriving,wa,nt,busy',
#  'really,fantastic,thai,restaurant,definitely,worth,visit',
#  'nice,spicy,tender',
#  'good,price',
#  'check',
#  'wa,pretty,gross',
#  've,better,atmosphere',
#  'kind,hard,mess,steak',
#  'although,much,liked,look,sound,place,actual,experience,wa,bit,disappointing',
#  'nt,know,place,managed,served,blandest,food,ever,eaten,preparing,indian,cuisine',
#  'worst,service,boot,least,worry',
#  'service,wa,fine,waitress,wa,friendly',
#  'guy,steak,steak,loving,son,ha,steak,best,worst,place,said,wa,best,steak,s,ever,eaten',
#  'thought,d,venture,away,get,good,sushi,place,really,hit,spot,night',
#  'host,staff,lack,better,word,bitch',
#  'bland,liking,place,number,reason,nt,want,waste,time,bad,reviewing,ll,leave',
#  'phenomenal,food,service,ambiance',
#  'would,nt,return',
#  'definitely,worth,venturing,strip,pork,belly,return,next,time,m,vega',
#  'place,way,overpriced,mediocre,food',
#  'penne,vodka,excellent',
#  'good,selection,food,including,massive,meatloaf,sandwich,crispy,chicken,wrap,delish,tuna,melt,tasty,burger',
#  'management,rude',
#  'delicious,nyc,bagel,good,selection,cream,cheese,real,lox,caper,even',
#  'great,subway,fact,s,good,come,every,subway,meet,expectation',
#  'seriously,solid,breakfast',
#  'one,best,bar,food,vega',
#  'wa,extremely,rude,really,many,restaurant,would,love,dine,weekend,vega',
#  'drink,wa,never,empty,made,really,great,menu,suggestion',
#  'nt',
#  'waiter,wa,nt,helpful,friendly,rarely,checked,u',
#  'husband,ate,lunch,disappointed,food,service',
#  'red,curry,much,bamboo,shoot,wa,nt,tasty',
#  'nice,blanket,moz,top,feel,like,wa,done,cover,subpar,food',
#  'bathroom,clean,place,well,decorated',
#  'menu,always,changing,food,quality,going,service,extremely,slow',
#  'service,wa,little,slow,considering,served,3,people,server,food,wa,coming,slow,pace',
#  'give,2,thumb',
#  'watched,waiter,pay,lot,attention,table,ignore,u',
#  'fiancé,came,middle,day,greeted,seated,right,away',
#  'great,restaurant,mandalay,bay',
#  'waited,forty,five,minute,vain',
#  'crostini,came,salad,wa,stale',
#  'highlight,great,quality,nigiri',
#  'staff,friendly,joint,always,clean',
#  'wa,different,cut,piece,day,still,wonderful,tender,well,well,flavored',
#  'ordered,voodoo,pasta,wa,first,time,d,really,excellent,pasta,since,going,gluten,free,several,year,ago',
#  'place,good',
#  'unfortunately,must,hit,bakery,leftover,day,everything,ordered,wa,stale',
#  'came,back,today,since,relocated,still,impressed',
#  'wa,seated,immediately',
#  'menu,diverse,reasonably,priced',
#  'avoid,cost',
#  'restaurant,always,full,never,wait',
#  'delicious',
#  'place,handsdown,one,best,place,eat,phoenix,metro,area',
#  'nt,go,looking,good,food',
#  've,never,treated,bad',
#  'bacon,hella,salty',
#  'also,ordered,spinach,avocado,salad,ingredient,sad,dressing,literally,zero,taste',
#  'really,vega,fine,dining,used,right,menu,handed,lady,price,listed',
#  'waitress,friendly',
#  'lordy,khao,soi,dish,missed,curry,lover',
#  'everything,menu,terrific,also,thrilled,made,amazing,accommodation,vegetarian,daughter',
#  'perhaps,caught,night,judging,review,m,inspired,go,back',
#  'service,leaf,lot,desired',
#  'atmosphere,modern,hip,maintaining,touch,coziness',
#  'weekly,haunt,definitely,place,come,back,every',
#  'literally,sat,20,minute,one,asking,take,order',
#  'burger,absolutely,flavor,meat,wa,totally,bland,burger,wa,overcooked,wa,charcoal,flavor',
#  'also,decided,send,back,waitress,looked,like,wa,verge,heart,attack',
#  'dressed,treated,rudely',
#  'wa,probably,dirt',
#  'love,place,hit,spot,want,something,healthy,lacking,quantity,flavor',
#  'ordered,lemon,raspberry,ice,cocktail,wa,also,incredible',
#  'food,sucked,expected,sucked,could,imagined',
#  'interesting,decor',
#  'really,like,crepe,station',
#  'also,served,hot,bread,butter,home,made,potato,chip,bacon,bit,top,original,good',
#  'watch,preparing,delicious,food',
#  'egg,roll,fantastic',
#  'order,arrived,one,gyro,wa,missing',
#  'salad,wing,ice,cream,dessert,left,feeling,quite,satisfied',
#  'm,really,sure,joey,s,wa,voted,best,hot,dog,valley,reader,phoenix,magazine',
#  'best,place,go,tasty,bowl,pho',
#  'live,music,friday,totally,blow',
#  've,never,insulted,felt,disrespected',
#  'friendly,staff',
#  'worth,drive',
#  ...]

# %% [markdown]
# #### <a id="post">Postprocessing</a>

# %%
#normalize the data by using L2 norm for training set: x^ = x / ||x||
#Due to the huge variance in the dataset, we want to minimize the effect, thus using L2 minimize the variance effect
#L2 normalization is the best choice

x_train_bag_norm = normalize(x_train_bag)

#normalize the data by using L2 norm for testing set 
x_test_bag_norm = normalize(x_test_bag)

# %% [markdown]
# #### <a id="models">Logistic Regression vs Naive Bayes</a>

# %%
lrl2 = LogisticRegression()
lrl2.fit(x_train_bag_norm, y_train)
print("Logistic Regression normalized by L2 norm accuracy:{:.2f}".format(lrl2.score(x_test_bag_norm ,y_test)))
# Out:
# Logistic Regression normalized by L2 norm accuracy:0.74

# %%
print(len(x_train_bag_norm),len(y_train),len(x_test_bag_norm),len(y_test))
# Out:
# 1200 1200 300 300

# %%
gaussian = GaussianNB()
gaussian.fit(x_train_bag_norm, y_train)
print("Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:{:.2f}"
      .format(gaussian.score(x_test_bag_norm ,y_test)))

bernoulli = BernoulliNB()
bernoulli.fit(x_train_bag_norm, y_train)
print("Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:{:.2f}"
      .format(bernoulli.score(x_test_bag_norm ,y_test)))
# Out:
# Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:0.69
# Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:0.72

# %% [markdown]
# Logistic Regression model performs slightly better than Naive Bayes Classifier.

# %%
sorted_vocab = sorted(ctV.vocabulary_.items(), key=operator.itemgetter(1), reverse=True)
print("Dictionary with 10 highest values:")   
for word in sorted_vocab[:10]:
    print(word)
# Out:
# Dictionary with 10 highest values:
# ('zombiez', 2985)
# ('zombiestudents', 2984)
# ('zillion', 2983)
# ('zero', 2982)
# ('yun', 2981)
# ('yummy', 2980)
# ('yum', 2979)
# ('yukon', 2978)
# ('yucky', 2977)
# ('youthful', 2976)

# %% [markdown]
# #### <a id ="2">N-gram Model</a>

# %%
ctV2 = CountVectorizer(ngram_range=(2, 2))
#build a 2-gram dictionary of unique words for training set
x_train_bag2 = ctV2.fit_transform(x_train).todense()

ctV_test2 = CountVectorizer(vocabulary=ctV2.get_feature_names())
x_test_bag2 = ctV_test2.fit_transform(x_test).todense()

#postprocessing
x_train_bag_norm2 = normalize(x_train_bag2)

#normalize the data by using L2 norm for testing set 
x_test_bag_norm2 = normalize(x_test_bag2)

# %%
lrl2_2 = LogisticRegression()
lrl2_2.fit(x_train_bag_norm2, y_train)
print("Logistic Regression normalized by L2 norm accuracy:{:.2f}".format(lrl2_2.score(x_test_bag_norm2 ,y_test)))

gaussian2 = GaussianNB()
gaussian2.fit(x_train_bag_norm2, y_train)
print("Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:{:.2f}"
      .format(gaussian2.score(x_test_bag_norm2 ,y_test)))

bernoulli2 = BernoulliNB()
bernoulli2.fit(x_train_bag_norm2, y_train)
print("Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:{:.2f}"
      .format(bernoulli2.score(x_test_bag_norm2 ,y_test)))
# Out:
# Logistic Regression normalized by L2 norm accuracy:0.41
# Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:0.59
# Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:0.59

# %%
sorted_vocab2 = sorted(ctV2.vocabulary_.items(), key=operator.itemgetter(1), reverse=True)
print("Dictionary with 10 highest values:")   
for word in sorted_vocab2[:10]:
    print(word)
# Out:
# Dictionary with 10 highest values:
# ('zombiez part', 7181)
# ('zombiestudents back', 7180)
# ('zillion time', 7179)
# ('zero taste', 7178)
# ('zero star', 7177)
# ('yun fat', 7176)
# ('yummy try', 7175)
# ('yum yum', 7174)
# ('yum sauce', 7173)
# ('yukon gold', 7172)

# %% [markdown]
# #### <a id="pca">PCA for Bag of Words<a/>

# %%
#PCA Features = 10
pca = PCA(n_components=10)

x_trainpca = pca.fit_transform(x_train_bag_norm) 
x_testpca = pca.transform(x_test_bag_norm) 

lr_pca = LogisticRegression() 
lr_pca.fit(x_trainpca, y_train)
print("Logistic Regression normalized by L2 norm accuracy:{:.2f}".format(lr_pca.score(x_testpca ,y_test)))

gaussian_pca = GaussianNB()
gaussian_pca.fit(x_trainpca, y_train)
print("Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:{:.2f}"
      .format(gaussian_pca.score(x_testpca ,y_test)))

bernoulli_pca = BernoulliNB()
bernoulli_pca.fit(x_trainpca, y_train)
print("Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:{:.2f}"
      .format(bernoulli_pca.score(x_testpca ,y_test)))
# Out:
# Logistic Regression normalized by L2 norm accuracy:0.55
# Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:0.51
# Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:0.52

# %%
#PCA Features = 50
pca = PCA(n_components=50)

x_trainpca = pca.fit_transform(x_train_bag_norm) 
x_testpca = pca.transform(x_test_bag_norm) 

lr_pca = LogisticRegression() 
lr_pca.fit(x_trainpca, y_train)
print("Logistic Regression normalized by L2 norm accuracy:{:.2f}".format(lr_pca.score(x_testpca ,y_test)))

gaussian_pca = GaussianNB()
gaussian_pca.fit(x_trainpca, y_train)
print("Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:{:.2f}"
      .format(gaussian_pca.score(x_testpca ,y_test)))

bernoulli_pca = BernoulliNB()
bernoulli_pca.fit(x_trainpca, y_train)
print("Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:{:.2f}"
      .format(bernoulli_pca.score(x_testpca ,y_test)))
# Out:
# Logistic Regression normalized by L2 norm accuracy:0.67
# Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:0.62
# Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:0.59

# %%
pca = PCA(n_components=100)

x_trainpca = pca.fit_transform(x_train_bag_norm) 
x_testpca = pca.transform(x_test_bag_norm) 

lr_pca = LogisticRegression() 
lr_pca.fit(x_trainpca, y_train)
print("Logistic Regression normalized by L2 norm accuracy:{:.2f}".format(lr_pca.score(x_testpca ,y_test)))

gaussian_pca = GaussianNB()
gaussian_pca.fit(x_trainpca, y_train)
print("Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:{:.2f}"
      .format(gaussian_pca.score(x_testpca ,y_test)))

bernoulli_pca = BernoulliNB()
bernoulli_pca.fit(x_trainpca, y_train)
print("Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:{:.2f}"
      .format(bernoulli_pca.score(x_testpca ,y_test)))
# Out:
# Logistic Regression normalized by L2 norm accuracy:0.69
# Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:0.65
# Navie Bayes Classifier with Gaussian assumption normalized by L2 norm accuracy:0.60

# %% [markdown]
# Bag of words using logistic regression performs the best. It reserves all features of words with every single word being captured. The 2-gram method is worse off because it introduces unnecessary features which are more sparse, and it is more biased. The reason that PCA doesn't work well because when it reduces dimension, it also losses some information.
# Regarding to online review language usage, we notice that people always use similar keywords for each label, refer to top 20 words for positive label and negative label in part f and g.
