# %% [markdown]
# Key Points
# Key points to keep in mind when data wrangling for this project:
#
# You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# Cleaning includes merging individual pieces of data according to the rules of tidy data.
# The fact that the rating numerators are greater than the denominators does not need to be cleaned. This unique rating system is a big part of the popularity of WeRateDogs.
# You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %% [markdown]
# Your tasks in this project are as follows:
#
# Data wrangling, which consists of:
# - Gathering data
# - Assessing data
# - Cleaning data
#
#
# Storing, analyzing, and visualizing your wrangled data
# Reporting on 1) your data wrangling efforts and 2) your data analyses and visualizations

# %% [markdown]
# 1. The WeRateDogs Twitter archive. I am giving this file to you, so imagine it as a file on hand. Download this file manually by clicking the following link: twitter_archive_enhanced.csv
# 2. The tweet image predictions, i.e., what breed of dog (or other object, animal, etc.) is present in each tweet according to a neural network. This file (image_predictions.tsv) is hosted on Udacity's servers and should be downloaded programmatically using the Requests library and the following URL: https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv
# 3. Each tweet's retweet count and favorite ("like") count at minimum, and any additional data you find interesting. Using the tweet IDs in the WeRateDogs Twitter archive, query the Twitter API for each tweet's JSON data using Python's Tweepy library and store each tweet's entire set of JSON data in a file called tweet_json.txt file. Each tweet's JSON data should be written to its own line. Then read this .txt file line by line into a pandas DataFrame with (at minimum) tweet ID, retweet count, and favorite count. Note: do not include your Twitter API keys, secrets, and tokens in your project submission.

# %%
import pandas as pd
import numpy as np
import requests
import os
import json
import tweepy
import timeit
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# ### File 1. Enhanced Twitter Archive
#
# The WeRateDogs Twitter archive contains basic tweet data for all 5000+ of their tweets, but not everything. One column the archive does contain though: each tweet's text, which I used to extract rating, dog name, and dog "stage" (i.e. doggo, floofer, pupper, and puppo) to make this Twitter archive "enhanced." Of the 5000+ tweets, I have filtered for tweets with ratings only (there are 2356).

# %%
df_enhanced = pd.read_csv("twitter-archive-enhanced.csv")
df_enhanced.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %% [markdown]
# ### File 2. The tweet image predictions using url

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

# %%
#the name of the file
url.split("/")[-1]
# Out:
# 'image-predictions.tsv'

# %%
#create a file named 'image-predictions.tsv' with mode 'wb' (binary)
with open(url.split("/")[-1],"wb") as file:
    file.write(response.content)
    
#check if file is created
os.path.exists('image-predictions.tsv')
# Out:
# True

# %%
#read tsv file using pandas read_csv with seperator \t
df_pred=pd.read_csv("image-predictions.tsv", sep = "\t")
df_pred.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %% [markdown]
# ### File 3. Additional Data via the Twitter API
#
# Using the WeRateDogs Twitter archive and specifically the tweet IDs within it, I query Twitter's API to gather this additional data including retweet count, favorite count, user id, friends count, and followers count.

# %%
#not supposed to share keys
consumer_key = 'xxxxx'
consumer_secret = 'xxxxx'
access_token = 'xxxxx'
access_secret = 'xxxxx'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %%
api.get_status(892420643555336193, tweet_mode='extended')._json
# Out:
# {'created_at': 'Tue Aug 01 16:23:56 +0000 2017',
#  'id': 892420643555336193,
#  'id_str': '892420643555336193',
#  'full_text': "This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU",
#  'truncated': False,
#  'display_text_range': [0, 85],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [],
#   'media': [{'id': 892420639486877696,
#     'id_str': '892420639486877696',
#     'indices': [86, 109],
#     'media_url': 'http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#     'url': 'https://t.co/MgUWQ76dJU',
#     'display_url': 'pic.twitter.com/MgUWQ76dJU',
#     'expanded_url': 'https://twitter.com/dog_rates/status/892420643555336193/photo/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'medium': {'w': 540, 'h': 528, 'resize': 'fit'},
#      'small': {'w': 540, 'h': 528, 'resize': 'fit'},
#      'large': {'w': 540, 'h': 528, 'resize': 'fit'}}}]},
#  'extended_entities': {'media': [{'id': 892420639486877696,
#     'id_str': '892420639486877696',
#     'indices': [86, 109],
#     'media_url': 'http://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg',
#     'url': 'https://t.co/MgUWQ76dJU',
#     'display_url': 'pic.twitter.com/MgUWQ76dJU',
#     'expanded_url': 'https://twitter.com/dog_rates/status/892420643555336193/photo/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'medium': {'w': 540, 'h': 528, 'resize': 'fit'},
#      'small': {'w': 540, 'h': 528, 'resize': 'fit'},
#      'large': {'w': 540, 'h': 528, 'resize': 'fit'}}}]},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 4196983835,
#   'id_str': '4196983835',
#   'name': 'WeRateDogs®',
#   'screen_name': 'dog_rates',
#   'location': 'links and things ➜',
#   'description': 'Your Only Source For Professional Dog Ratings Instagram and Facebook ➜ WeRateDogs partnerships@weratedogs.com ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀',
#   'url': 'https://t.co/6ytGi24QCk',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/6ytGi24QCk',
#       'expanded_url': 'http://campsite.bio/weratedogs',
#       'display_url': 'campsite.bio/weratedogs',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 8944654,
#   'friends_count': 18,
#   'listed_count': 6240,
#   'created_at': 'Sun Nov 15 21:41:29 +0000 2015',
#   'favourites_count': 146142,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': True,
#   'statuses_count': 13294,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1322993722691211264/vyjR1ftm_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1322993722691211264/vyjR1ftm_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4196983835/1591077312',
#   'profile_link_color': 'F5ABB5',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 7421,
#  'favorite_count': 35159,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'possibly_sensitive_appealable': False,
#  'lang': 'en'}

# %% [markdown]
# Get `retweet_count`,`favorite_count`,`user_id`,`friends_count`and `followers_count` from Tweeter API._json

# %%
id_list = list(df_enhanced.tweet_id)
tweet_df,no_stats = {},{}
start_time = timeit.default_timer()
for tweetid in id_list:
    try:
        status = api.get_status(tweetid, tweet_mode='extended')._json
        tweet_df[tweetid] = {'retweet_count':status['retweet_count'],
                             'favorite_count':status['favorite_count'],
                             'user_id':status['user']['id'],
                             'friends_count':status['user']['friends_count'],
                             'followers_count':status['user']['followers_count']}
    except:
        no_stats[tweetid] = 'no status'      

print("Completed! Running Time: {:.2f} seconds".format(timeit.default_timer()- start_time))
# Out:
# Completed! Running Time: 562.19 seconds

# %% [markdown]
# Transform dictionary into Pandas DataFrame

# %%
retweet_df = pd.DataFrame.from_dict(tweet_df, orient = 'index')
retweet_df.reset_index(inplace=True)
retweet_df.rename(columns = {'index':'tweet_id'},inplace = True)
retweet_df.head()
# Out:
#              tweet_id  retweet_count  favorite_count     user_id  \
# 0  760190180481531904           1744            5565  4196983835
# 1  760252756032651264            847            3865  4196983835
# 2  760290219849637889          11170           26178  4196983835
# 3  760521673607086080           1362            4123  4196983835
# 4  760539183865880579           3523            7401  4196983835
#
#    friends_count  followers_count
# 0             18          8944594
# 1             18          8944594
# 2             18          8944594
# 3             18          8944594
# 4             18          8944594

# %%
len(id_list)
# Out:
# 2356

# %%
len(no_stats.keys())
# Out:
# 1493

# %%
retweet_df.to_csv('additional_tweeter_data.csv')

# %% [markdown]
# ### Accessing Data

# %% [markdown]
# #### Enhanced Twitter Archive
# `Quality`:
# - timestamp and retweeted_status_timestamp should be datetime object instead of objects
# - in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id should not be floats
# - tweet id (#835246439529840640) has a rating denominator of $0$.
# - expanded_urls has duplicates within some cells.
# - In columns like name, doggo, floofer, pupper, puppo, NA is marked as "None".
# - In name column, there are 55 names showing "a".
# - get prediction with highest confidence and reduce columns.
#
# `Tidiness`:
# - source column too complicated to understand
# - text column contains links to the tweet

# %%
pd.set_option("display.max_colwidth", -1)

# %%
df_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
df_enhanced.source.unique()
# Out:
# array(['<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#        '<a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>',
#        '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>'],
#       dtype=object)

# %%
sum(df_enhanced.duplicated())
# Out:
# 0

# %%
df_enhanced.expanded_urls.sample(10)
# Out:
# 988     https://twitter.com/dog_rates/status/748977405889503236/photo/1
# 1300    https://twitter.com/dog_rates/status/707693576495472641/photo/1
# 993     https://twitter.com/dog_rates/status/748575535303884801/photo/1
# 965     https://twitter.com/dog_rates/status/750429297815552001/photo/1,https://twitter.com/dog_rates/status/750429297815552001/photo/1
# 1919    https://twitter.com/dog_rates/status/674269164442398721/photo/1
# 269     https://twitter.com/abc/status/841311395547250688
# 653     https://twitter.com/dog_rates/status/792050063153438720/photo/1,https://twitter.com/dog_rates/status/792050063153438720/photo/1
# 2307    https://twitter.com/dog_rates/status/666826780179869698/photo/1
# 740     https://twitter.com/dog_rates/status/780543529827336192/photo/1
# 1820    https://twitter.com/dog_rates/status/676588346097852417/photo/1
# Name: expanded_urls, dtype: object

# %%
df_enhanced.in_reply_to_status_id.sample(10)
# Out:
# 603    NaN
# 1413   NaN
# 1499   NaN
# 872    NaN
# 621    NaN
# 853    NaN
# 1272   NaN
# 2322   NaN
# 1596   NaN
# 630    NaN
# Name: in_reply_to_status_id, dtype: float64

# %%
df_enhanced.rating_denominator.value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %%
df_enhanced[df_enhanced.rating_denominator == 0]
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313  835246439529840640           8.352460e+17           26259576.0
#
#                      timestamp  \
# 313  2017-02-24 21:54:03 +0000
#
#                                                 source  \
# 313  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 313  @jonnysun @Lin_Manuel ok jomny I know you're e...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp expanded_urls  \
# 313                       NaN                        NaN           NaN
#
#      rating_numerator  rating_denominator  name doggo floofer pupper puppo
# 313               960                   0  None  None    None   None  None

# %%
df_enhanced.name.value_counts()[:10]
# Out:
# None       745
# a           55
# Charlie     12
# Oliver      11
# Cooper      11
# Lucy        11
# Lola        10
# Penny       10
# Tucker      10
# Winston      9
# Name: name, dtype: int64

# %%
df_enhanced.doggo.value_counts()[:10]
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64

# %%
df_enhanced.floofer.value_counts()[:10]
# Out:
# None       2346
# floofer      10
# Name: floofer, dtype: int64

# %%
df_enhanced.pupper.value_counts()[:10]
# Out:
# None      2099
# pupper     257
# Name: pupper, dtype: int64

# %%
df_enhanced.puppo.value_counts()[:10]
# Out:
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %% [markdown]
# #### The tweet image predictions
# `Quality`:
# - id column should be string
# - predictions are a mix of upper and lower case
# - 2075 tweet id has images
#
# `Tidiness`:
# - all 2075 tweet id can be found in df_enhanced, suggesting predictions data should be joined to enhanced data.

# %%
df_pred.sample(10)
# Out:
#                 tweet_id                                            jpg_url  \
# 682   683834909291606017  https://pbs.twimg.com/ext_tw_video_thumb/68383...
# 640   681302363064414209    https://pbs.twimg.com/media/CXR44l9WcAAcG_N.jpg
# 1182  738402415918125056    https://pbs.twimg.com/media/Cj9VEs_XAAAlTai.jpg
# 689   684188786104872960    https://pbs.twimg.com/media/CX66EiJWkAAVjA-.jpg
# 1208  742385895052087300    https://pbs.twimg.com/media/Ck18CFcXIAAUWoy.jpg
# 1582  796759840936919040    https://pbs.twimg.com/media/Cw6o1JQXcAAtP78.jpg
# 1703  817181837579653120  https://pbs.twimg.com/ext_tw_video_thumb/81596...
# 1124  727286334147182592    https://pbs.twimg.com/media/ChfXDrGUkAEAtF-.jpg
# 2011  879008229531029506    https://pbs.twimg.com/media/DDLdUrqXYAMOVzY.jpg
# 318   671763349865160704    https://pbs.twimg.com/media/CVKVM3NW4AAdi1e.jpg
#
#       img_num                              p1   p1_conf  p1_dog  \
# 682         1                     Maltese_dog  0.738449    True
# 640         1                  frilled_lizard  0.326259   False
# 1182        1                  cocker_spaniel  0.346695    True
# 689         1                          kelpie  0.537782    True
# 1208        1                        Cardigan  0.566911    True
# 1582        1  American_Staffordshire_terrier  0.463996    True
# 1703        1                 Tibetan_mastiff  0.506312    True
# 1124        1                          bonnet  0.146440   False
# 2011        1                          vizsla  0.960513    True
# 318         1                      prayer_rug  0.445334   False
#
#                                   p2   p2_conf  p2_dog  \
# 682                       toy_poodle  0.102992    True
# 640                      tailed_frog  0.104539   False
# 1182                Blenheim_spaniel  0.193905    True
# 689   American_Staffordshire_terrier  0.082953    True
# 1208                   Border_collie  0.117566    True
# 1582       Staffordshire_bullterrier  0.155566    True
# 1703                 Tibetan_terrier  0.295690    True
# 1124                            sock  0.083091   False
# 2011              miniature_pinscher  0.009431    True
# 318                          doormat  0.275311   False
#
#                                   p3   p3_conf  p3_dog
# 682                          Samoyed  0.023247    True
# 640                          axolotl  0.072479   False
# 1182                       Chihuahua  0.078000    True
# 689        Staffordshire_bullterrier  0.069760    True
# 1208                     Appenzeller  0.047664    True
# 1582                      Weimaraner  0.137587    True
# 1703                      otterhound  0.036251    True
# 1124                       Chihuahua  0.070554    True
# 2011  American_Staffordshire_terrier  0.008711    True
# 318                              bib  0.048813   False

# %%
df_pred.tweet_id.nunique()
# Out:
# 2075

# %%
pred_id = set(df_pred.tweet_id)
archive_id = set(df_enhanced.tweet_id)
common_id = pred_id.intersection(archive_id)
print("prediction data has {} tweet ids, enhanced data has {} tweet ids, and they share {} common tweet ids."\
      .format(len(pred_id),len(archive_id),len(common_id)))
# Out:
# prediction data has 2075 tweet ids, enhanced data has 2356 tweet ids, and they share 2075 common tweet ids.

# %% [markdown]
# #### Additional Data via the Twitter API
# `Quality`:
# - only 863 tweet id has status
#
# `Tidiness`:
# - all 863 tweet id can be found in df_enhanced, suggesting predictions data should be joined to enhanced data.

# %%
retweet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 6 columns):
# tweet_id           863 non-null int64
# retweet_count      863 non-null int64
# favorite_count     863 non-null int64
# user_id            863 non-null int64
# friends_count      863 non-null int64
# followers_count    863 non-null int64
# dtypes: int64(6)
# memory usage: 40.5 KB

# %%
len(id_list)
# Out:
# 2356

# %%
len(no_stats.keys())
# Out:
# 1493

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Enhanced Twitter Archive
# `Quality`:
# - timestamp and retweeted_status_timestamp should be datetime object instead of objects
# - in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id should not be floats
# - tweet id (#835246439529840640) has a rating denominator of $0$.
# - expanded_urls has duplicates within some cells.
# - In columns like name, doggo, floofer, pupper, puppo, NA is marked as "None".
# - Transform doggo, floofer, pupper, puppo into one dog class column
# - In name column, there are 55 names showing "a".(can't fix)
# - get prediction with highest confidence and reduce columns.
#
# `Tidiness`:
# - source column too complicated to understand
# - text column contains links to the tweet
#
# #### The tweet image predictions
# `Quality`:
# - id column should be string
# - predictions are a mix of upper and lower case
# - 2075 tweet id has images
#
# `Tidiness`:
# - all 2075 tweet id can be found in df_enhanced, suggesting predictions data should be joined to enhanced data.
#
# #### Additional Data via the Twitter API
# `Quality`:
# - only 863 tweet id has status
#
# `Tidiness`:
# - all 863 tweet id can be found in df_enhanced, suggesting predictions data should be joined to enhanced data.

# %% [markdown]
# Start Cleaning:

# %% [markdown]
# `Tidiness`:
# - From df_pred, all 2075 tweet id can be found in df_enhanced, suggesting predictions data should be joined to enhanced data.
# - From retweet_df, all 863 tweet id can be found in df_enhanced, suggesting predictions data should be joined to enhanced data.

# %%
master_df = pd.merge(df_enhanced, df_pred, how = 'inner', on = 'tweet_id')
master_df = pd.merge(master_df, retweet_df, how = 'inner', on = 'tweet_id')

# %%
master_df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  ...   p2_conf  p2_dog  \
# 0  https://twitter.com/dog_rates/status/892420643...  ...  0.085851   False
# 1  https://twitter.com/dog_rates/status/892177421...  ...  0.090647    True
# 2  https://twitter.com/dog_rates/status/891815181...  ...  0.078253    True
# 3  https://twitter.com/dog_rates/status/891689557...  ...  0.168086    True
# 4  https://twitter.com/dog_rates/status/891327558...  ...  0.225770    True
#
#                             p3   p3_conf p3_dog retweet_count favorite_count  \
# 0                       banana  0.076110  False          7421          35160
# 1                     papillon  0.068957   True          5519          30433
# 2                       kelpie  0.031379   True          3644          22885
# 3                      spatula  0.040836  False          7595          38454
# 4  German_short-haired_pointer  0.175219   True          8173          36716
#
#       user_id  friends_count followers_count
# 0  4196983835             18         8944594
# 1  4196983835             18         8944594
# 2  4196983835             18         8944594
# 3  4196983835             18         8944594
# 4  4196983835             18         8944594
#
# [5 rows x 33 columns]

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 709 entries, 0 to 708
# Data columns (total 33 columns):
# tweet_id                      709 non-null int64
# in_reply_to_status_id         4 non-null float64
# in_reply_to_user_id           4 non-null float64
# timestamp                     709 non-null object
# source                        709 non-null object
# text                          709 non-null object
# retweeted_status_id           64 non-null float64
# retweeted_status_user_id      64 non-null float64
# retweeted_status_timestamp    64 non-null object
# expanded_urls                 709 non-null object
# rating_numerator              709 non-null int64
# rating_denominator            709 non-null int64
# name                          709 non-null object
# doggo                         709 non-null object
# floofer                       709 non-null object
# pupper                        709 non-null object
# puppo                         709 non-null object
# jpg_url                       709 non-null object
# img_num                       709 non-null int64
# p1                            709 non-null object
# p1_conf                       709 non-null float64
# p1_dog                        709 non-null bool
# p2                            709 non-null object
# p2_conf                       709 non-null float64
# p2_dog                        709 non-null bool
# p3                            709 non-null object
# p3_conf                       709 non-null float64
# p3_dog                        709 non-null bool
# retweet_count                 709 non-null int64
# favorite_count                709 non-null int64
# user_id                       709 non-null int64
# friends_count                 709 non-null int64
# followers_count               709 non-null int64
# dtypes: bool(3), float64(7), int64(9), object(14)
# memory usage: 173.8+ KB

# %% [markdown]
# `Tidiness`:
# - source column too complicated to understand

# %%
master_df.source.unique()
# Out:
# array(['<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#        '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>'],
#       dtype=object)

# %%
master_df['source'] = master_df.source.str.extract(r'>(.*)<')

# %%
master_df.source.tail(5)
# Out:
# 704    Twitter for iPhone
# 705    Twitter for iPhone
# 706    Twitter Web Client
# 707    Twitter for iPhone
# 708    Twitter for iPhone
# Name: source, dtype: object

# %% [markdown]
# `Tidiness`:
# - text column contains links to the tweet

# %%
pd.set_option("display.max_colwidth", -1)
master_df.text.sample(5)
# Out:
# 438    This is Bo. He's going to make me cry. 13/10 please get off the bus for him Carly https://t.co/U7FvBZo6Bq
# 498    This is Clark. He was just caught wearing pants. 13/10 game-changing af https://t.co/2Xo19aPrG5
# 177    At first I thought this was a dog because of the sign, but it is clearly Wilson from Home Improvement. Please only send in dogs... 11/10 https://t.co/jqPk1BZ6xu
# 448    Like doggo, like pupper version 2. Both 11/10 https://t.co/9IxWAXFqze
# 41     Meet Grizzwald. He may be the floofiest floofer I ever did see. Lost eyes saving a schoolbus from a volcano erpuption. 13/10 heroic as h*ck https://t.co/rf661IFEYP
# Name: text, dtype: object

# %%
master_df['text_link'] = master_df.text.str.extract(r'(https://.*)')
master_df['text'] = master_df.text.str.extract(r'(.*)https://')

# %%
master_df[['text','text_link']].sample(10)
# Out:
#                                                                                                                                             text  \
# 387  We only rate dogs. Please don't send in other things like this very good Christmas tree. Thank you... 13/10
# 386  Here's a doggo who has concluded that Christmas is entirely too bright. Requests you tone it down a notch. 11/10
# 271  This is Scooter and his son Montoya.  Scooter is a wonderful father. He takes very good care of Montoya. Both 12/10 would pet at same time
# 468  This is Shadow. He's a firm believer that they're all good dogs. H*ckin passionate about it too. 11/10 I stand with Shadow
# 252  This is Poppy. She just arrived. 13/10 would snug passionately
# 280  This is Malcolm. He goes from sneaky tongue slip to flirt wink city in a matter of seconds. 12/10 would hug softly
# 592  Have you ever seen such a smol pupper? Portable af. 12/10 would keep in shirt pocket
# 686  This is Belle. She's a Butterflop Hufflepoof. Rarer than most. Having trouble with car seat. 10/10 perturbed af
# 307  This is Sweet Pea. She hides in shoe boxes and waits for someone to pick her. Then she surpuprises them. 13/10
# 485  This is Ruby. She just turned on the news. Officially terrified. 11/10 deep breaths Ruby
#
#                    text_link
# 387  https://t.co/rvSANEsQZJ
# 386  https://t.co/cD967DjnIn
# 271  https://t.co/ghqMfxxa4V
# 468  https://t.co/8yvpacwBcu
# 252  https://t.co/YGeSpyN8Gu
# 280  https://t.co/rHwfySggqR
# 592  https://t.co/KsqaIzlQ12
# 686  https://t.co/VIXT3D26VM
# 307  https://t.co/AyBEmx56MD
# 485  https://t.co/y5KarNXWXt

# %% [markdown]
# `Quality`:
# - timestamp and retweeted_status_timestamp should be datetime object instead of objects

# %%
master_df.retweeted_status_timestamp.dtypes
# Out:
# dtype('O')

# %%
master_df.timestamp.dtypes
# Out:
# dtype('O')

# %%
master_df.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf',
#        'p2_dog', 'p3', 'p3_conf', 'p3_dog', 'retweet_count', 'favorite_count',
#        'user_id', 'friends_count', 'followers_count', 'text_link'],
#       dtype='object')

# %%
master_df.retweeted_status_timestamp = pd.to_datetime(master_df.retweeted_status_timestamp) 
master_df.timestamp = pd.to_datetime(master_df.timestamp)

# %%
master_df.retweeted_status_timestamp.dtypes
# Out:
# datetime64[ns, UTC]

# %%
master_df.timestamp.dtypes
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# `Quality`:
# - in_reply_to_status_id, in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id should not be floats

# %%
master_df[['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id']].dtypes
# Out:
# in_reply_to_status_id       float64
# in_reply_to_user_id         float64
# retweeted_status_id         float64
# retweeted_status_user_id    float64
# dtype: object

# %%
master_df.in_reply_to_status_id = master_df.in_reply_to_status_id.astype(str)
master_df.in_reply_to_user_id = master_df.in_reply_to_user_id.astype(str)
master_df.retweeted_status_id = master_df.retweeted_status_id.astype(str)
master_df.retweeted_status_user_id = master_df.retweeted_status_user_id.astype(str)

# %%
master_df[['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id']].dtypes
# Out:
# in_reply_to_status_id       object
# in_reply_to_user_id         object
# retweeted_status_id         object
# retweeted_status_user_id    object
# dtype: object

# %% [markdown]
# `Quality`:
# - tweet id (#835246439529840640) has a rating denominator of $0$.
#
# **When I merge I use inner join, so the client with rating denominator of $0$ has already been dropped due to another fields has NAs.**

# %%
master_df[master_df['rating_denominator']==0]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog, retweet_count, favorite_count, user_id, friends_count, followers_count, text_link]
# Index: []
#
# [0 rows x 34 columns]

# %%
master_df[master_df['tweet_id']=='835246439529840640)']
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog, retweet_count, favorite_count, user_id, friends_count, followers_count, text_link]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# `Quality`:
# - expanded_urls has duplicates within cell

# %%
master_df.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo',
#        'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf',
#        'p2_dog', 'p3', 'p3_conf', 'p3_dog', 'retweet_count', 'favorite_count',
#        'user_id', 'friends_count', 'followers_count', 'text_link'],
#       dtype='object')

# %%
master_df.expanded_urls.sample(10)
# Out:
# 283    https://twitter.com/dog_rates/status/828708714936930305/photo/1,https://twitter.com/dog_rates/status/828708714936930305/photo/1
# 583    https://twitter.com/dog_rates/status/780858289093574656/photo/1
# 46     https://twitter.com/dog_rates/status/882268110199369728/photo/1,https://twitter.com/dog_rates/status/882268110199369728/photo/1,https://twitter.com/dog_rates/status/882268110199369728/photo/1
# 613    https://twitter.com/dog_rates/status/776201521193218049/photo/1
# 267    http://www.gofundme.com/bluethewhitehusky,https://twitter.com/dog_rates/status/831650051525054464/photo/1,https://twitter.com/dog_rates/status/831650051525054464/photo/1,https://twitter.com/dog_rates/status/831650051525054464/photo/1,https://twitter.com/dog_rates/status/831650051525054464/photo/1
# 444    https://twitter.com/dog_rates/status/802952499103731712/photo/1
# 404    https://twitter.com/dog_rates/status/811627233043480576/photo/1
# 78     https://twitter.com/dog_rates/status/874296783580663808/photo/1
# 309    https://twitter.com/dog_rates/status/795076730285391872/photo/1,https://twitter.com/dog_rates/status/795076730285391872/photo/1,https://twitter.com/dog_rates/status/795076730285391872/photo/1,https://twitter.com/dog_rates/status/795076730285391872/photo/1,https://twitter.com/dog_rates/status/795076730285391872/photo/1,https://twitter.com/dog_rates/status/795076730285391872/photo/1
# 202    https://twitter.com/dog_rates/status/843604394117681152/photo/1
# Name: expanded_urls, dtype: object

# %%
master_df['expanded_urls'] = master_df.expanded_urls.str.extract(r'(https://twitter.com.*/photo/1)')

# %%
master_df['expanded_urls'] = master_df['expanded_urls'].str.split(',').str[0]

# %%
#check to make sure it is consistent
master_df.expanded_urls.iloc[[283,583,46,613,267,444,404,78,309,202]]
# Out:
# 283    https://twitter.com/dog_rates/status/828708714936930305/photo/1
# 583    https://twitter.com/dog_rates/status/780858289093574656/photo/1
# 46     https://twitter.com/dog_rates/status/882268110199369728/photo/1
# 613    https://twitter.com/dog_rates/status/776201521193218049/photo/1
# 267    https://twitter.com/dog_rates/status/831650051525054464/photo/1
# 444    https://twitter.com/dog_rates/status/802952499103731712/photo/1
# 404    https://twitter.com/dog_rates/status/811627233043480576/photo/1
# 78     https://twitter.com/dog_rates/status/874296783580663808/photo/1
# 309    https://twitter.com/dog_rates/status/795076730285391872/photo/1
# 202    https://twitter.com/dog_rates/status/843604394117681152/photo/1
# Name: expanded_urls, dtype: object

# %% [markdown]
# `Quality`:
# - In columns like name, doggo, floofer, pupper, puppo, NA is marked as "None".
# - Transform doggo, floofer, pupper, puppo into one dog class column

# %%
master_df['name'].value_counts()[:10]
# Out:
#            136
# Tucker     6
# Bo         6
# Charlie    6
# Penny      6
# Stanley    4
# Cooper     4
# Loki       4
# Dave       4
# Bailey     4
# Name: name, dtype: int64

# %%
master_df['doggo'].value_counts()
# Out:
# None     654
# doggo    55
# Name: doggo, dtype: int64

# %%
master_df['floofer'].value_counts()
# Out:
# None       705
# floofer    4
# Name: floofer, dtype: int64

# %%
master_df[['name','doggo','floofer','pupper','puppo']].sample(5)
# Out:
#         name doggo floofer  pupper puppo
# 569  Dave     None  None    None    None
# 653  Jackson  None  None    None    None
# 325  Gabe     None  None    pupper  None
# 290  Sailer   None  None    None    None
# 180  Odin     None  None    None    None

# %%
#replace None for np.nan in name column
master_df['name'] = master_df['name'].replace('None',np.nan)

# %%
master_df['doggo'] = master_df['doggo'].replace('None',"")
master_df['floofer'] = master_df['floofer'].replace('None',"")
master_df['pupper'] = master_df['pupper'].replace('None',"")
master_df['puppo'] = master_df['puppo'].replace('None',"")

# %%
#transform doggo, floofer, pupper, puppo into one dog class column
master_df['dog_class'] = master_df['doggo']+master_df['floofer']+master_df['pupper']+master_df['puppo']

# %%
master_df['dog_class'] = master_df['dog_class'].replace("",np.nan)

# %%
master_df['dog_class'].value_counts()
# Out:
# doggo           46
# pupper          43
# puppo           17
# doggopupper     7
# floofer         3
# doggopuppo      1
# doggofloofer    1
# Name: dog_class, dtype: int64

# %%
master_df['name'].value_counts()[:10]
# Out:
#            136
# Tucker     6
# Bo         6
# Charlie    6
# Penny      6
# Stanley    4
# Cooper     4
# Loki       4
# Dave       4
# Bailey     4
# Name: name, dtype: int64

# %%
master_df['floofer'].value_counts()
# Out:
#            705
# floofer    4
# Name: floofer, dtype: int64

# %%
master_df[['name','doggo','floofer','pupper','puppo','dog_class']].iloc[[569,653,325,290,180]]
# Out:
#         name doggo floofer  pupper puppo dog_class
# 569  Dave                                 NaN
# 653  Jackson                              NaN
# 325  Gabe                   pupper        pupper
# 290  Sailer                               NaN
# 180  Odin                                 NaN

# %%
master_df.drop(columns = ['doggo','floofer','pupper','puppo'],inplace = True)

# %% [markdown]
# `Quality`:
# - get prediction with highest confidence and reduce columns.

# %%
master_df.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'jpg_url', 'img_num', 'p1', 'p1_conf',
#        'p1_dog', 'p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog',
#        'retweet_count', 'favorite_count', 'user_id', 'friends_count',
#        'followers_count', 'text_link', 'dog_class'],
#       dtype='object')

# %%
master_df[['p1','p1_conf','p1_dog','p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog']].head()
# Out:
#             p1   p1_conf  p1_dog                  p2   p2_conf  p2_dog  \
# 0  orange       0.097049  False   bagel               0.085851  False
# 1  Chihuahua    0.323581  True    Pekinese            0.090647  True
# 2  Chihuahua    0.716012  True    malamute            0.078253  True
# 3  paper_towel  0.170278  False   Labrador_retriever  0.168086  True
# 4  basset       0.555712  True    English_springer    0.225770  True
#
#                             p3   p3_conf  p3_dog
# 0  banana                       0.076110  False
# 1  papillon                     0.068957  True
# 2  kelpie                       0.031379  True
# 3  spatula                      0.040836  False
# 4  German_short-haired_pointer  0.175219  True

# %%
def dog_pred(x):
    if x[1] > max(x[4],x[7]):
        return x[0]
    elif x[4] > max(x[1],x[7]):
        return x[3]
    else:
        return x[6]
def probability(x):
    if x[1] > max(x[4],x[7]):
        return x[1]
    elif x[4] > max(x[1],x[7]):
        return x[4]
    else:
        return x[7]
def TrueFalse(x):
    if x[1] > max(x[4],x[7]):
        return x[2]
    elif x[4] > max(x[1],x[7]):
        return x[5]
    else:
        return x[8]

# %%
master_df['pred']= master_df[['p1','p1_conf','p1_dog','p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog']]\
                    .apply(dog_pred,axis = 1)
master_df['p_conf']= master_df[['p1','p1_conf','p1_dog','p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog']]\
                    .apply(probability,axis = 1)
master_df['actual']= master_df[['p1','p1_conf','p1_dog','p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog']]\
                    .apply(TrueFalse,axis = 1)

# %%
master_df[['p1','p1_conf','p1_dog','p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog','pred','p_conf','actual']].head()
# Out:
#             p1   p1_conf  p1_dog                  p2   p2_conf  p2_dog  \
# 0  orange       0.097049  False   bagel               0.085851  False
# 1  Chihuahua    0.323581  True    Pekinese            0.090647  True
# 2  Chihuahua    0.716012  True    malamute            0.078253  True
# 3  paper_towel  0.170278  False   Labrador_retriever  0.168086  True
# 4  basset       0.555712  True    English_springer    0.225770  True
#
#                             p3   p3_conf  p3_dog         pred    p_conf  \
# 0  banana                       0.076110  False   orange       0.097049
# 1  papillon                     0.068957  True    Chihuahua    0.323581
# 2  kelpie                       0.031379  True    Chihuahua    0.716012
# 3  spatula                      0.040836  False   paper_towel  0.170278
# 4  German_short-haired_pointer  0.175219  True    basset       0.555712
#
#    actual
# 0  False
# 1  True
# 2  True
# 3  False
# 4  True

# %%
master_df.drop(columns = ['p1','p1_conf','p1_dog','p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog'],inplace = True)

# %%
master_df.pred.value_counts()[:10]
# Out:
# golden_retriever      74
# Labrador_retriever    37
# Pembroke              36
# Chihuahua             23
# chow                  23
# Samoyed               19
# cocker_spaniel        17
# malamute              14
# French_bulldog        14
# Cardigan              13
# Name: pred, dtype: int64

# %% [markdown]
# `Quality`:
# - predictions are a mix of upper and lower case

# %%
master_df.pred = master_df.pred.str.replace("_", " ").str.lower()

# %%
master_df.pred.value_counts()[:10]
# Out:
# golden retriever      74
# labrador retriever    37
# pembroke              36
# chihuahua             23
# chow                  23
# samoyed               19
# cocker spaniel        17
# malamute              14
# french bulldog        14
# cardigan              13
# Name: pred, dtype: int64

# %%
master_df
# Out:
#                tweet_id in_reply_to_status_id in_reply_to_user_id  \
# 0    892420643555336193  nan                   nan
# 1    892177421306343426  nan                   nan
# 2    891815181378084864  nan                   nan
# 3    891689557279858688  nan                   nan
# 4    891327558926688256  nan                   nan
# 5    891087950875897856  nan                   nan
# 6    890971913173991426  nan                   nan
# 7    890729181411237888  nan                   nan
# 8    890609185150312448  nan                   nan
# 9    890240255349198849  nan                   nan
# 10   890006608113172480  nan                   nan
# 11   889880896479866881  nan                   nan
# 12   889665388333682689  nan                   nan
# 13   889638837579907072  nan                   nan
# 14   889531135344209921  nan                   nan
# 15   889278841981685760  nan                   nan
# 16   888917238123831296  nan                   nan
# 17   888804989199671297  nan                   nan
# 18   888554962724278272  nan                   nan
# 19   888078434458587136  nan                   nan
# 20   887705289381826560  nan                   nan
# 21   887517139158093824  nan                   nan
# 22   887473957103951883  nan                   nan
# 23   887343217045368832  nan                   nan
# 24   887101392804085760  nan                   nan
# 25   886983233522544640  nan                   nan
# 26   886736880519319552  nan                   nan
# 27   886680336477933568  nan                   nan
# 28   886366144734445568  nan                   nan
# 29   886258384151887873  nan                   nan
# ..                  ...  ...                   ...
# 679  765395769549590528  nan                   nan
# 680  765371061932261376  nan                   nan
# 681  765222098633691136  nan                   nan
# 682  764857477905154048  nan                   nan
# 683  764259802650378240  nan                   nan
# 684  763837565564780549  nan                   nan
# 685  763183847194451968  nan                   nan
# 686  763103485927849985  nan                   nan
# 687  762699858130116608  nan                   nan
# 688  762471784394268675  nan                   nan
# 689  762464539388485633  nan                   nan
# 690  762316489655476224  nan                   nan
# 691  762035686371364864  nan                   nan
# 692  761976711479193600  nan                   nan
# 693  761750502866649088  nan                   nan
# 694  761745352076779520  nan                   nan
# 695  761672994376806400  nan                   nan
# 696  761599872357261312  nan                   nan
# 697  761371037149827077  nan                   nan
# 698  761334018830917632  nan                   nan
# 699  761292947749015552  nan                   nan
# 700  761227390836215808  nan                   nan
# 701  761004547850530816  nan                   nan
# 702  760893934457552897  nan                   nan
# 703  760656994973933572  nan                   nan
# 704  760641137271070720  nan                   nan
# 705  760539183865880579  nan                   nan
# 706  760290219849637889  nan                   nan
# 707  760252756032651264  nan                   nan
# 708  760190180481531904  nan                   nan
#
#                     timestamp              source  \
# 0   2017-08-01 16:23:56+00:00  Twitter for iPhone
# 1   2017-08-01 00:17:27+00:00  Twitter for iPhone
# 2   2017-07-31 00:18:03+00:00  Twitter for iPhone
# 3   2017-07-30 15:58:51+00:00  Twitter for iPhone
# 4   2017-07-29 16:00:24+00:00  Twitter for iPhone
# 5   2017-07-29 00:08:17+00:00  Twitter for iPhone
# 6   2017-07-28 16:27:12+00:00  Twitter for iPhone
# 7   2017-07-28 00:22:40+00:00  Twitter for iPhone
# 8   2017-07-27 16:25:51+00:00  Twitter for iPhone
# 9   2017-07-26 15:59:51+00:00  Twitter for iPhone
# 10  2017-07-26 00:31:25+00:00  Twitter for iPhone
# 11  2017-07-25 16:11:53+00:00  Twitter for iPhone
# 12  2017-07-25 01:55:32+00:00  Twitter for iPhone
# 13  2017-07-25 00:10:02+00:00  Twitter for iPhone
# 14  2017-07-24 17:02:04+00:00  Twitter for iPhone
# 15  2017-07-24 00:19:32+00:00  Twitter for iPhone
# 16  2017-07-23 00:22:39+00:00  Twitter for iPhone
# 17  2017-07-22 16:56:37+00:00  Twitter for iPhone
# 18  2017-07-22 00:23:06+00:00  Twitter for iPhone
# 19  2017-07-20 16:49:33+00:00  Twitter for iPhone
# 20  2017-07-19 16:06:48+00:00  Twitter for iPhone
# 21  2017-07-19 03:39:09+00:00  Twitter for iPhone
# 22  2017-07-19 00:47:34+00:00  Twitter for iPhone
# 23  2017-07-18 16:08:03+00:00  Twitter for iPhone
# 24  2017-07-18 00:07:08+00:00  Twitter for iPhone
# 25  2017-07-17 16:17:36+00:00  Twitter for iPhone
# 26  2017-07-16 23:58:41+00:00  Twitter for iPhone
# 27  2017-07-16 20:14:00+00:00  Twitter for iPhone
# 28  2017-07-15 23:25:31+00:00  Twitter for iPhone
# 29  2017-07-15 16:17:19+00:00  Twitter for iPhone
# ..                        ...                 ...
# 679 2016-08-16 03:52:26+00:00  Twitter for iPhone
# 680 2016-08-16 02:14:15+00:00  Twitter for iPhone
# 681 2016-08-15 16:22:20+00:00  Twitter for iPhone
# 682 2016-08-14 16:13:27+00:00  Twitter for iPhone
# 683 2016-08-13 00:38:30+00:00  Twitter for iPhone
# 684 2016-08-11 20:40:41+00:00  Twitter for iPhone
# 685 2016-08-10 01:23:03+00:00  Twitter for iPhone
# 686 2016-08-09 20:03:43+00:00  Twitter for iPhone
# 687 2016-08-08 17:19:51+00:00  Twitter for iPhone
# 688 2016-08-08 02:13:34+00:00  Twitter for iPhone
# 689 2016-08-08 01:44:46+00:00  Twitter for iPhone
# 690 2016-08-07 15:56:28+00:00  Twitter for iPhone
# 691 2016-08-06 21:20:40+00:00  Twitter for iPhone
# 692 2016-08-06 17:26:19+00:00  Twitter for iPhone
# 693 2016-08-06 02:27:27+00:00  Twitter for iPhone
# 694 2016-08-06 02:06:59+00:00  Twitter for iPhone
# 695 2016-08-05 21:19:27+00:00  Twitter for iPhone
# 696 2016-08-05 16:28:54+00:00  Twitter for iPhone
# 697 2016-08-05 01:19:35+00:00  Twitter for iPhone
# 698 2016-08-04 22:52:29+00:00  Twitter for iPhone
# 699 2016-08-04 20:09:17+00:00  Twitter for iPhone
# 700 2016-08-04 15:48:47+00:00  Twitter for iPhone
# 701 2016-08-04 01:03:17+00:00  Twitter for iPhone
# 702 2016-08-03 17:43:45+00:00  Twitter for iPhone
# 703 2016-08-03 02:02:14+00:00  Twitter for iPhone
# 704 2016-08-03 00:59:13+00:00  Twitter for iPhone
# 705 2016-08-02 18:14:06+00:00  Twitter for iPhone
# 706 2016-08-02 01:44:48+00:00  Twitter Web Client
# 707 2016-08-01 23:15:56+00:00  Twitter for iPhone
# 708 2016-08-01 19:07:17+00:00  Twitter for iPhone
#
#                                                                                                                                             text  \
# 0    This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10
# 1    This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10
# 2    This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10
# 3    This is Darla. She commenced a snooze mid meal. 13/10 happens to the best of us
# 4    This is Franklin. He would like you to stop calling him "cute." He is a very fierce shark and should be respected as such. 12/10 #BarkWeek
# 5    Here we have a majestic great white breaching off South Africa's coast. Absolutely h*ckin breathtaking. 13/10 (IG: tucker_marlo) #BarkWeek
# 6    https://t.co/Zr4hWfAs1H
# 7    When you watch your owner call another dog a good boy but then they turn back to you and say you're a great boy. 13/10
# 8    This is Zoey. She doesn't want to be one of the scary sharks. Just wants to be a snuggly pettable boatpet. 13/10 #BarkWeek
# 9    This is Cassie. She is a college pup. Studying international doggo communication and stick theory. 14/10 so elegant much sophisticate
# 10   This is Koda. He is a South Australian deckshark. Deceptively deadly. Frighteningly majestic. 13/10 would risk a petting #BarkWeek
# 11   This is Bruno. He is a service shark. Only gets out of the water to assist you. 13/10 terrifyingly good boy
# 12   Here's a puppo that seems to be on the fence about something haha no but seriously someone help her. 13/10
# 13   This is Ted. He does his best. Sometimes that's not enough. But it's ok. 12/10 would assist
# 14   This is Stuart. He's sporting his favorite fanny pack. Secretly filled with bones only. 13/10 puppared puppo #BarkWeek
# 15   This is Oliver. You're witnessing one of his many brutal attacks. Seems to be playing with his victim. 13/10 fr*ckin frightening #BarkWeek
# 16   This is Jim. He found a fren. Taught him how to sit like the good boys. 12/10 for both
# 17   This is Zeke. He has a new stick. Very proud of it. Would like you to throw it for him without taking it. 13/10 would do my best
# 18   This is Ralphus. He's powering up. Attempting maximum borkdrive. 13/10 inspirational af
# 19   This is Gerald. He was just told he didn't get the job he interviewed for. A h*ckin injustice. 12/10 didn't want the job anyway
# 20   This is Jeffrey. He has a monopoly on the pool noodles. Currently running a 'boop for two' midweek sale. 13/10 h*ckin strategic
# 21   I've yet to rate a Venezuelan Hover Wiener. This is such an honor. 14/10 paw-inspiring af (IG: roxy.thedoxy)
# 22   This is Canela. She attempted some fancy porch pics. They were unsuccessful. 13/10 someone help her
# 23   You may not have known you needed to see this today. 13/10 please enjoy (IG: emmylouroo)
# 24   This... is a Jubilant Antarctic House Bear. We only rate dogs. Please only send dogs. Thank you... 12/10 would suffocate in floof
# 25   This is Maya. She's very shy. Rarely leaves her cup. 13/10 would find her an environment to thrive in
# 26   https://t.co/bVi0Yr4Cff
# 27   This is Derek. He's late for a dog meeting. 13/10 pet...al to the metal
# 28   This is Roscoe. Another pupper fallen victim to spontaneous tongue ejections. Get the BlepiPen immediate. 12/10 deep breaths Roscoe
# 29   This is Waffles. His doggles are pupside down. Unsure how to fix. 13/10 someone assist Waffles
# ..                                                                                               ...
# 679  This is my dog. Her name is Zoey. She knows I've been rating other dogs. She's not happy. 13/10 no bias at all
# 680  This is Louie. He's had a long day. Did a lot of pupper things. Also appears to be rather heckin pettable. 11/10
# 681  This is Gromit. He's pupset because there's no need to beware of him. Just wants a pettin. 10/10
# 682  This is Aubie. He has paws for days. Nibbling tables is one of his priorities. Second only to being cuddly af. 12/10
# 683  This is Kota and her son Benedict. She doesn't know why you're staring. They are a normal family. Both 10/10
# 684  This is Alfie. He's touching a butt. Couldn't be happier. 11/10
# 685  This is Clark. He collects teddy bears. It's absolutely h*ckin horrifying. 8/10 please stop this Clark
# 686  This is Belle. She's a Butterflop Hufflepoof. Rarer than most. Having trouble with car seat. 10/10 perturbed af
# 687  This is Leela. She's a Fetty Woof. Lost eye while saving a baby from an avalanche. 11/10 true h*ckin hero
# 688  Meet Glenn. Being in public scares him. Frighteningly relatable. 12/10 keep hangin in there Glenn (Imgur - Wuhahha)
# 689  This is Buddy. His father was a bear and his mother was a perfectly toasted marshmallow. 12/10 would snug so well
# 690  This is Scout. He specializes in mid-air freeze frames. 11/10
# 691  This left me speechless. 14/10 heckin heroic af
# 692  This is Shelby. She finds stuff to put on her head for attention. It works really well. 12/10 talented af
# 693  RT @dog_rates: "Tristan do not speak to me with that kind of tone or I will take away the Xbox." 10/10
# 694  Guys.. we only rate dogs. Pls don't send any more pics of the Loch Ness Monster. Only send in dogs. Thank you. 11/10
# 695  Ohboyohboyohboyohboyohboyohboyohboyohboyohboyohboyohboyohboyohboyohboyohboy. 10/10 for all (by happytailsresort)
# 696  This is Sephie. According to this picture, she can read. Fantastic at following directions. 11/10 such a good girl
# 697  RT @dog_rates: Oh. My. God. 13/10 magical af
# 698  This is Bruce. I really want to hear the joke he was told. 10/10 for chuckle pup
# 699  Meet Bonaparte. He's pupset because it's cloudy at the beach. Can't take any pics for his Instagram. 11/10
# 700  This is Albert. He just found out that bees are dying globally at an alarming rate. 10/10 heckin worried af now
# 701  This is Bo and Ty. Bo eats paper and Ty felt left out. 11/10 for both
# 702  This is Wishes. He has the day off. Daily struggles of being a doggo have finally caught up with him. 11/10
# 703  This is Rose. Her face is stuck like that. 11/10 would pet so heckin well
# 704  This is Theo. He can walk on water. Still coming to terms with it. 12/10 magical af
# 705  This is Atlas. Swinging is his passion. 12/10 would push all day
# 706  This is Rocco. He's doing his best. 13/10 someone help him (IG: rocco_roni)
# 707  This is Fido. He can tell the weather. Not good at fetch tho. Never comes when called. 4/10 would probably still pet
# 708  Meet Sadie. She's addicted to balloons. It's tearing her family apart. Won't admit she has a problem. Still 10/10
#
#        retweeted_status_id retweeted_status_user_id  \
# 0    nan                    nan
# 1    nan                    nan
# 2    nan                    nan
# 3    nan                    nan
# 4    nan                    nan
# 5    nan                    nan
# 6    nan                    nan
# 7    nan                    nan
# 8    nan                    nan
# 9    nan                    nan
# 10   nan                    nan
# 11   nan                    nan
# 12   nan                    nan
# 13   nan                    nan
# 14   nan                    nan
# 15   nan                    nan
# 16   nan                    nan
# 17   nan                    nan
# 18   nan                    nan
# 19   nan                    nan
# 20   nan                    nan
# 21   nan                    nan
# 22   nan                    nan
# 23   nan                    nan
# 24   nan                    nan
# 25   nan                    nan
# 26   nan                    nan
# 27   nan                    nan
# 28   nan                    nan
# 29   nan                    nan
# ..   ...                    ...
# 679  nan                    nan
# 680  nan                    nan
# 681  nan                    nan
# 682  nan                    nan
# 683  nan                    nan
# 684  nan                    nan
# 685  nan                    nan
# 686  nan                    nan
# 687  nan                    nan
# 688  nan                    nan
# 689  nan                    nan
# 690  nan                    nan
# 691  nan                    nan
# 692  nan                    nan
# 693  6.853251128501248e+17  4196983835.0
# 694  nan                    nan
# 695  nan                    nan
# 696  nan                    nan
# 697  7.116947884295537e+17  4196983835.0
# 698  nan                    nan
# 699  nan                    nan
# 700  nan                    nan
# 701  nan                    nan
# 702  nan                    nan
# 703  nan                    nan
# 704  nan                    nan
# 705  nan                    nan
# 706  nan                    nan
# 707  nan                    nan
# 708  nan                    nan
#
#     retweeted_status_timestamp  \
# 0   NaT
# 1   NaT
# 2   NaT
# 3   NaT
# 4   NaT
# 5   NaT
# 6   NaT
# 7   NaT
# 8   NaT
# 9   NaT
# 10  NaT
# 11  NaT
# 12  NaT
# 13  NaT
# 14  NaT
# 15  NaT
# 16  NaT
# 17  NaT
# 18  NaT
# 19  NaT
# 20  NaT
# 21  NaT
# 22  NaT
# 23  NaT
# 24  NaT
# 25  NaT
# 26  NaT
# 27  NaT
# 28  NaT
# 29  NaT
# ..   ..
# 679 NaT
# 680 NaT
# 681 NaT
# 682 NaT
# 683 NaT
# 684 NaT
# 685 NaT
# 686 NaT
# 687 NaT
# 688 NaT
# 689 NaT
# 690 NaT
# 691 NaT
# 692 NaT
# 693 2016-01-08 05:00:14+00:00
# 694 NaT
# 695 NaT
# 696 NaT
# 697 2016-03-20 23:23:54+00:00
# 698 NaT
# 699 NaT
# 700 NaT
# 701 NaT
# 702 NaT
# 703 NaT
# 704 NaT
# 705 NaT
# 706 NaT
# 707 NaT
# 708 NaT
#
#                                                        expanded_urls  ...  \
# 0    https://twitter.com/dog_rates/status/892420643555336193/photo/1  ...
# 1    https://twitter.com/dog_rates/status/892177421306343426/photo/1  ...
# 2    https://twitter.com/dog_rates/status/891815181378084864/photo/1  ...
# 3    https://twitter.com/dog_rates/status/891689557279858688/photo/1  ...
# 4    https://twitter.com/dog_rates/status/891327558926688256/photo/1  ...
# 5    https://twitter.com/dog_rates/status/891087950875897856/photo/1  ...
# 6    https://twitter.com/dog_rates/status/890971913173991426/photo/1  ...
# 7    https://twitter.com/dog_rates/status/890729181411237888/photo/1  ...
# 8    https://twitter.com/dog_rates/status/890609185150312448/photo/1  ...
# 9    https://twitter.com/dog_rates/status/890240255349198849/photo/1  ...
# 10   https://twitter.com/dog_rates/status/890006608113172480/photo/1  ...
# 11   https://twitter.com/dog_rates/status/889880896479866881/photo/1  ...
# 12   https://twitter.com/dog_rates/status/889665388333682689/photo/1  ...
# 13   https://twitter.com/dog_rates/status/889638837579907072/photo/1  ...
# 14   https://twitter.com/dog_rates/status/889531135344209921/photo/1  ...
# 15   NaN                                                              ...
# 16   https://twitter.com/dog_rates/status/888917238123831296/photo/1  ...
# 17   https://twitter.com/dog_rates/status/888804989199671297/photo/1  ...
# 18   https://twitter.com/dog_rates/status/888554962724278272/photo/1  ...
# 19   https://twitter.com/dog_rates/status/888078434458587136/photo/1  ...
# 20   https://twitter.com/dog_rates/status/887705289381826560/photo/1  ...
# 21   NaN                                                              ...
# 22   https://twitter.com/dog_rates/status/887473957103951883/photo/1  ...
# 23   NaN                                                              ...
# 24   https://twitter.com/dog_rates/status/887101392804085760/photo/1  ...
# 25   https://twitter.com/dog_rates/status/886983233522544640/photo/1  ...
# 26   https://twitter.com/dog_rates/status/886736880519319552/photo/1  ...
# 27   https://twitter.com/dog_rates/status/886680336477933568/photo/1  ...
# 28   https://twitter.com/dog_rates/status/886366144734445568/photo/1  ...
# 29   https://twitter.com/dog_rates/status/886258384151887873/photo/1  ...
# ..                                                               ...  ...
# 679  https://twitter.com/dog_rates/status/765395769549590528/photo/1  ...
# 680  https://twitter.com/dog_rates/status/765371061932261376/photo/1  ...
# 681  https://twitter.com/dog_rates/status/765222098633691136/photo/1  ...
# 682  https://twitter.com/dog_rates/status/764857477905154048/photo/1  ...
# 683  https://twitter.com/dog_rates/status/764259802650378240/photo/1  ...
# 684  https://twitter.com/dog_rates/status/763837565564780549/photo/1  ...
# 685  https://twitter.com/dog_rates/status/763183847194451968/photo/1  ...
# 686  https://twitter.com/dog_rates/status/763103485927849985/photo/1  ...
# 687  https://twitter.com/dog_rates/status/762699858130116608/photo/1  ...
# 688  NaN                                                              ...
# 689  https://twitter.com/dog_rates/status/762464539388485633/photo/1  ...
# 690  https://twitter.com/dog_rates/status/762316489655476224/photo/1  ...
# 691  NaN                                                              ...
# 692  https://twitter.com/dog_rates/status/761976711479193600/photo/1  ...
# 693  https://twitter.com/dog_rates/status/685325112850124800/photo/1  ...
# 694  https://twitter.com/dog_rates/status/761745352076779520/photo/1  ...
# 695  NaN                                                              ...
# 696  https://twitter.com/dog_rates/status/761599872357261312/photo/1  ...
# 697  https://twitter.com/dog_rates/status/711694788429553666/photo/1  ...
# 698  https://twitter.com/dog_rates/status/761334018830917632/photo/1  ...
# 699  https://twitter.com/dog_rates/status/761292947749015552/photo/1  ...
# 700  https://twitter.com/dog_rates/status/761227390836215808/photo/1  ...
# 701  https://twitter.com/dog_rates/status/761004547850530816/photo/1  ...
# 702  https://twitter.com/dog_rates/status/760893934457552897/photo/1  ...
# 703  https://twitter.com/dog_rates/status/760656994973933572/photo/1  ...
# 704  https://twitter.com/dog_rates/status/760641137271070720/photo/1  ...
# 705  https://twitter.com/dog_rates/status/760539183865880579/photo/1  ...
# 706  NaN                                                              ...
# 707  https://twitter.com/dog_rates/status/760252756032651264/photo/1  ...
# 708  https://twitter.com/dog_rates/status/760190180481531904/photo/1  ...
#
#      retweet_count  favorite_count     user_id friends_count  followers_count  \
# 0    7421           35160           4196983835  18            8944594
# 1    5519           30433           4196983835  18            8944594
# 2    3644           22885           4196983835  18            8944594
# 3    7595           38454           4196983835  18            8944594
# 4    8173           36716           4196983835  18            8944594
# 5    2743           18500           4196983835  18            8944594
# 6    1773           10759           4196983835  18            8944594
# 7    16605          59207           4196983835  18            8944594
# 8    3790           25481           4196983835  18            8944594
# 9    6431           29075           4196983835  18            8944594
# 10   6451           28034           4196983835  18            8944594
# 11   4383           25497           4196983835  18            8944594
# 12   8799           43785           4196983835  18            8944594
# 13   3934           24611           4196983835  18            8944594
# 14   1985           13870           4196983835  18            8944594
# 15   4684           22969           4196983835  18            8944594
# 16   3939           26593           4196983835  18            8944594
# 17   3724           23340           4196983835  18            8944594
# 18   3044           17994           4196983835  18            8944594
# 19   3050           19894           4196983835  18            8944594
# 20   4749           27646           4196983835  18            8944594
# 21   10352          42326           4196983835  18            8944594
# 22   15807          62641           4196983835  18            8944594
# 23   9263           30731           4196983835  18            8944594
# 24   5246           27993           4196983835  18            8944594
# 25   6723           31717           4196983835  18            8944594
# 26   2795           10904           4196983835  18            8944594
# 27   3937           20530           4196983835  18            8945289
# 28   2783           19283           4196983835  18            8944594
# 29   5568           25546           4196983835  18            8944594
# ..    ...             ...                  ...  ..                ...
# 679  3308           26135           4196983835  18            8944594
# 680  2116           6923            4196983835  18            8944594
# 681  3306           11391           4196983835  18            8944594
# 682  1737           6319            4196983835  18            8944594
# 683  1469           5889            4196983835  18            8944594
# 684  4037           12282           4196983835  18            8944594
# 685  1437           5263            4196983835  18            8944594
# 686  2251           7225            4196983835  18            8944594
# 687  3510           11862           4196983835  18            8944594
# 688  6240           10980           4196983835  18            8944594
# 689  4055           10071           4196983835  18            8944594
# 690  1083           4691            4196983835  18            8944594
# 691  15134          31112           4196983835  18            8944594
# 692  1948           5278            4196983835  18            8944594
# 693  3808           0               4196983835  18            8944594
# 694  840            4182            4196983835  18            8944594
# 695  28312          48284           4196983835  18            8944594
# 696  1160           4032            4196983835  18            8944594
# 697  17594          0               4196983835  18            8944594
# 698  1419           5073            4196983835  18            8944594
# 699  1057           4388            4196983835  18            8944594
# 700  1521           5216            4196983835  18            8944594
# 701  3384           11092           4196983835  18            8944594
# 702  944            3730            4196983835  18            8944594
# 703  1853           6440            4196983835  18            8944594
# 704  1262           4872            4196983835  18            8944594
# 705  3523           7401            4196983835  18            8944594
# 706  11170          26178           4196983835  18            8944594
# 707  847            3865            4196983835  18            8944594
# 708  1744           5565            4196983835  18            8944594
#
#                                            text_link  dog_class  \
# 0    https://t.co/MgUWQ76dJU                          NaN
# 1    https://t.co/0Xxu71qeIV                          NaN
# 2    https://t.co/wUnZnhtVJB                          NaN
# 3    https://t.co/tD36da7qLQ                          NaN
# 4    https://t.co/AtUZn91f7f                          NaN
# 5    https://t.co/kQ04fDDRmh                          NaN
# 6    https://t.co/Zr4hWfAs1H https://t.co/tVJBRMnhxl  NaN
# 7    https://t.co/v0nONBcwxq                          NaN
# 8    https://t.co/9TwLuAGH0b                          NaN
# 9    https://t.co/t1bfwz5S2A                          doggo
# 10   https://t.co/dVPW0B0Mme                          NaN
# 11   https://t.co/u1XPQMl29g                          NaN
# 12   https://t.co/BxvuXk0UCm                          puppo
# 13   https://t.co/f8dEDcrKSR                          NaN
# 14   https://t.co/y70o6h3isq                          puppo
# 15   https://t.co/WpHvrQedPb                          NaN
# 16   https://t.co/chxruIOUJN                          NaN
# 17   https://t.co/HTQ77yNQ5K                          NaN
# 18   https://t.co/YnYAFCTTiK                          NaN
# 19   https://t.co/DK7iDPfuRX                          NaN
# 20   https://t.co/PhrUk20Q64                          NaN
# 21   https://t.co/20VrLAA8ba                          NaN
# 22   https://t.co/cLyzpcUcMX                          NaN
# 23   https://t.co/WZqNqygEyV                          NaN
# 24   https://t.co/4Ad1jzJSdp                          NaN
# 25   https://t.co/I6oNy0CgiT                          NaN
# 26   https://t.co/bVi0Yr4Cff https://t.co/ISvKOSkd5b  NaN
# 27   https://t.co/BCoWue0abA                          NaN
# 28   https://t.co/RGE08MIJox                          pupper
# 29   https://t.co/xZDA9Qsq1O                          NaN
# ..                       ...                          ...
# 679  https://t.co/ep1NkYoiwB                          NaN
# 680  https://t.co/w2qDmoTIZ5                          pupper
# 681  https://t.co/eSvz4EapHH                          NaN
# 682  https://t.co/cBIFBsCRz6                          NaN
# 683  https://t.co/Q1v9BZylvZ                          NaN
# 684  https://t.co/gx3xF5mZbo                          NaN
# 685  https://t.co/EDMcwt86fU                          NaN
# 686  https://t.co/VIXT3D26VM                          NaN
# 687  https://t.co/2lBg3ZgivD                          NaN
# 688  https://t.co/pA4MDKwRci                          NaN
# 689  https://t.co/zGSj1oUgxx                          NaN
# 690  https://t.co/sAHmwRtfSq                          NaN
# 691  https://t.co/3td8P3o0mB                          NaN
# 692  https://t.co/WTZ484EntP                          NaN
# 693  https://t.co/VGPH0TfESw                          NaN
# 694  https://t.co/obH5vMbm1j                          NaN
# 695  https://t.co/EY8kEFuzK7                          NaN
# 696  https://t.co/7HY9RvCudo                          NaN
# 697  https://t.co/Ezu6jQrKAZ                          NaN
# 698  https://t.co/ErPLjjJOKc                          NaN
# 699  https://t.co/0THNOfv2Jo                          NaN
# 700  https://t.co/nhLX27WsDY                          NaN
# 701  https://t.co/1acHQS8rvK                          NaN
# 702  https://t.co/H9YgrUkYwa                          doggo
# 703  https://t.co/tl3gNYdoq2                          NaN
# 704  https://t.co/8Kmuj6SFbC                          NaN
# 705  https://t.co/9k8LLjJ0uJ                          NaN
# 706  https://t.co/qFsl1nnXMv                          NaN
# 707  https://t.co/4gOv2Q3iKP                          NaN
# 708  https://t.co/h6s9Rch0gZ                          NaN
#
#                          pred    p_conf  actual
# 0    orange                    0.097049  False
# 1    chihuahua                 0.323581  True
# 2    chihuahua                 0.716012  True
# 3    paper towel               0.170278  False
# 4    basset                    0.555712  True
# 5    chesapeake bay retriever  0.425595  True
# 6    appenzeller               0.341703  True
# 7    pomeranian                0.566142  True
# 8    irish terrier             0.487574  True
# 9    pembroke                  0.511319  True
# 10   samoyed                   0.957979  True
# 11   french bulldog            0.377417  True
# 12   pembroke                  0.966327  True
# 13   french bulldog            0.991650  True
# 14   golden retriever          0.953442  True
# 15   whippet                   0.626152  True
# 16   golden retriever          0.714719  True
# 17   golden retriever          0.469760  True
# 18   siberian husky            0.700377  True
# 19   french bulldog            0.995026  True
# 20   basset                    0.821664  True
# 21   limousine                 0.130432  False
# 22   pembroke                  0.809197  True
# 23   mexican hairless          0.330741  True
# 24   samoyed                   0.733942  True
# 25   chihuahua                 0.793469  True
# 26   kuvasz                    0.309706  True
# 27   convertible               0.738995  False
# 28   french bulldog            0.999201  True
# 29   pug                       0.943575  True
# ..   ...                            ...   ...
# 679  pembroke                  0.509491  True
# 680  golden retriever          0.829456  True
# 681  dalmatian                 0.556595  True
# 682  bernese mountain dog      0.792059  True
# 683  german shepherd           0.973677  True
# 684  malamute                  0.375098  True
# 685  miniature poodle          0.354674  True
# 686  seat belt                 0.685821  False
# 687  kelpie                    0.519047  True
# 688  samoyed                   0.540276  True
# 689  chow                      0.999953  True
# 690  african grey              0.270468  False
# 691  home theater              0.063152  False
# 692  labrador retriever        0.475552  True
# 693  golden retriever          0.586937  True
# 694  paddle                    0.393118  False
# 695  gondola                   0.318851  False
# 696  gordon setter             0.240427  True
# 697  brown bear                0.713293  False
# 698  norwegian elkhound        0.822936  True
# 699  standard poodle           0.660893  True
# 700  cougar                    0.306512  False
# 701  golden retriever          0.735163  True
# 702  blenheim spaniel          0.113992  True
# 703  golden retriever          0.760546  True
# 704  axolotl                   0.132695  False
# 705  samoyed                   0.988013  True
# 706  old english sheepdog      0.302200  True
# 707  radio telescope           0.155279  False
# 708  balloon                   0.917525  False
#
# [709 rows x 25 columns]

# %%
#save master file
master_df.to_csv('master.csv', index = False)

# %% [markdown]
# ### Analysis

# %% [markdown]
# 1. Based on the predictions with the most confidence, top 1 predictions is golden retriever.

# %%
master_df['pred'].value_counts()[:10].plot(kind = 'bar');

# %%
df_pred['p1'].value_counts()[:10]
# Out:
# golden_retriever      150
# Labrador_retriever    100
# Pembroke              89
# Chihuahua             83
# pug                   57
# chow                  44
# Samoyed               43
# toy_poodle            39
# Pomeranian            38
# cocker_spaniel        30
# Name: p1, dtype: int64

# %%
plt.subplot(1,3,1)
df_pred['p1'].value_counts()[:10].plot(kind = 'bar', figsize = (20,5));
plt.subplot(1,3,2)
df_pred['p2'].value_counts()[:10].plot(kind = 'bar', figsize = (20,5));
plt.subplot(1,3,3)
df_pred['p3'].value_counts()[:10].plot(kind = 'bar', figsize = (20,5));

# %% [markdown]
# 2. Based on the top 1 predictions: golden retriever, if I sort by the most retweet count as well as favorite count, I found that golden retriever is also the most popular dog.

# %%
dog_info = master_df[['pred','actual','retweet_count','favorite_count']]

# %%
dog_info1 = dog_info.groupby('pred').agg({'actual':['sum','count'],'retweet_count':'sum','favorite_count':'sum'})

# %%
dog_info1.sort_values([('favorite_count','sum'),('retweet_count','sum')],ascending = [False,False])[:10]
# Out:
#                    actual       retweet_count favorite_count
#                       sum count           sum            sum
# pred
# golden retriever    74.0   74    363066        1145276
# pembroke            36.0   36    165856        691380
# labrador retriever  37.0   37    160047        549143
# chihuahua           23.0   23    150557        459822
# french bulldog      14.0   14    94773         395938
# samoyed             19.0   19    138587        380207
# chow                23.0   23    84461         289617
# cocker spaniel      17.0   17    95750         252063
# cardigan            13.0   13    70150         196740
# pomeranian          9.0    9     60269         186431

# %% [markdown]
# 3. Checking predictions accuracy, based on the cleaned data, the total accuracy is around 80% with golden retriever  100% accuracy.

# %%
dog_pred = dog_info1['actual'].reset_index()

# %%
dog_pred['percentage'] = dog_pred['sum']/dog_pred['count']

# %%
dog_pred.sort_values(by=['percentage','sum'],ascending = False)[:10]
# Out:
#                    pred   sum  count  percentage
# 73   golden retriever    74.0  74     1.0
# 94   labrador retriever  37.0  37     1.0
# 132  pembroke            36.0  36     1.0
# 41   chihuahua           23.0  23     1.0
# 43   chow                23.0  23     1.0
# 151  samoyed             19.0  19     1.0
# 45   cocker spaniel      17.0  17     1.0
# 67   french bulldog      14.0  14     1.0
# 106  malamute            14.0  14     1.0
# 39   cardigan            13.0  13     1.0

# %%
dog_pred['sum'].sum()
# Out:
# 564.0

# %%
total_acc = dog_pred['sum'].sum()/dog_pred['count'].sum()
print("Based on cleaned data, prediction accuracy is {:.2f}%".format(total_acc*100))
# Out:
# Based on cleaned data, prediction accuracy is 79.55%
